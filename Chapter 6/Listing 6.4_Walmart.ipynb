# %% [markdown]
# # Solving Delivery Semi-Truck Routing Problem

# %%
from optalgotools.algorithms import TabuSearch
from optalgotools.problems import TSP
import pandas as pd
import numpy as np
import osmnx as ox
import networkx as nx
import folium
import folium.plugins

# %% [markdown]
# ## Data Preperation

# %%
# Load list of all walmart locations on Ontario
# Data is available in Appendix B of the book's GitHub repo and can be read directly using URL begins with raw.
wal_df = pd.read_csv("https://raw.githubusercontent.com/Optimization-Algorithms-Book/Code-Listings/main/Appendix%20B/data/TSP/Walmart_ON.csv")

# %%
wal_df.tail(5)
# Out:
#       latitude  longitude                store_number           phone  \
# 148  43.917370 -78.959730  Walmart Supercentre; #3113  (905) 655-0206
# 149  42.270682 -83.010996  Walmart Supercentre; #3114  (519) 969-8121
# 150  42.314048 -82.942432  Walmart Supercentre; #3115  (519) 945-3065
# 151  43.786103 -79.628413  Walmart Supercentre; #1081  (905) 851-4648
# 152  43.115150 -80.734587  Walmart Supercentre; #3120  (519) 539-5120
#
#                 address        city Province postal_code
# 148   4100 Baldwin St S      Whitby       ON     L1R 3H8
# 149    3120 Dougall Ave     Windsor       ON     N9E 1S7
# 150  7100 Tecumseh Rd E     Windsor       ON     N8T 1E6
# 151         8300 Hwy 27  Woodbridge       ON     L4H 0R9
# 152     499 Norwich Ave   Woodstock       ON     N4S 9A2

# %%
# city to region mapping from wikipedia
cityToRegion = {
    'Toronto': 'Toronto',
    'Ajax': 'Durham Region',
    'Clarington': 'Durham Region',
    'Brock': 'Durham Region',
    'Oshawa': 'Durham Region',
    'Pickering': 'Durham Region',
    'Scugog': 'Durham Region',
    'Uxbridge': 'Durham Region',
    'Whitby': 'Durham Region',
    'Burlington': 'Halton Region',
    'Halton Hills': 'Halton Region',
    'Milton': 'Halton Region',
    'Oakville': 'Halton Region',
    'Brampton': 'Peel Region',
    'Caledon': 'Peel Region',
    'Mississauga': 'Peel Region',
    'Aurora': 'York Region',
    'East Gwillimbury': 'York Region',
    'Georgina': 'York Region',
    'King': 'York Region',
    'Markham': 'York Region',
    'Newmarket': 'York Region',
    'Richmond Hill': 'York Region',
    'Vaughan': 'York Region',
    'Whitchurch-Stouffville': 'York Region',
    'Mono': 'Dufferin County',
    'Orangeville': 'Dufferin County',
    'Bradford West Gwillimbury': 'Simcoe County',
    'New Tecumseth': 'Simcoe County'
}

# %%
# selecting cities that are in Durham Region, York Region, or Toronto
cities_list = [city for city, region in cityToRegion.items() if city in wal_df.city.unique() and region in ['Durham Region', 'York Region', 'Toronto']]
print(cities_list)
# Out:
# ['Toronto', 'Ajax', 'Oshawa', 'Pickering', 'Uxbridge', 'Whitby', 'Aurora', 'Markham', 'Newmarket', 'Richmond Hill', 'Vaughan']

# %%
# select walmarts thar are in the above list and is Supercentre
gta_part = wal_df[wal_df.store_number.str.startswith('Walmart Supercentre') & wal_df.city.isin(cities_list)].reset_index(drop=True)
wal_gta_count = gta_part.shape[0]
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8

# %%
# get the lat and long locations of the above set of Walmart's and create the graph of roads that connects them
# that is within 42KM  
gta_part_loc = gta_part[['latitude', 'longitude']]

G = ox.graph_from_point(tuple(gta_part_loc.mean().to_list()), dist=42000, dist_type='network',
                        network_type='drive', clean_periphery=True, simplify=True, retain_all=True, truncate_by_edge=True)

# %%
# Map each walmart to the nearst road on the map and make sure that the distances (in meter) is small (e.g. less than 300m) 
# or otherwise re-evaluate the graph above with a bigger dist
gta_part['osmid'], gta_part['osmid_dist_m'] = zip(*gta_part.apply(lambda row: ox.nearest_nodes(G, row.longitude, row.latitude, return_dist=True), axis = 1))
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code  \
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8
#
#           osmid  osmid_dist_m
# 0     674536269    277.963737
# 1     701911552    246.673809
# 2   10291311614     98.517541
# 3     437952581    189.265679
# 4     699255429     95.426436
# 5    1543685682    119.115062
# 6    1768769491    243.984412
# 7    1360818945    155.728635
# 8     414466395     83.206854
# 9     414461288    133.692850
# 10    428087600    165.561053
# 11     35992100    111.385944
# 12    420576809     88.513525
# 13    253013816     44.449970
# 14     23828442    103.976358
# 15    391917373    155.188839
# 16    391909065     82.203538
# 17   4597575290    135.341559

# %%
# Visualize the Walmart superstores locations on the map
m = folium.Map(location=gta_part_loc.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=False)
for store_ind in range(wal_gta_count):
    folium.Marker(gta_part_loc.values.tolist()[store_ind],  popup=gta_part['store_number'][store_ind], icon=folium.Icon(color='blue', icon="fa-shopping-cart", prefix='fa'),).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16df8cbcc94b451a9b1399dc24c7f07e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16df8cbcc94b451a9b1399dc24c7f07e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_16df8cbcc94b451a9b1399dc24c7f07e = L.map(
#                 &quot;map_16df8cbcc94b451a9b1399dc24c7f07e&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ea7af7476164fa5806df900f8315b1b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16df8cbcc94b451a9b1399dc24c7f07e);
#
#
#             var marker_b5a3a36b377c5b913142cbd349e20719 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_16df8cbcc94b451a9b1399dc24c7f07e);
#
#
#             var icon_33d0835b7f2bc36d220e862be8e11643 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b5a3a36b377c5b913142cbd349e20719.setIcon(icon_33d0835b7f2bc36d220e862be8e11643);
#
#
#         var popup_ca5c925e932cc981926cfd92fe9e7de4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73787dc133738998114412bad447aea5 = $(`&lt;div id=&quot;html_73787dc133738998114412bad447aea5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #3001&lt;/div&gt;`)[0];
#                 popup_ca5c925e932cc981926cfd92fe9e7de4.setContent(html_73787dc133738998114412bad447aea5);
#
#
#
#         marker_b5a3a36b377c5b913142cbd349e20719.bindPopup(popup_ca5c925e932cc981926cfd92fe9e7de4)
#         ;
#
#
#
#
#             var marker_a4d7ffa7370a92296fd2137e211dbd78 = L.marker(
#                 [44.01501, -79.411176],
#                 {}
#             ).addTo(map_16df8cbcc94b451a9b1399dc24c7f07e);
#
#
#             var icon_f654bd6cfeb0d786efdcb70a06729299 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a4d7ffa7370a92296fd2137e211dbd78.setIcon(icon_f654bd6cfeb0d786efdcb70a06729299);
#
#
#         var popup_9568dc735111610d137aa5817f062382 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c494c74615441a4264d1c1257362dfd4 = $(`&lt;div id=&quot;html_c494c74615441a4264d1c1257362dfd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #5778&lt;/div&gt;`)[0];
#                 popup_9568dc735111610d137aa5817f062382.setContent(html_c494c74615441a4264d1c1257362dfd4);
#
#
#
#         marker_a4d7ffa7370a92296fd2137e211dbd78.bindPopup(popup_9568dc735111610d137aa5817f062382)
#         ;
#
#
#
#
#             var marker_4523f370c0c849891b443da99f39dac2 = L.marker(
#                 [43.871301, -79.215267],
#                 {}
#             ).addTo(map_16df8cbcc94b451a9b1399dc24c7f07e);
#
#
#             var icon_d29e01686048d49beb03861c16edefbe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4523f370c0c849891b443da99f39dac2.setIcon(icon_d29e01686048d49beb03861c16edefbe);
#
#
#         var popup_0dbfaa2b8122995166ba84dcfcff18c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02b2a91a60e1cafc61bd92788fc36e02 = $(`&lt;div id=&quot;html_02b2a91a60e1cafc61bd92788fc36e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #1109&lt;/div&gt;`)[0];
#                 popup_0dbfaa2b8122995166ba84dcfcff18c6.setContent(html_02b2a91a60e1cafc61bd92788fc36e02);
#
#
#
#         marker_4523f370c0c849891b443da99f39dac2.bindPopup(popup_0dbfaa2b8122995166ba84dcfcff18c6)
#         ;
#
#
#
#
#             var marker_ec47ab285bf85100531c6ea6fd0f48dd = L.marker(
#                 [43.867108, -79.290345],
#                 {}
#             ).addTo(map_16df8cbcc94b451a9b1399dc24c7f07e);
#
#
#             var icon_91197b2e60d6ea16e13597d9aad7f9c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Finding the optimal route using Tabu Search

# %%
# helper function that takes a folium map and plot an antpath based on the route of the osmids 
def draw_route(G, route, m):
    ways_frame = ox.graph_to_gdfs(G)[1]    
    path = []
    for u, v in zip(route[0:], route[1:]):
        try:
            geo = (ways_frame.query(f'u == {u} and v == {v}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        except:
            geo = (ways_frame.query(f'u == {v} and v == {u}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        x, y = m_geo.coords.xy
        points = map(list, [*zip([*y],[*x])])
        path.extend([*points][:-1])

    folium.plugins.AntPath(
        locations = path,
        dash_array=[1, 10],
        delay=1000,
        color='red',
        pulse_color='black'
    ).add_to(m)

    return m

# %%
# A helper function that takes the graph and it creates a map and draw a path between all locations in it 
def draw_map_path(G, path, locations, routes):
    m = folium.Map(location=locations.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=True)

    route = []

    locationlist = locations.values.tolist()
    num_loc = len(locationlist)
    for i in range(num_loc):
        store_id = path[i]

        folium.Marker(location=locationlist[store_id], icon=folium.Icon(color='white', icon_color='white')).add_to(m)
        icon = folium.DivIcon(
            icon_size=(150,36),
            icon_anchor=(12,40),
            html="""<span class="fa-stack " style="font-size: 12pt" >
                    <span class="fa fa-circle-o fa-stack-2x" style="color : blue"></span>
                    <strong class="fa-stack-1x">
                         {:d}
                    </strong>
                </span>""".format(i)
        )
        folium.Marker(location=locationlist[store_id], icon=icon).add_to(m)
        
        if i == 0:
            store_id_1 = path[num_loc-1]
        else:
            store_id_1 = path[i-1]

        shortest_route = routes[store_id_1][store_id]
        
        if i == num_loc-1:
            route.extend(shortest_route)
        else:
            route.extend(shortest_route[:-1])

    draw_route(G, route, m=m)
        
    return m

# %%
# eval the distances between the walmart locations using the graph
gta_part_dists = np.zeros([wal_gta_count, wal_gta_count])
gta_part_pathes = [[[] for i in range(wal_gta_count)] for j in range(wal_gta_count)]
for i in range(wal_gta_count):
    for j in range(wal_gta_count):
        if i==j:
            continue
        gta_part_pathes[i][j] = nx.shortest_path(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length', method='dijkstra')
        gta_part_dists[i][j] = nx.shortest_path_length(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length', method='dijkstra')/1000

# %%
# create a TSP object for the problem
gta_part_tsp = TSP(dists=gta_part_dists, gen_method='mutate')

# %%
# create an TS object to help solving the tsp problem
ts = TabuSearch(max_iter=1000, tabu_tenure=5, neighbor_size=100, use_aspiration=True, aspiration_limit=2, use_longterm=False, debug=1)

# %%
# Get an initial random solution and check its length 
ts.init_ts(gta_part_tsp,'random')
print(ts.s_cur)

# Draw the path of the random initial solution
draw_map_path(G, ts.s_cur, gta_part_loc, gta_part_pathes)
# Out:
# Tabu search is initialized:
# current value = 717.6200139999999
# [0, 14, 16, 11, 17, 1, 3, 13, 8, 6, 9, 5, 12, 10, 15, 7, 4, 2, 0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_165f68a05db9fd672f58a8096522c4a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_165f68a05db9fd672f58a8096522c4a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_165f68a05db9fd672f58a8096522c4a6 = L.map(
#                 &quot;map_165f68a05db9fd672f58a8096522c4a6&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0795c0d06559fc0a9fc402a1cb998a85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var marker_7c8dd61daf0c7704fcf2e348a87f0b15 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var icon_b8ac932b4e3acd47faf54ec51c5e252c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c8dd61daf0c7704fcf2e348a87f0b15.setIcon(icon_b8ac932b4e3acd47faf54ec51c5e252c);
#
#
#             var marker_1e41cace3d799d5ff8ec9199d8da7765 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var div_icon_2fb4af3d0033c7f506318aa428f42b0a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_1e41cace3d799d5ff8ec9199d8da7765.setIcon(div_icon_2fb4af3d0033c7f506318aa428f42b0a);
#
#
#             var marker_ebf6d54e6451b44e251825d0cf944b80 = L.marker(
#                 [43.656318, -79.43493],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var icon_f60662d09e690242a738f623e12d8610 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ebf6d54e6451b44e251825d0cf944b80.setIcon(icon_f60662d09e690242a738f623e12d8610);
#
#
#             var marker_343a5ec327fe4c6b782a5101cf7132d8 = L.marker(
#                 [43.656318, -79.43493],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var div_icon_c5695f94a5fd21a4ea1fc7dd50d8e9fa = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_343a5ec327fe4c6b782a5101cf7132d8.setIcon(div_icon_c5695f94a5fd21a4ea1fc7dd50d8e9fa);
#
#
#             var marker_f01639f9eca6bfe3e3f9c4fbaad952a1 = L.marker(
#                 [43.84549, -79.555122],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);
#
#
#             var icon_11334fa1ab38e7618c08f6dc516e1f87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f01639f9eca6bfe3e3f9c4fbaad952a1.setIcon(icon_11334fa1ab38e7618c08f6dc516e1f87);
#
#
#             var marker_368b6f27d6f7023e627203acec206491 = L.marker(
#                 [43.84549, -79.555122],
#                 {}
#             ).addTo(map_165f68a05db9fd672f58a8096522c4a6);

# %%
# Run TS and eval the best solution distance
ts.run(gta_part_tsp, repetition=5)

print('Optimal solution: ')
print(ts.s_allbest)
print(ts.val_allbest)
# Draw the path of the best solution
draw_map_path(G, ts.s_allbest, gta_part_loc, gta_part_pathes)
# Out:
# Optimal solution:
# [0, 8, 11, 14, 12, 13, 15, 16, 4, 1, 9, 10, 3, 2, 17, 6, 5, 7, 0]
# 223.532649
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e284c3effbd8a0b9650d9b7a8c6d064 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e284c3effbd8a0b9650d9b7a8c6d064&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5e284c3effbd8a0b9650d9b7a8c6d064 = L.map(
#                 &quot;map_5e284c3effbd8a0b9650d9b7a8c6d064&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84eeea453c0e6c72aab15efe418deb4f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var marker_e1d7855835382da15cae3aafa83e5709 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var icon_d34fe8c8a4f5ee2c26dde91ae8510fb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1d7855835382da15cae3aafa83e5709.setIcon(icon_d34fe8c8a4f5ee2c26dde91ae8510fb3);
#
#
#             var marker_9e1fb91aa779444bc8d137d96812a8b8 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var div_icon_471548efc4e55f632cbfcdc59fc08539 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_9e1fb91aa779444bc8d137d96812a8b8.setIcon(div_icon_471548efc4e55f632cbfcdc59fc08539);
#
#
#             var marker_6ae2ee6ffeedf9781634bef508d7227c = L.marker(
#                 [43.843959, -79.068945],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var icon_494e6a0a8e3f4fc260f3e9c174ca30d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ae2ee6ffeedf9781634bef508d7227c.setIcon(icon_494e6a0a8e3f4fc260f3e9c174ca30d9);
#
#
#             var marker_ddab8652515bf718d15fc6315f2cab55 = L.marker(
#                 [43.843959, -79.068945],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var div_icon_cde54878ae65c5f538c6ab376ca6e616 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_ddab8652515bf718d15fc6315f2cab55.setIcon(div_icon_cde54878ae65c5f538c6ab376ca6e616);
#
#
#             var marker_60f26b927a15faa03d33e34f94a0e30b = L.marker(
#                 [43.669418, -79.339249],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
#
#
#             var icon_9480235f9547d7bbb11edf6c1addf571 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_60f26b927a15faa03d33e34f94a0e30b.setIcon(icon_9480235f9547d7bbb11edf6c1addf571);
#
#
#             var marker_65cf32306eb60fc5daa2fdc40733b350 = L.marker(
#                 [43.669418, -79.339249],
#                 {}
#             ).addTo(map_5e284c3effbd8a0b9650d9b7a8c6d064);
