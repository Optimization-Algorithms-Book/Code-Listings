# %%
import sys
# adding search_optimization_tools to the system path
sys.path.insert(0, '../')

# %%
import latexify
import sympy
from search_optimization_tools.algorithms.trajectory_based import SimulatedAnnealing
from search_optimization_tools.problems import ContinuousFunctionBase
import random
import math
import numpy as np

# %%
@latexify.with_latex
def simple_example(x):
    return (x-6)**2

simple_example_bounds = np.asarray([[0, 31]])
simple_example_obj = ContinuousFunctionBase(simple_example, simple_example_bounds)
simple_example
# Out:
# <latexify.core.with_latex.<locals>._LatexifiedFunction at 0x1449d852110>

# %%
sa = SimulatedAnnealing(simple_example_obj, max_iter=1000, max_iter_per_temp=100, initial_temp=1000, final_temp=0.0001, cooling_schedule='geometric', cooling_alpha=0.9)
sa.run()
sa.s_best, sa.val_best,sa.t,sa.iter
# Out:
# (array([5.99994732]), 2.7752771892134874e-09, 9.97938882337113e-05, 154)

# %%
sa.init_annealing()
print ("init_sol=%f, eval_sol=%f, cur_temp=%f, cur_iter=%f" %(sa.s_best, sa.val_best,sa.t,sa.iter))
for i in range(100):
    sa.annealing_step()
    sa.iter += 1
    sa.update_temperature()
    print ("cur_sol=%f, eval_sol=%f, cur_temp=%f, cur_iter=%f" %(sa.s_best, sa.val_best,sa.t,sa.iter))
# Out:
# init_sol=1.849508, eval_sol=17.226580, cur_temp=1000.000000, cur_iter=1.000000
# cur_sol=2.647711, eval_sol=11.237842, cur_temp=810.000000, cur_iter=2.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=729.000000, cur_iter=3.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=656.100000, cur_iter=4.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=590.490000, cur_iter=5.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=531.441000, cur_iter=6.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=478.296900, cur_iter=7.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=430.467210, cur_iter=8.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=387.420489, cur_iter=9.000000
# cur_sol=2.742929, eval_sol=10.608510, cur_temp=348.678440, cur_iter=10.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=313.810596, cur_iter=11.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=282.429536, cur_iter=12.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=254.186583, cur_iter=13.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=228.767925, cur_iter=14.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=205.891132, cur_iter=15.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=185.302019, cur_iter=16.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=166.771817, cur_iter=17.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=150.094635, cur_iter=18.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=135.085172, cur_iter=19.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=121.576655, cur_iter=20.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=109.418989, cur_iter=21.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=98.477090, cur_iter=22.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=88.629381, cur_iter=23.000000
# cur_sol=3.681375, eval_sol=5.376022, cur_temp=79.766443, cur_iter=24.000000
# cur_sol=4.299471, eval_sol=2.891798, cur_temp=71.789799, cur_iter=25.000000
# cur_sol=5.048983, eval_sol=0.904434, cur_temp=64.610819, cur_iter=26.000000
# cur_sol=5.424878, eval_sol=0.330765, cur_temp=58.149737, cur_iter=27.000000
# cur_sol=5.424878, eval_sol=0.330765, cur_temp=52.334763, cur_iter=28.000000
# cur_sol=5.424878, eval_sol=0.330765, cur_temp=47.101287, cur_iter=29.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=42.391158, cur_iter=30.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=38.152042, cur_iter=31.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=34.336838, cur_iter=32.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=30.903154, cur_iter=33.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=27.812839, cur_iter=34.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=25.031555, cur_iter=35.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=22.528400, cur_iter=36.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=20.275560, cur_iter=37.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=18.248004, cur_iter=38.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=16.423203, cur_iter=39.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=14.780883, cur_iter=40.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=13.302795, cur_iter=41.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=11.972515, cur_iter=42.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=10.775264, cur_iter=43.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=9.697737, cur_iter=44.000000
# cur_sol=5.933460, eval_sol=0.004428, cur_temp=8.727964, cur_iter=45.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=7.855167, cur_iter=46.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=7.069650, cur_iter=47.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=6.362685, cur_iter=48.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=5.726417, cur_iter=49.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=5.153775, cur_iter=50.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=4.638398, cur_iter=51.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=4.174558, cur_iter=52.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=3.757102, cur_iter=53.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=3.381392, cur_iter=54.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=3.043253, cur_iter=55.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=2.738927, cur_iter=56.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=2.465035, cur_iter=57.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=2.218531, cur_iter=58.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.996678, cur_iter=59.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.797010, cur_iter=60.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.617309, cur_iter=61.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.455578, cur_iter=62.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.310021, cur_iter=63.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.179018, cur_iter=64.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=1.061117, cur_iter=65.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.955005, cur_iter=66.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.859504, cur_iter=67.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.773554, cur_iter=68.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.696199, cur_iter=69.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.626579, cur_iter=70.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.563921, cur_iter=71.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.507529, cur_iter=72.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.456776, cur_iter=73.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.411098, cur_iter=74.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.369988, cur_iter=75.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.332990, cur_iter=76.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.299691, cur_iter=77.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.269722, cur_iter=78.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.242749, cur_iter=79.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.218475, cur_iter=80.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.196627, cur_iter=81.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.176964, cur_iter=82.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.159268, cur_iter=83.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.143341, cur_iter=84.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.129007, cur_iter=85.000000
# cur_sol=5.985243, eval_sol=0.000218, cur_temp=0.116106, cur_iter=86.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.104496, cur_iter=87.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.094046, cur_iter=88.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.084641, cur_iter=89.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.076177, cur_iter=90.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.068560, cur_iter=91.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.061704, cur_iter=92.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.055533, cur_iter=93.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.049980, cur_iter=94.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.044982, cur_iter=95.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.040484, cur_iter=96.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.036435, cur_iter=97.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.032792, cur_iter=98.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.029513, cur_iter=99.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.026561, cur_iter=100.000000
# cur_sol=5.995944, eval_sol=0.000016, cur_temp=0.023905, cur_iter=101.000000

# %%
simple_example_obj.plot(sa.s_best)
# Out:
# global minimum: x = 5.9959, f(x) = 0.0000
