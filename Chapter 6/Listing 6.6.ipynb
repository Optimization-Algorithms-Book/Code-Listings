# %%
import sys
# adding search_optimization_tools to the system path
sys.path.insert(0, '../')

# %%
from search_optimization_tools.algorithms.trajectory_based import SimulatedAnnealing
from search_optimization_tools.problems import TSP
import pandas as pd
import numpy as np
import osmnx as ox
import networkx as nx
import folium
import folium.plugins

# %%
# load list of all walmart locations on Ontario
wal_df = pd.read_csv("../search_optimization_tools/problems/samples/TSP/Walmart_ON.csv")

# %%
# city to region mapping from wikipedia
cityToRegion = {
    'Toronto': 'Toronto',
    'Ajax': 'Durham Region',
    'Clarington': 'Durham Region',
    'Brock': 'Durham Region',
    'Oshawa': 'Durham Region',
    'Pickering': 'Durham Region',
    'Scugog': 'Durham Region',
    'Uxbridge': 'Durham Region',
    'Whitby': 'Durham Region',
    'Burlington': 'Halton Region',
    'Halton Hills': 'Halton Region',
    'Milton': 'Halton Region',
    'Oakville': 'Halton Region',
    'Brampton': 'Peel Region',
    'Caledon': 'Peel Region',
    'Mississauga': 'Peel Region',
    'Aurora': 'York Region',
    'East Gwillimbury': 'York Region',
    'Georgina': 'York Region',
    'King': 'York Region',
    'Markham': 'York Region',
    'Newmarket': 'York Region',
    'Richmond Hill': 'York Region',
    'Vaughan': 'York Region',
    'Whitchurch-Stouffville': 'York Region',
    'Mono': 'Dufferin County',
    'Orangeville': 'Dufferin County',
    'Bradford West Gwillimbury': 'Simcoe County',
    'New Tecumseth': 'Simcoe County'
}

# %%
# selecting cities that are in Durham Region, York Region, or Toronto
cities_list = [city for city, region in cityToRegion.items() if city in wal_df.city.unique() and region in ['Durham Region', 'York Region', 'Toronto']]
print(cities_list)
# Out:
# ['Toronto', 'Ajax', 'Oshawa', 'Pickering', 'Uxbridge', 'Whitby', 'Aurora', 'Markham', 'Newmarket', 'Richmond Hill', 'Vaughan']

# %%
# select walmarts thar are in the above list and is Supercentre
gta_part = wal_df[wal_df.store_number.str.startswith('Walmart Supercentre') & wal_df.city.isin(cities_list)].reset_index(drop=True)
wal_gta_count = gta_part.shape[0]
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8

# %%
# get the lat and long locations of the above set of Walmart's and create the graph of roads that connects them
# that is within 42KM  
gta_part_loc = gta_part[['latitude', 'longitude']]

G = ox.graph_from_point(tuple(gta_part_loc.mean().to_list()), dist=42000, dist_type='network',
                        network_type='drive', clean_periphery=True, simplify=True, retain_all=True, truncate_by_edge=True)

# %%
# map each walmart to the nearst road on the map and make sure that the distances (in meter) is small (e.g. less than 300m) 
# or otherwise re-evaluate the graph above with a bigger dist
gta_part['osmid'], gta_part['osmid_dist_m'] = zip(*gta_part.apply(lambda row: ox.nearest_nodes(G, row.longitude, row.latitude, return_dist=True), axis = 1))
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code       osmid  \
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7   674536269
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2   701911552
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1  4561502734
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9   437952581
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4   699255429
# 5              1300 King St E         Oshawa       ON     L1H 8J4  1543685682
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5  1768769491
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5  1360818945
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7   414466395
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3   414461288
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5   428087600
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6    35992100
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5   420576809
# 13              3757 Keele St        Toronto       ON     M3J 1N4   253013816
# 14            900 Dufferin St        Toronto       ON     M6H 4A9    23828442
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4   391917373
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1   391909065
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8  4597575290
#
#     osmid_dist_m
# 0     277.963737
# 1     246.673809
# 2     253.726480
# 3     189.265679
# 4      95.426436
# 5     119.115062
# 6     243.984412
# 7     155.728635
# 8      83.206854
# 9     133.692850
# 10    165.561053
# 11    111.385944
# 12     88.513525
# 13     44.449970
# 14    103.976358
# 15    155.188839
# 16     82.203538
# 17    135.341559

# %%
# visualize the walmart locations on the map
m = folium.Map(location=gta_part_loc.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=False)
for store_ind in range(wal_gta_count):
    folium.Marker(gta_part_loc.values.tolist()[store_ind],  popup=gta_part['store_number'][store_ind], icon=folium.Icon(color='blue', icon="fa-shopping-cart", prefix='fa'),).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fc83e3cb96d3d8c7ee7153a5c017332 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fc83e3cb96d3d8c7ee7153a5c017332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1fc83e3cb96d3d8c7ee7153a5c017332 = L.map(
#                 &quot;map_1fc83e3cb96d3d8c7ee7153a5c017332&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_936ead15ec8841739f609cc68cf03069 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fc83e3cb96d3d8c7ee7153a5c017332);
#
#
#             var marker_1c9f00fe9ce8010e119dd7831ee4a6de = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_1fc83e3cb96d3d8c7ee7153a5c017332);
#
#
#             var icon_4c815d253558f7dcf191c10f467e4460 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1c9f00fe9ce8010e119dd7831ee4a6de.setIcon(icon_4c815d253558f7dcf191c10f467e4460);
#
#
#         var popup_8100c14ffff988be792fe0131a41d458 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43397f095a3342fe77bc00bc3ca86543 = $(`&lt;div id=&quot;html_43397f095a3342fe77bc00bc3ca86543&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #3001&lt;/div&gt;`)[0];
#                 popup_8100c14ffff988be792fe0131a41d458.setContent(html_43397f095a3342fe77bc00bc3ca86543);
#
#
#
#         marker_1c9f00fe9ce8010e119dd7831ee4a6de.bindPopup(popup_8100c14ffff988be792fe0131a41d458)
#         ;
#
#
#
#
#             var marker_32e8f39d0d23c3739aecaacd3b3d195d = L.marker(
#                 [44.01501, -79.411176],
#                 {}
#             ).addTo(map_1fc83e3cb96d3d8c7ee7153a5c017332);
#
#
#             var icon_0606f66d0bee161b68e9cb45c1d256ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_32e8f39d0d23c3739aecaacd3b3d195d.setIcon(icon_0606f66d0bee161b68e9cb45c1d256ec);
#
#
#         var popup_5ffbabbcf3821f4ae102959168151492 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a030d3c76ce7794356b234cf4198c9e = $(`&lt;div id=&quot;html_4a030d3c76ce7794356b234cf4198c9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #5778&lt;/div&gt;`)[0];
#                 popup_5ffbabbcf3821f4ae102959168151492.setContent(html_4a030d3c76ce7794356b234cf4198c9e);
#
#
#
#         marker_32e8f39d0d23c3739aecaacd3b3d195d.bindPopup(popup_5ffbabbcf3821f4ae102959168151492)
#         ;
#
#
#
#
#             var marker_f60eb908f87211e9239ff66c4248c6dd = L.marker(
#                 [43.871301, -79.215267],
#                 {}
#             ).addTo(map_1fc83e3cb96d3d8c7ee7153a5c017332);
#
#
#             var icon_76c82461cb6bb8eb9d26ee2f643ede6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f60eb908f87211e9239ff66c4248c6dd.setIcon(icon_76c82461cb6bb8eb9d26ee2f643ede6c);
#
#
#         var popup_45d8023a06f419589a73cc28d066cd6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cd6a755f60ac4d42698d298d62dcfd3 = $(`&lt;div id=&quot;html_1cd6a755f60ac4d42698d298d62dcfd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #1109&lt;/div&gt;`)[0];
#                 popup_45d8023a06f419589a73cc28d066cd6b.setContent(html_1cd6a755f60ac4d42698d298d62dcfd3);
#
#
#
#         marker_f60eb908f87211e9239ff66c4248c6dd.bindPopup(popup_45d8023a06f419589a73cc28d066cd6b)
#         ;
#
#
#
#
#             var marker_057bd4545e9b8b837cbfc15468934222 = L.marker(
#                 [43.867108, -79.290345],
#                 {}
#             ).addTo(map_1fc83e3cb96d3d8c7ee7153a5c017332);
#
#
#             var icon_49950b7eaed2646201e1bd465c436008 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
# helper function that takes a folium map and plot an antpath based on the route of the osmids 
def draw_route(G, route, m):
    ways_frame = ox.graph_to_gdfs(G)[1]    
    path = []
    for u, v in zip(route[0:], route[1:]):
        try:
            geo = (ways_frame.query(f'u == {u} and v == {v}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        except:
            geo = (ways_frame.query(f'u == {v} and v == {u}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        x, y = m_geo.coords.xy
        points = map(list, [*zip([*y],[*x])])
        path.extend([*points][:-1])

    folium.plugins.AntPath(
        locations = path,
        dash_array=[1, 10],
        delay=1000,
        color='red',
        pulse_color='black'
    ).add_to(m)

    return m

# %%
# A helper function that takes the graph and it creates a map and draw a path between all locations in it 
def draw_map_path(G, path, locations, routes):
    m = folium.Map(location=locations.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=True)

    route = []

    locationlist = locations.values.tolist()
    num_loc = len(locationlist)
    for i in range(num_loc):
        store_id = path[i]

        folium.Marker(location=locationlist[store_id], icon=folium.Icon(color='white', icon_color='white')).add_to(m)
        icon = folium.DivIcon(
            icon_size=(150,36),
            icon_anchor=(12,40),
            html="""<span class="fa-stack " style="font-size: 12pt" >
                    <span class="fa fa-circle-o fa-stack-2x" style="color : blue"></span>
                    <strong class="fa-stack-1x">
                         {:d}
                    </strong>
                </span>""".format(i)
        )
        folium.Marker(location=locationlist[store_id], icon=icon).add_to(m)
        
        if i == 0:
            store_id_1 = path[num_loc-1]
        else:
            store_id_1 = path[i-1]

        shortest_route = routes[store_id_1][store_id]
        
        if i == num_loc-1:
            route.extend(shortest_route)
        else:
            route.extend(shortest_route[:-1])

    draw_route(G, route, m=m)
        
    return m

# %%
# eval the distances between the walmart locations using the graph
gta_part_dists = np.zeros([wal_gta_count, wal_gta_count])
gta_part_pathes = [[[] for i in range(wal_gta_count)] for j in range(wal_gta_count)]
for i in range(wal_gta_count):
    for j in range(wal_gta_count):
        if i==j:
            continue
        gta_part_pathes[i][j] = nx.shortest_path(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length')
        gta_part_dists[i][j] = nx.shortest_path_length(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length')/1000

# %%
# create a TSP object for the problem
gta_part_tsp = TSP(gta_part_dists, 'random_swap', num_swaps=1)

# %%
# create an SA object to help solving the tsp problem
sa = SimulatedAnnealing(max_iter=10000, max_iter_per_temp=10000, initial_temp=10000000, final_temp=0.000001, cooling_schedule='geometric', cooling_alpha=0.9)

# %%
# Get an initial random solution and check its length 
sa.init_annealing(gta_part_tsp)
sa.val_best
# Out:
# 663.0282360000001

# %%
# assuming store with index #7 has a warehouse and the tour will start and end with it.
ind = sa.s_best.index(7)
r =  sa.s_best[ind:] + sa.s_best[:ind]

# %%
# Draw the path of the random initial solution
draw_map_path(G, r, gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11fa101b61ec01f935d02d7fefd58b56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11fa101b61ec01f935d02d7fefd58b56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_11fa101b61ec01f935d02d7fefd58b56 = L.map(
#                 &quot;map_11fa101b61ec01f935d02d7fefd58b56&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2318b0b8f3c174d7a01bdca16e469db9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var marker_6adf8cc1860f4e97c32314ea21304aff = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var icon_456130dbcbf26a1536abe70c50c77a6e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6adf8cc1860f4e97c32314ea21304aff.setIcon(icon_456130dbcbf26a1536abe70c50c77a6e);
#
#
#             var marker_e9c55f9c798ced740dcbe249c28f3b9c = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var div_icon_e257bb678fc5c216afc12b9993358696 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_e9c55f9c798ced740dcbe249c28f3b9c.setIcon(div_icon_e257bb678fc5c216afc12b9993358696);
#
#
#             var marker_2532ff84fa7cde6806aab2403449526b = L.marker(
#                 [43.91737, -78.95973],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var icon_8f482d8a54d0fc21d5b84920fb23f8a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2532ff84fa7cde6806aab2403449526b.setIcon(icon_8f482d8a54d0fc21d5b84920fb23f8a9);
#
#
#             var marker_534121c3c5c2c61ce16518f6b6157d92 = L.marker(
#                 [43.91737, -78.95973],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var div_icon_2fd15c8ffe72673dcd4ca0c10818760a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_534121c3c5c2c61ce16518f6b6157d92.setIcon(div_icon_2fd15c8ffe72673dcd4ca0c10818760a);
#
#
#             var marker_d8993253ed069d9ba8ce57aaca2f6e0f = L.marker(
#                 [43.656318, -79.43493],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);
#
#
#             var icon_a99a1625ba44b768e2d3baa60a7bdfda = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d8993253ed069d9ba8ce57aaca2f6e0f.setIcon(icon_a99a1625ba44b768e2d3baa60a7bdfda);
#
#
#             var marker_b5a1fe7541616332a8401e3714a8f326 = L.marker(
#                 [43.656318, -79.43493],
#                 {}
#             ).addTo(map_11fa101b61ec01f935d02d7fefd58b56);

# %%
# Run SA and eval the best solution distance
sa.run(gta_part_tsp)
sa.val_best
# Out:
# 304.98237300000005

# %%
ind = sa.s_best.index(7)
r =  sa.s_best[ind:] + sa.s_best[:ind]

# %%
# draw the sub-optimal path
draw_map_path(G, r, gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_684fd42e054822a1910bcb8ad7a07584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_684fd42e054822a1910bcb8ad7a07584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_684fd42e054822a1910bcb8ad7a07584 = L.map(
#                 &quot;map_684fd42e054822a1910bcb8ad7a07584&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b93545794e50176abb2911b00cbf2f9c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var marker_968b4ed283c6f1f272f3c47e1cd94c30 = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var icon_17c4f5178eb10f8d4dbba46ff873b4fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_968b4ed283c6f1f272f3c47e1cd94c30.setIcon(icon_17c4f5178eb10f8d4dbba46ff873b4fe);
#
#
#             var marker_805c3fca1000caed026a12532e8330e0 = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var div_icon_70c057b11d7e95e30d847778636fee6d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_805c3fca1000caed026a12532e8330e0.setIcon(div_icon_70c057b11d7e95e30d847778636fee6d);
#
#
#             var marker_f0fba6f75985e44ed7bc46b356250441 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var icon_d12d2ab9c7a405bcd552f551f6a480cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f0fba6f75985e44ed7bc46b356250441.setIcon(icon_d12d2ab9c7a405bcd552f551f6a480cb);
#
#
#             var marker_62b74c8f454ddd7dda5563ec9794b962 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var div_icon_1baee1cbc6434c78ee4d7f8c729774d4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_62b74c8f454ddd7dda5563ec9794b962.setIcon(div_icon_1baee1cbc6434c78ee4d7f8c729774d4);
#
#
#             var marker_25f5508d855a2bc2088abe95ab43d4fe = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);
#
#
#             var icon_e965e8180233adb2d9281ccd6574e668 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25f5508d855a2bc2088abe95ab43d4fe.setIcon(icon_e965e8180233adb2d9281ccd6574e668);
#
#
#             var marker_bf20faa8a167b89ca6af8a32ef6f3808 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_684fd42e054822a1910bcb8ad7a07584);

# %%
b=[12,13, 15, 16, 10, 9, 1, 4, 6, 5, 7, 17, 0, 8, 2, 3, 11, 14]
ind = b.index(7)
r =  b[ind:] + b[:ind]

# %%
# draw the sub-optimal path
draw_map_path(G, r, gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdf3a3822736bcc025a0bcb9462d1359 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdf3a3822736bcc025a0bcb9462d1359&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cdf3a3822736bcc025a0bcb9462d1359 = L.map(
#                 &quot;map_cdf3a3822736bcc025a0bcb9462d1359&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_918871587a80e6e3c2ceb5203f2c73ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var marker_78c5789b58a151e9a4167a6ea1fa81ce = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var icon_400e384acddce5cfe697b473cc767e9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_78c5789b58a151e9a4167a6ea1fa81ce.setIcon(icon_400e384acddce5cfe697b473cc767e9f);
#
#
#             var marker_9146329d43b8bc31f01f8a9ea9419aef = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var div_icon_0272bdf7544d8a1fbf5000c673388df0 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_9146329d43b8bc31f01f8a9ea9419aef.setIcon(div_icon_0272bdf7544d8a1fbf5000c673388df0);
#
#
#             var marker_d9ba40458c551bcb7bae368e1c0a0161 = L.marker(
#                 [43.91737, -78.95973],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var icon_a4c7ed26ab7c7bb64c15fe81c94f10d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9ba40458c551bcb7bae368e1c0a0161.setIcon(icon_a4c7ed26ab7c7bb64c15fe81c94f10d5);
#
#
#             var marker_80b206c90c9ba29c7c6fc9cc8d3aae71 = L.marker(
#                 [43.91737, -78.95973],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var div_icon_453c8f5309e3be153c1724e381c9cd5b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_80b206c90c9ba29c7c6fc9cc8d3aae71.setIcon(div_icon_453c8f5309e3be153c1724e381c9cd5b);
#
#
#             var marker_059b4d34e1179dd82479532c2b0611b8 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);
#
#
#             var icon_bb453a2c63aa9c5663009209dffa9062 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_059b4d34e1179dd82479532c2b0611b8.setIcon(icon_bb453a2c63aa9c5663009209dffa9062);
#
#
#             var marker_2425ec280904fdaf8893b0ba91047136 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_cdf3a3822736bcc025a0bcb9462d1359);

# %%
gta_part_tsp.eval_solution(b)
# Out:
# 251.80100099999996
