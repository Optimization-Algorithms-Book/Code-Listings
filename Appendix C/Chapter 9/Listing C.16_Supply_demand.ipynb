# %% [markdown]
# ## Solving transportation problem using bio-inspired algorithms

# %% [markdown]
# In neighborhood $Y$ of city $X$, there are 8 schools that collectively possess 100 microscopes for use in biology classes. These resources, however, are not uniformly distributed amongst the schools. With recent changes in student enrollment, 4 schools have more microscopes than needed while the other 4 schools are in need of additional ones. To address this issue, Dr. Rachel Carson, who is in charge of the biology department at City $X$'s School Board, decides to use a mathematical model. She chooses to use the Transportation Problem model, a strategy aimed at efficiently allocating resources while minimizing transportation costs [1]. The model represents supply $n$ and demand $m$ as unit weights of decision variables at various points in a network, with the cost of transporting a unit from a supply point to a demand point equivalent to the time or distance between nodes. This data is captured in an $n \times m$ cost matrix.
#
# The formal statement of this integer linear programming problem is as follows [2]:
#
# Minimize $\sum_{i \in I}\sum_{j \in J} c_{ij}x_{ij}$
#
# Subject to the following constaints
#
# $\sum_{j \in J} x_{ij}\leq S_i  \quad \quad \forall i \in I$
#
# $\sum_{i \in I} x_{ij}\geq D_j  \quad \quad \forall j \in J$
#
# $x_{ij}\geq 0 \quad \quad \forall i \in I \quad \quad \forall j \in J$
#
# where
# * $i$ is each potential origin node
# * $I$ is the complete set of potential origin nodes
# * $j$ is each potenial destination node
# * $J$ is the complete set of potential nodes
# * $x_{ij}$ is the amount to be shipped from $i \in I$ to $j \in J$
# * $c_{ij}$ is per unit shipping costs between all $i, j$ pairs
# * $S_i$ is node i supply for $i \in I$
# * $D_j$ is node i demand for $j \in J$
#
# <b> References</b>
#
# [1] Lovelace, R. Open source tools for geographic analysis in transport planning. Journal of Geographical Systems (2021).
#
# [2] Daskin, M. (2013) Network and Discrete Location: Models, Algorithms, and Applications. New York: John Wiley & Sons, Inc.

# %% [markdown]
# ### Import used libraries

# %%
from pymoo.algorithms.soo.nonconvex.pso import PSO
from pymoo.optimize import minimize
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.operators.crossover.pntx import PointCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.core.problem import Problem
import numpy as np
import matplotlib.pyplot as plt
import math
from math import exp

# %% [markdown]
# ## Define the transportation problem data

# %%
supply_schools = [1, 6, 7, 8]
demand_schools = [2, 3, 4, 5]
amount_supply = [20, 30, 15, 35]
amount_demand = [5, 45, 10, 40]

# %% [markdown]
# ### Visualize the problem data

# %%
import random
from geopy.geocoders import Nominatim
import folium

geolocator = Nominatim(user_agent="SupplyDemand")
location = geolocator.geocode("Toronto, Ontario")

# %%
def generate_random(number, center_point):
    lat, lon = center_point
    # Generate random locations around center_point
    coords = [(random.uniform(lat - 0.01, lat + 0.01), random.uniform(lon - 0.01, lon + 0.01)) for _ in range(number)]
    return coords

np.random.seed(0)  # for reproducibility
supply_coords = generate_random(len(supply_schools), [location.latitude, location.longitude])
demand_coords = generate_random(len(demand_schools), [location.latitude, location.longitude])

# %%
# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e794d7c13bd22a766ad23370d358c8d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e794d7c13bd22a766ad23370d358c8d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e794d7c13bd22a766ad23370d358c8d4 = L.map(
#                 &quot;map_e794d7c13bd22a766ad23370d358c8d4&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8645c6f8e5e3bcfe45598ef80d15716 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e794d7c13bd22a766ad23370d358c8d4);
#
#
#             var marker_31ca8ad3cf9147c8df55dc9c0b93e9f1 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_e794d7c13bd22a766ad23370d358c8d4);
#
#
#             var icon_259e507e154e7ffc48803350e6195155 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31ca8ad3cf9147c8df55dc9c0b93e9f1.setIcon(icon_259e507e154e7ffc48803350e6195155);
#
#
#         var popup_b11b0b40901475fe29a81d569bde2713 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96045c8c871c00e8986143dae740e559 = $(`&lt;div id=&quot;html_96045c8c871c00e8986143dae740e559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_b11b0b40901475fe29a81d569bde2713.setContent(html_96045c8c871c00e8986143dae740e559);
#
#
#
#         marker_31ca8ad3cf9147c8df55dc9c0b93e9f1.bindPopup(popup_b11b0b40901475fe29a81d569bde2713)
#         ;
#
#
#
#
#             var marker_9863b23f0c36b79fa091c98c552e0404 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_e794d7c13bd22a766ad23370d358c8d4);
#
#
#             var icon_3efe10f65fc7d77c545cf549f32e8e4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9863b23f0c36b79fa091c98c552e0404.setIcon(icon_3efe10f65fc7d77c545cf549f32e8e4a);
#
#
#         var popup_fb16c2fe2d9c4d318d0546b026085e25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a67fcc84aff31138ca6d0c19c29a8131 = $(`&lt;div id=&quot;html_a67fcc84aff31138ca6d0c19c29a8131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_fb16c2fe2d9c4d318d0546b026085e25.setContent(html_a67fcc84aff31138ca6d0c19c29a8131);
#
#
#
#         marker_9863b23f0c36b79fa091c98c552e0404.bindPopup(popup_fb16c2fe2d9c4d318d0546b026085e25)
#         ;
#
#
#
#
#             var marker_31f8e83eb733fcf929ce4e54853b42ba = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_e794d7c13bd22a766ad23370d358c8d4);
#
#
#             var icon_a68ad9b13bfcddee6c81fee8f4195fad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31f8e83eb733fcf929ce4e54853b42ba.setIcon(icon_a68ad9b13bfcddee6c81fee8f4195fad);
#
#
#         var popup_20741c0db51fa0b49d16d0de88663a36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d8e876dab2930412b87c071d53b174c = $(`&lt;div id=&quot;html_0d8e876dab2930412b87c071d53b174c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_20741c0db51fa0b49d16d0de88663a36.setContent(html_0d8e876dab2930412b87c071d53b174c);
#
#
#
#         marker_31f8e83eb733fcf929ce4e54853b42ba.bindPopup(popup_20741c0db51fa0b49d16d0de88663a36)
#         ;
#
#
#
#
#             var marker_4d112f113c950fda441cc4d37cbcf980 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_e794d7c13bd22a766ad23370d358c8d4);
#
#
#             var icon_eb2fab8f4eb3df5d652c7c17c1f86a77 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ### Define Cost matrix

# %%
from geopy.distance import geodesic

distances = []
for supply in supply_coords:
    row = []
    for demand in demand_coords:
        row.append(geodesic(supply, demand).kilometers)
    distances.append(row)

distances = np.array(distances)

cost_matrix=50*distances

# %% [markdown]
# ### Define the transportation problem

# %%
class Transportation_problem(Problem):
    def __init__(self,
                 cost_matrix, 
                 amount_supply,
                 amount_demand
                 ):
        super().__init__(n_var=16,n_constr=1, vtype=int)
        self.cost_matrix = cost_matrix
        self.amount_supply = amount_supply
        self.amount_demand = amount_demand
        self.xl = np.array(np.zeros(16))
        self.xu = np.repeat(amount_supply, len(amount_demand))

    def _evaluate(self, X, out, *args, **kwargs):
        loss = np.zeros((X.shape[0], 1))
        g = np.zeros((X.shape[0], 1))
        for i in range(len(X)):
            cost_x = X[i].reshape(self.cost_matrix.shape)
            cost = cost_x * cost_matrix.T
            cost = cost.sum()
            loss[i] = cost
            sup_limit = cost_x.sum(axis=1)
            demand_limit = cost_x.sum(axis=0)  
            g[i] =  np.any(sup_limit<self.amount_supply) or np.any(demand_limit<self.amount_demand)
        out["F"] = loss
        out["G"] = g
        

problem = Transportation_problem(cost_matrix,amount_supply,amount_demand)

# %% [markdown]
# ## Define PSO solver to solve the problem

# %%
algorithm = PSO(pop_size=100, 
                repair=RoundingRepair()
)

res = minimize(problem, algorithm, ('n_gen', 150), seed=1, verbose=False)

# %% [markdown]
# ### Print the soltuion

# %%
soln = res.X

# For each supply point
for i in range(len(amount_supply)):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*4, (i+1)*4)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*4:(i+1)*4]))} <= {amount_supply[i]} or {sum(soln[i*4:(i+1)*4])} <= {amount_supply[i]}")

# For each demand point
for j in range(len(amount_demand)):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*4+j)+']' for i in range(len(amount_demand))])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(len(amount_demand))]))} >= {sum(soln[i*4+j] for i in range(len(amount_demand)))} or {sum(soln[i*4+j] for i in range(len(amount_demand)))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 1 + 0 + 14 + 5 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 30 + 0 + 0 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 15 + 0 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 4 + 0 + 0 + 35 <= 35 or 39 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 1 + 0 + 0 + 4 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 0 + 30 + 15 + 0 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 14 + 0 + 0 + 0 >= 14 or 14 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 5 + 0 + 0 + 35 >= 40 or 40 >= 40
# Shipping cost =  3053.94 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e74476509efdbde6d5f2b0fdd5f91cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e74476509efdbde6d5f2b0fdd5f91cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2e74476509efdbde6d5f2b0fdd5f91cc = L.map(
#                 &quot;map_2e74476509efdbde6d5f2b0fdd5f91cc&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a39aef39d2fc65141aff62bd97f3c1d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e74476509efdbde6d5f2b0fdd5f91cc);
#
#
#             var marker_d569c1c3e8e679763e7c961159e6fcc6 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_2e74476509efdbde6d5f2b0fdd5f91cc);
#
#
#             var icon_0848f235eebe4eea00e57163473b6764 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d569c1c3e8e679763e7c961159e6fcc6.setIcon(icon_0848f235eebe4eea00e57163473b6764);
#
#
#         var popup_47cc81d38799e6fedd134f0c22254324 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea33e26bfd457bf3da6d1728db9be4e1 = $(`&lt;div id=&quot;html_ea33e26bfd457bf3da6d1728db9be4e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_47cc81d38799e6fedd134f0c22254324.setContent(html_ea33e26bfd457bf3da6d1728db9be4e1);
#
#
#
#         marker_d569c1c3e8e679763e7c961159e6fcc6.bindPopup(popup_47cc81d38799e6fedd134f0c22254324)
#         ;
#
#
#
#
#             var marker_d3a524077384b0c26cfde29cf88d7fb8 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_2e74476509efdbde6d5f2b0fdd5f91cc);
#
#
#             var icon_a05c7c04e6e12c9e25631ec395b7198f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d3a524077384b0c26cfde29cf88d7fb8.setIcon(icon_a05c7c04e6e12c9e25631ec395b7198f);
#
#
#         var popup_daa8fc4dad064c411ea5b6df9fc40608 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c0d408471624493273bfe5714295daf = $(`&lt;div id=&quot;html_6c0d408471624493273bfe5714295daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_daa8fc4dad064c411ea5b6df9fc40608.setContent(html_6c0d408471624493273bfe5714295daf);
#
#
#
#         marker_d3a524077384b0c26cfde29cf88d7fb8.bindPopup(popup_daa8fc4dad064c411ea5b6df9fc40608)
#         ;
#
#
#
#
#             var marker_f9b59a889ae53b594161e958cbdfbfe3 = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_2e74476509efdbde6d5f2b0fdd5f91cc);
#
#
#             var icon_e3c3c7a810c571a4b77254231fbd58d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f9b59a889ae53b594161e958cbdfbfe3.setIcon(icon_e3c3c7a810c571a4b77254231fbd58d3);
#
#
#         var popup_7ab105494f77673860123bd3877511cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e62c7cdb12ba9738882b86decb2dd042 = $(`&lt;div id=&quot;html_e62c7cdb12ba9738882b86decb2dd042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_7ab105494f77673860123bd3877511cb.setContent(html_e62c7cdb12ba9738882b86decb2dd042);
#
#
#
#         marker_f9b59a889ae53b594161e958cbdfbfe3.bindPopup(popup_7ab105494f77673860123bd3877511cb)
#         ;
#
#
#
#
#             var marker_2fc14fc186b2742f8cffe35dc8b3d55e = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_2e74476509efdbde6d5f2b0fdd5f91cc);
#
#
#             var icon_af1d272a98188684a2577a80e8a6bd27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Define GA solver to solve the problem

# %%
algorithm = GA(
    pop_size=50,
    sampling=FloatRandomSampling(),
    crossover=PointCrossover(prob=0.8, n_points=2),
    mutation = PolynomialMutation(prob=0.3, repair=RoundingRepair()),
    eliminate_duplicates=False
)

res = minimize(problem, algorithm, ('n_gen', 600), seed=1, verbose=False)

# %% [markdown]
# ### Print the solution

# %%
# Print the soltuion
soln = res.X

# For each supply point
for i in range(len(amount_supply)):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*4, (i+1)*4)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*4:(i+1)*4]))} <= {amount_supply[i]} or {sum(soln[i*4:(i+1)*4])} <= {amount_supply[i]}")

# For each demand point
for j in range(len(amount_demand)):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*4+j)+']' for i in range(len(amount_demand))])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(len(amount_demand))]))} >= {sum(soln[i*4+j] for i in range(len(amount_demand)))} or {sum(soln[i*4+j] for i in range(len(amount_demand)))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 3 + 3 + 2 + 12 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 5 + 6 + 19 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 14 + 1 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 2 + 23 + 1 + 9 <= 35 or 35 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 3 + 0 + 0 + 2 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 3 + 5 + 14 + 23 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 2 + 6 + 1 + 1 >= 10 or 10 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 12 + 19 + 0 + 9 >= 40 or 40 >= 40
# Shipping cost =  4392.97 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68ed5efb93cd3260208a7cfbba6f56ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68ed5efb93cd3260208a7cfbba6f56ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_68ed5efb93cd3260208a7cfbba6f56ec = L.map(
#                 &quot;map_68ed5efb93cd3260208a7cfbba6f56ec&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_624a94f235be741909ecd860e5306d21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_68ed5efb93cd3260208a7cfbba6f56ec);
#
#
#             var marker_0914fd189ac1425ab0e9559c5fa85b3e = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_68ed5efb93cd3260208a7cfbba6f56ec);
#
#
#             var icon_f55a5cba73a0540ba5fe014b10eb1620 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0914fd189ac1425ab0e9559c5fa85b3e.setIcon(icon_f55a5cba73a0540ba5fe014b10eb1620);
#
#
#         var popup_6d119d73f277d4ee08bdc2e70196fe3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e356b657b9b99b5e058b7b584c33524 = $(`&lt;div id=&quot;html_4e356b657b9b99b5e058b7b584c33524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_6d119d73f277d4ee08bdc2e70196fe3c.setContent(html_4e356b657b9b99b5e058b7b584c33524);
#
#
#
#         marker_0914fd189ac1425ab0e9559c5fa85b3e.bindPopup(popup_6d119d73f277d4ee08bdc2e70196fe3c)
#         ;
#
#
#
#
#             var marker_7179c61e9dbdc581034ffa2f277dd389 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_68ed5efb93cd3260208a7cfbba6f56ec);
#
#
#             var icon_4425dc988639e9ced7f415a2cc850180 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7179c61e9dbdc581034ffa2f277dd389.setIcon(icon_4425dc988639e9ced7f415a2cc850180);
#
#
#         var popup_a1259968fc986dee4325f91161264735 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef74eee248b8fe6b02b0ebe5040b99d1 = $(`&lt;div id=&quot;html_ef74eee248b8fe6b02b0ebe5040b99d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_a1259968fc986dee4325f91161264735.setContent(html_ef74eee248b8fe6b02b0ebe5040b99d1);
#
#
#
#         marker_7179c61e9dbdc581034ffa2f277dd389.bindPopup(popup_a1259968fc986dee4325f91161264735)
#         ;
#
#
#
#
#             var marker_68e93e106fb5b36ff5c7c810ef7ffe1a = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_68ed5efb93cd3260208a7cfbba6f56ec);
#
#
#             var icon_4fccf0c31aa6af639e9c05cf67d2e544 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68e93e106fb5b36ff5c7c810ef7ffe1a.setIcon(icon_4fccf0c31aa6af639e9c05cf67d2e544);
#
#
#         var popup_79ed1f3b54c54d276a25ed2b6fd25da4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b59f7f17029a86dcd544ead68a39a17 = $(`&lt;div id=&quot;html_1b59f7f17029a86dcd544ead68a39a17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_79ed1f3b54c54d276a25ed2b6fd25da4.setContent(html_1b59f7f17029a86dcd544ead68a39a17);
#
#
#
#         marker_68e93e106fb5b36ff5c7c810ef7ffe1a.bindPopup(popup_79ed1f3b54c54d276a25ed2b6fd25da4)
#         ;
#
#
#
#
#             var marker_7f0778ddcaa39ddad8874480b086f447 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_68ed5efb93cd3260208a7cfbba6f56ec);
#
#
#             var icon_ab29054b25341603152f6e022246f979 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;
