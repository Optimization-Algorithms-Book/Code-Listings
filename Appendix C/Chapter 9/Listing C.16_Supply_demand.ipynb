# %% [markdown]
# ## Solving supply-demand problem using bio-inspired algorithms

# %% [markdown]
# In neighborhood $Y$ of city $X$, there are 8 schools that collectively possess 100 microscopes for use in biology classes. These resources, however, are not uniformly distributed amongst the schools. With recent changes in student enrollment, 4 schools have more microscopes than needed while the other 4 schools are in need of additional ones. To address this issue, Dr. Rachel Carson, who is in charge of the biology department at City $X$'s School Board, decides to use a mathematical model. She chooses to use the Transportation Problem model, a strategy aimed at efficiently allocating resources while minimizing transportation costs [1]. The model represents supply $n$ and demand $m$ as unit weights of decision variables at various points in a network, with the cost of transporting a unit from a supply point to a demand point equivalent to the time or distance between nodes. This data is captured in an $n \times m$ cost matrix.
#
# The formal statement of this integer linear programming problem is as follows [2]:
#
# Minimize $\sum_{i \in I}\sum_{j \in J} c_{ij}x_{ij}$
#
# Subject to the following constraints:
#
# $\sum_{j \in J} x_{ij}\leq S_i  \quad \quad \forall i \in I$
#
# $\sum_{i \in I} x_{ij}\geq D_j  \quad \quad \forall j \in J$
#
# $x_{ij}\geq 0 \quad \quad \forall i \in I \quad \quad \forall j \in J$
#
# where
# * $i$ is each potential origin node
# * $I$ is the complete set of potential origin nodes
# * $j$ is each potential destination node
# * $J$ is the complete set of potential nodes
# * $x_{ij}$ is the amount to be shipped from $i \in I$ to $j \in J$
# * $c_{ij}$ is per unit shipping costs between all $i, j$ pairs. Assume that this cost is 50*distance between between $i$ and $j$.
# * $S_i$ is node i supply for $i \in I$
# * $D_j$ is node i demand for $j \in J$
#
# <b> References</b>
#
# [1] Lovelace, R. Open source tools for geographic analysis in transport planning. Journal of Geographical Systems (2021).
#
# [2] Daskin, M. (2013) Network and Discrete Location: Models, Algorithms, and Applications. New York: John Wiley & Sons, Inc.

# %% [markdown]
# ### Import used libraries

# %%
import numpy as np
import random
from pymoo.algorithms.soo.nonconvex.pso import PSO
from pymoo.optimize import minimize
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.operators.crossover.pntx import PointCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.core.problem import Problem
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import folium

# %% [markdown]
# ### Set the supply-demand problem data

# %%
supply_schools = [1, 6, 7, 8] # schools with microscopes available
demand_schools = [2, 3, 4, 5] # schools with microscopes requested
amount_supply = [20, 30, 15, 35] # number of microscopes available at each school
amount_demand = [5, 45, 10, 40] # number of microscopes requested at each school
n_var=len(supply_schools)*len(demand_schools) # number of variables

# %% [markdown]
# ### Visualize the problem data

# %%
geolocator = Nominatim(user_agent="SupplyDemand") # create geolocator object
location = geolocator.geocode("Toronto, Ontario") # get coordinates of Toronto

# %%
# Function to generate random locations around a center point
def generate_random(number, center_point):
    lat, lon = center_point
    coords = [(random.uniform(lat - 0.01, lat + 0.01), random.uniform(lon - 0.01, lon + 0.01)) for _ in range(number)]
    return coords

np.random.seed(0)  # for reproducibility
supply_coords = generate_random(len(supply_schools), [location.latitude, location.longitude])
demand_coords = generate_random(len(demand_schools), [location.latitude, location.longitude])

# %%
# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a47571baa9deda7f262c4461a0c5f4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a47571baa9deda7f262c4461a0c5f4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4a47571baa9deda7f262c4461a0c5f4b = L.map(
#                 &quot;map_4a47571baa9deda7f262c4461a0c5f4b&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a29e87f69f38be445d86a1ad983f093 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a47571baa9deda7f262c4461a0c5f4b);
#
#
#             var marker_3a85dad35650f576978b1b4f1f5ca85c = L.marker(
#                 [43.65694922389745, -79.38127959602173],
#                 {}
#             ).addTo(map_4a47571baa9deda7f262c4461a0c5f4b);
#
#
#             var icon_c8dba015dd48f263f7046c8627c145b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a85dad35650f576978b1b4f1f5ca85c.setIcon(icon_c8dba015dd48f263f7046c8627c145b5);
#
#
#         var popup_7adab0114f35b322f7f14e6cf1e4df5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53224bd66cabd78340cc69a444e41d10 = $(`&lt;div id=&quot;html_53224bd66cabd78340cc69a444e41d10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_7adab0114f35b322f7f14e6cf1e4df5a.setContent(html_53224bd66cabd78340cc69a444e41d10);
#
#
#
#         marker_3a85dad35650f576978b1b4f1f5ca85c.bindPopup(popup_7adab0114f35b322f7f14e6cf1e4df5a)
#         ;
#
#
#
#
#             var marker_254508df6b9cb040531c29eaf5cc3841 = L.marker(
#                 [43.646291144665355, -79.3774712432156],
#                 {}
#             ).addTo(map_4a47571baa9deda7f262c4461a0c5f4b);
#
#
#             var icon_a23a38a75eae089a0ebf2537bf3c2e6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_254508df6b9cb040531c29eaf5cc3841.setIcon(icon_a23a38a75eae089a0ebf2537bf3c2e6c);
#
#
#         var popup_ae94a6c2dd6851945b30bebdae13dffb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d0f25f89a1d51457b7042e6f4bdab73 = $(`&lt;div id=&quot;html_0d0f25f89a1d51457b7042e6f4bdab73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_ae94a6c2dd6851945b30bebdae13dffb.setContent(html_0d0f25f89a1d51457b7042e6f4bdab73);
#
#
#
#         marker_254508df6b9cb040531c29eaf5cc3841.bindPopup(popup_ae94a6c2dd6851945b30bebdae13dffb)
#         ;
#
#
#
#
#             var marker_463cc55d09227a8a5d22d6b74631accb = L.marker(
#                 [43.65344029881349, -79.37466071688105],
#                 {}
#             ).addTo(map_4a47571baa9deda7f262c4461a0c5f4b);
#
#
#             var icon_93785dcb05b0f7dada62bd067c1815bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_463cc55d09227a8a5d22d6b74631accb.setIcon(icon_93785dcb05b0f7dada62bd067c1815bc);
#
#
#         var popup_ea9bacb4f814a4771ea016c13e9344b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4b29bb4fc36e78964cb143b2266fea5 = $(`&lt;div id=&quot;html_a4b29bb4fc36e78964cb143b2266fea5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_ea9bacb4f814a4771ea016c13e9344b8.setContent(html_a4b29bb4fc36e78964cb143b2266fea5);
#
#
#
#         marker_463cc55d09227a8a5d22d6b74631accb.bindPopup(popup_ea9bacb4f814a4771ea016c13e9344b8)
#         ;
#
#
#
#
#             var marker_d397f06e9b432dca6343f1f6d9ebfcdc = L.marker(
#                 [43.66107991935101, -79.37404426921324],
#                 {}
#             ).addTo(map_4a47571baa9deda7f262c4461a0c5f4b);
#
#
#             var icon_cd5f70f2fcf085de0ad49641bed35752 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ### Define Cost matrix

# %%
distances = []
for supply in supply_coords:
    row = []
    for demand in demand_coords:
        row.append(geodesic(supply, demand).kilometers)
    distances.append(row)

distances = np.array(distances)

cost_matrix=50*distances

# %% [markdown]
# ### Define the transportation problem

# %%
class Transportation_problem(Problem):
    def __init__(self,
                 cost_matrix, 
                 amount_supply,
                 amount_demand
                 ):
        super().__init__(n_var=n_var,n_constr=1, vtype=int)
        self.cost_matrix = cost_matrix
        self.amount_supply = amount_supply
        self.amount_demand = amount_demand
        self.xl = np.array(np.zeros(n_var))
        self.xu = np.repeat(amount_supply, len(amount_demand))

    def _evaluate(self, X, out, *args, **kwargs):
        loss = np.zeros((X.shape[0], 1))
        g = np.zeros((X.shape[0], 1))
        for i in range(len(X)):
            soln = X[i].reshape(self.cost_matrix.shape)
            cost_x = X[i].reshape(self.cost_matrix.shape)
            cost = cost_x * cost_matrix.T
            cost = cost.sum()
            loss[i] = cost         
            total_supply = soln.sum(axis=1)
            total_demand = soln.sum(axis=0)  
            g[i] =  np.any(total_supply<self.amount_supply) or np.any(total_demand<self.amount_demand)
        out["F"] = loss
        out["G"] = g

# %%
problem = Transportation_problem(cost_matrix,amount_supply,amount_demand) # create problem object

# %% [markdown]
# ## Define PSO solver to solve the problem

# %%
algorithm = PSO(pop_size=100,repair=RoundingRepair()) # create the algorithm object
res = minimize(problem, algorithm, ('n_gen', 150), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the soltuion

# %%
soln = res.X # Get the solution

supply_num=len(amount_supply) # Number of supply points
demand_num=len(amount_demand) # Number of demand points

# For each supply point
for i in range(supply_num):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*supply_num, (i+1)*supply_num)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*supply_num:(i+1)*supply_num]))} <= {amount_supply[i]} or {sum(soln[i*supply_num:(i+1)*supply_num])} <= {amount_supply[i]}")

# For each demand point
for j in range(demand_num):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*demand_num+j)+']' for i in range(demand_num)])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(demand_num)]))} >= {sum(soln[i*demand_num+j] for i in range(demand_num))} or {sum(soln[i*demand_num+j] for i in range(demand_num))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 0 + 20 + 10 + 0 <= 20 or 30 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 0 + 0 + 30 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 7 + 0 + 0 + 8 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 8 + 25 + 0 + 2 <= 35 or 35 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 0 + 0 + 7 + 8 >= 15 or 15 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 20 + 0 + 0 + 25 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 10 + 0 + 0 + 0 >= 10 or 10 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 0 + 30 + 8 + 2 >= 40 or 40 >= 40
# Shipping cost =  4735.1 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87ff0c31c747573c9ecfe1506e87a15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87ff0c31c747573c9ecfe1506e87a15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_87ff0c31c747573c9ecfe1506e87a15a = L.map(
#                 &quot;map_87ff0c31c747573c9ecfe1506e87a15a&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_304d234d9520ed1306ae1dcb319ac908 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87ff0c31c747573c9ecfe1506e87a15a);
#
#
#             var marker_6b3d50fce6a2c31100a462229209e4f8 = L.marker(
#                 [43.65694922389745, -79.38127959602173],
#                 {}
#             ).addTo(map_87ff0c31c747573c9ecfe1506e87a15a);
#
#
#             var icon_1f04ac45a0f4de1af8ff549ad86e6444 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b3d50fce6a2c31100a462229209e4f8.setIcon(icon_1f04ac45a0f4de1af8ff549ad86e6444);
#
#
#         var popup_0f661f245fc5240e689b12edc72b9c73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2453fbf68ded7bd457b171af8f8b592d = $(`&lt;div id=&quot;html_2453fbf68ded7bd457b171af8f8b592d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_0f661f245fc5240e689b12edc72b9c73.setContent(html_2453fbf68ded7bd457b171af8f8b592d);
#
#
#
#         marker_6b3d50fce6a2c31100a462229209e4f8.bindPopup(popup_0f661f245fc5240e689b12edc72b9c73)
#         ;
#
#
#
#
#             var marker_b9116f5e34b0ba58d05b9920fdb36b60 = L.marker(
#                 [43.646291144665355, -79.3774712432156],
#                 {}
#             ).addTo(map_87ff0c31c747573c9ecfe1506e87a15a);
#
#
#             var icon_109cb9d4c2229187028c793deb0871af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b9116f5e34b0ba58d05b9920fdb36b60.setIcon(icon_109cb9d4c2229187028c793deb0871af);
#
#
#         var popup_4838907da3eae77ffd70130e921fb449 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ea7171140734239a43dfff2e5a6c6af = $(`&lt;div id=&quot;html_9ea7171140734239a43dfff2e5a6c6af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_4838907da3eae77ffd70130e921fb449.setContent(html_9ea7171140734239a43dfff2e5a6c6af);
#
#
#
#         marker_b9116f5e34b0ba58d05b9920fdb36b60.bindPopup(popup_4838907da3eae77ffd70130e921fb449)
#         ;
#
#
#
#
#             var marker_54bbbde86974785571bb8a3dff19a371 = L.marker(
#                 [43.65344029881349, -79.37466071688105],
#                 {}
#             ).addTo(map_87ff0c31c747573c9ecfe1506e87a15a);
#
#
#             var icon_8815a3ac69e43197c9179da4206025b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54bbbde86974785571bb8a3dff19a371.setIcon(icon_8815a3ac69e43197c9179da4206025b2);
#
#
#         var popup_c33bb1c0698ee8cba04216def4902971 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7740248c0ee7c5ce155e338b12695bc7 = $(`&lt;div id=&quot;html_7740248c0ee7c5ce155e338b12695bc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_c33bb1c0698ee8cba04216def4902971.setContent(html_7740248c0ee7c5ce155e338b12695bc7);
#
#
#
#         marker_54bbbde86974785571bb8a3dff19a371.bindPopup(popup_c33bb1c0698ee8cba04216def4902971)
#         ;
#
#
#
#
#             var marker_9658469503cbabd1df1dc5cc98d13890 = L.marker(
#                 [43.66107991935101, -79.37404426921324],
#                 {}
#             ).addTo(map_87ff0c31c747573c9ecfe1506e87a15a);
#
#
#             var icon_8b622307facb11143deb5ad4ca66b6cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Define GA solver to solve the problem

# %%
algorithm = GA(
    pop_size=50,
    sampling=FloatRandomSampling(),
    crossover=PointCrossover(prob=0.8, n_points=2),
    mutation = PolynomialMutation(prob=0.3, repair=RoundingRepair()),
    eliminate_duplicates=False
) # create the algorithm object

res = minimize(problem, algorithm, ('n_gen', 600), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the solution

# %%
soln = res.X # Get the solution

supply_num=len(amount_supply) # Number of supply points
demand_num=len(amount_demand) # Number of demand points

# For each supply point
for i in range(supply_num):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*supply_num, (i+1)*supply_num)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*supply_num:(i+1)*supply_num]))} <= {amount_supply[i]} or {sum(soln[i*supply_num:(i+1)*supply_num])} <= {amount_supply[i]}")

# For each demand point
for j in range(demand_num):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*demand_num+j)+']' for i in range(demand_num)])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(demand_num)]))} >= {sum(soln[i*demand_num+j] for i in range(demand_num))} or {sum(soln[i*demand_num+j] for i in range(demand_num))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 0 + 11 + 4 + 5 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 2 + 3 + 2 + 23 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 3 + 3 + 4 + 5 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 0 + 28 + 0 + 7 <= 35 or 35 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 0 + 2 + 3 + 0 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 11 + 3 + 3 + 28 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 4 + 2 + 4 + 0 >= 10 or 10 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 5 + 23 + 5 + 7 >= 40 or 40 >= 40
# Shipping cost =  5308.1 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0beecc62aeb2ebd4f3e9a12de931854e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0beecc62aeb2ebd4f3e9a12de931854e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0beecc62aeb2ebd4f3e9a12de931854e = L.map(
#                 &quot;map_0beecc62aeb2ebd4f3e9a12de931854e&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d6d0a90e418360ddd4355e0aae90c32 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0beecc62aeb2ebd4f3e9a12de931854e);
#
#
#             var marker_87bd653be7d660a49c9e9f726f37da97 = L.marker(
#                 [43.65694922389745, -79.38127959602173],
#                 {}
#             ).addTo(map_0beecc62aeb2ebd4f3e9a12de931854e);
#
#
#             var icon_b71e15746ad8598f15a7fe71c3091727 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_87bd653be7d660a49c9e9f726f37da97.setIcon(icon_b71e15746ad8598f15a7fe71c3091727);
#
#
#         var popup_bc88a81183091220887f38cfd77a1a09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_063f9b5ccf67dc1a43bba6b50b13a2ef = $(`&lt;div id=&quot;html_063f9b5ccf67dc1a43bba6b50b13a2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_bc88a81183091220887f38cfd77a1a09.setContent(html_063f9b5ccf67dc1a43bba6b50b13a2ef);
#
#
#
#         marker_87bd653be7d660a49c9e9f726f37da97.bindPopup(popup_bc88a81183091220887f38cfd77a1a09)
#         ;
#
#
#
#
#             var marker_0e6255956db936368c64f34b6495e8e4 = L.marker(
#                 [43.646291144665355, -79.3774712432156],
#                 {}
#             ).addTo(map_0beecc62aeb2ebd4f3e9a12de931854e);
#
#
#             var icon_87c76920bad1ab2592d6e5a43907c82e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e6255956db936368c64f34b6495e8e4.setIcon(icon_87c76920bad1ab2592d6e5a43907c82e);
#
#
#         var popup_14c4080536f47527d1f5a110299275f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9464738969d9d72571230ee8cb219705 = $(`&lt;div id=&quot;html_9464738969d9d72571230ee8cb219705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_14c4080536f47527d1f5a110299275f8.setContent(html_9464738969d9d72571230ee8cb219705);
#
#
#
#         marker_0e6255956db936368c64f34b6495e8e4.bindPopup(popup_14c4080536f47527d1f5a110299275f8)
#         ;
#
#
#
#
#             var marker_e1f0d80403306beb56e7843098eb9487 = L.marker(
#                 [43.65344029881349, -79.37466071688105],
#                 {}
#             ).addTo(map_0beecc62aeb2ebd4f3e9a12de931854e);
#
#
#             var icon_fa2a18a27939560ef607dbe82a548d9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1f0d80403306beb56e7843098eb9487.setIcon(icon_fa2a18a27939560ef607dbe82a548d9e);
#
#
#         var popup_2d7a8eb0a19f0bf11598dc7ca29dc453 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a27581b3eb5a1a4c17c0cd6132c4b80b = $(`&lt;div id=&quot;html_a27581b3eb5a1a4c17c0cd6132c4b80b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_2d7a8eb0a19f0bf11598dc7ca29dc453.setContent(html_a27581b3eb5a1a4c17c0cd6132c4b80b);
#
#
#
#         marker_e1f0d80403306beb56e7843098eb9487.bindPopup(popup_2d7a8eb0a19f0bf11598dc7ca29dc453)
#         ;
#
#
#
#
#             var marker_3e92180edca3c38dc5e9fbd0145bbcfb = L.marker(
#                 [43.66107991935101, -79.37404426921324],
#                 {}
#             ).addTo(map_0beecc62aeb2ebd4f3e9a12de931854e);
#
#
#             var icon_09d47ff5c6d16139fc4fafaf6cde1f9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;
