# %% [markdown]
# ## Solving supply-demand problem using bio-inspired algorithms

# %% [markdown]
# In neighborhood $Y$ of city $X$, there are 8 schools that collectively possess 100 microscopes for use in biology classes. These resources, however, are not uniformly distributed amongst the schools. With recent changes in student enrollment, 4 schools have more microscopes than needed while the other 4 schools are in need of additional ones. To address this issue, Dr. Rachel Carson, who is in charge of the biology department at City $X$'s School Board, decides to use a mathematical model. She chooses to use the Transportation Problem model, a strategy aimed at efficiently allocating resources while minimizing transportation costs [1]. The model represents supply $n$ and demand $m$ as unit weights of decision variables at various points in a network, with the cost of transporting a unit from a supply point to a demand point equivalent to the time or distance between nodes. This data is captured in an $n \times m$ cost matrix.
#
# The formal statement of this integer linear programming problem is as follows [2]:
#
# Minimize $\sum_{i \in I}\sum_{j \in J} c_{ij}x_{ij}$
#
# Subject to the following constraints:
#
# $\sum_{j \in J} x_{ij}\leq S_i  \quad \quad \forall i \in I$
#
# $\sum_{i \in I} x_{ij}\geq D_j  \quad \quad \forall j \in J$
#
# $x_{ij}\geq 0 \quad \quad \forall i \in I \quad \quad \forall j \in J$
#
# where
# * $i$ is each potential origin node
# * $I$ is the complete set of potential origin nodes
# * $j$ is each potential destination node
# * $J$ is the complete set of potential nodes
# * $x_{ij}$ is the amount to be shipped from $i \in I$ to $j \in J$
# * $c_{ij}$ is per unit shipping costs between all $i, j$ pairs. Assume that this cost is 50*distance between between $i$ and $j$.
# * $S_i$ is node i supply for $i \in I$
# * $D_j$ is node i demand for $j \in J$
#
# <b> References</b>
#
# [1] Lovelace, R. Open source tools for geographic analysis in transport planning. Journal of Geographical Systems (2021).
#
# [2] Daskin, M. (2013) Network and Discrete Location: Models, Algorithms, and Applications. New York: John Wiley & Sons, Inc.

# %% [markdown]
# ### Import used libraries

# %%
import numpy as np
import random
from pymoo.algorithms.soo.nonconvex.pso import PSO
from pymoo.optimize import minimize
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.operators.crossover.pntx import PointCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.core.problem import Problem
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import folium

# %% [markdown]
# ### Set the supply-demand problem data

# %%
supply_schools = [1, 6, 7, 8] # schools with microscopes available
demand_schools = [2, 3, 4, 5] # schools with microscopes requested
amount_supply = [20, 30, 15, 35] # number of microscopes available at each school
amount_demand = [5, 45, 10, 40] # number of microscopes requested at each school
n_var=len(supply_schools)*len(demand_schools) # number of variables

# %% [markdown]
# ### Visualize the problem data

# %%
geolocator = Nominatim(user_agent="SupplyDemand") # create geolocator object
location = geolocator.geocode("Toronto, Ontario") # get coordinates of Toronto

# %%
# Function to generate random locations around a center point
def generate_random(number, center_point):
    lat, lon = center_point
    coords = [(random.uniform(lat - 0.01, lat + 0.01), random.uniform(lon - 0.01, lon + 0.01)) for _ in range(number)]
    return coords

np.random.seed(0)  # for reproducibility
supply_coords = generate_random(len(supply_schools), [location.latitude, location.longitude])
demand_coords = generate_random(len(demand_schools), [location.latitude, location.longitude])

# %%
# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab2451a90999812a5758ec73035ff365 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab2451a90999812a5758ec73035ff365&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ab2451a90999812a5758ec73035ff365 = L.map(
#                 &quot;map_ab2451a90999812a5758ec73035ff365&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c2b05fe8e6e05d1f666368b0fe9ce2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab2451a90999812a5758ec73035ff365);
#
#
#             var marker_ef9e9cdcedcad3387a5f102a52abc20b = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_ab2451a90999812a5758ec73035ff365);
#
#
#             var icon_dc8173409f0c5645316934362e31cf77 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef9e9cdcedcad3387a5f102a52abc20b.setIcon(icon_dc8173409f0c5645316934362e31cf77);
#
#
#         var popup_78ca831a21454dc821f0adc0bf6e42d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2de957645b02277a592d65051017634 = $(`&lt;div id=&quot;html_a2de957645b02277a592d65051017634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_78ca831a21454dc821f0adc0bf6e42d2.setContent(html_a2de957645b02277a592d65051017634);
#
#
#
#         marker_ef9e9cdcedcad3387a5f102a52abc20b.bindPopup(popup_78ca831a21454dc821f0adc0bf6e42d2)
#         ;
#
#
#
#
#             var marker_705bf1a8ab3822cfce9642f76abec8ea = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_ab2451a90999812a5758ec73035ff365);
#
#
#             var icon_b78b6ee8a1b7160e4ab9077fdf8d593c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_705bf1a8ab3822cfce9642f76abec8ea.setIcon(icon_b78b6ee8a1b7160e4ab9077fdf8d593c);
#
#
#         var popup_8e047e2bd85f7d8fe962543bf9b2878d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_950f9f87d33f63dbfa9023ab74b078b1 = $(`&lt;div id=&quot;html_950f9f87d33f63dbfa9023ab74b078b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_8e047e2bd85f7d8fe962543bf9b2878d.setContent(html_950f9f87d33f63dbfa9023ab74b078b1);
#
#
#
#         marker_705bf1a8ab3822cfce9642f76abec8ea.bindPopup(popup_8e047e2bd85f7d8fe962543bf9b2878d)
#         ;
#
#
#
#
#             var marker_9c57d5682f1746f34f452ef58d15e29e = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_ab2451a90999812a5758ec73035ff365);
#
#
#             var icon_af17a1899b7a02155526cfb811b6bd4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c57d5682f1746f34f452ef58d15e29e.setIcon(icon_af17a1899b7a02155526cfb811b6bd4c);
#
#
#         var popup_9a2ef8e3ceef76621b0bb8a2fbb47c38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51228d9a510f436018d5ada84a4fc083 = $(`&lt;div id=&quot;html_51228d9a510f436018d5ada84a4fc083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_9a2ef8e3ceef76621b0bb8a2fbb47c38.setContent(html_51228d9a510f436018d5ada84a4fc083);
#
#
#
#         marker_9c57d5682f1746f34f452ef58d15e29e.bindPopup(popup_9a2ef8e3ceef76621b0bb8a2fbb47c38)
#         ;
#
#
#
#
#             var marker_d1514808672ceb58d9d6f971affb8b96 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_ab2451a90999812a5758ec73035ff365);
#
#
#             var icon_288935fbdc97fddd518402004d9fb6b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ### Define Cost matrix

# %%
distances = []
for supply in supply_coords:
    row = []
    for demand in demand_coords:
        row.append(geodesic(supply, demand).kilometers)
    distances.append(row)

distances = np.array(distances)

cost_matrix=50*distances

# %% [markdown]
# ### Define the transportation problem

# %%
class Transportation_problem(Problem):
    def __init__(self,
                 cost_matrix, 
                 amount_supply,
                 amount_demand
                 ):
        super().__init__(n_var=n_var,n_constr=1, vtype=int)
        self.cost_matrix = cost_matrix
        self.amount_supply = amount_supply
        self.amount_demand = amount_demand
        self.xl = np.array(np.zeros(n_var))
        self.xu = np.repeat(amount_supply, len(amount_demand))

    def _evaluate(self, X, out, *args, **kwargs):
        loss = np.zeros((X.shape[0], 1))
        g = np.zeros((X.shape[0], 1))
        for i in range(len(X)):
            soln = X[i].reshape(self.cost_matrix.shape)
            cost_x = X[i].reshape(self.cost_matrix.shape)
            cost = cost_x * cost_matrix.T
            cost = cost.sum()
            loss[i] = cost         
            total_supply = soln.sum(axis=1)
            total_demand = soln.sum(axis=0)  
            g[i] =  np.any(total_supply<self.amount_supply) or np.any(total_demand<self.amount_demand)
        out["F"] = loss
        out["G"] = g

# %%
problem = Transportation_problem(cost_matrix,amount_supply,amount_demand) # create problem object

# %% [markdown]
# ## Define PSO solver to solve the problem

# %%
algorithm = PSO(pop_size=100,repair=RoundingRepair()) # create the algorithm object
res = minimize(problem, algorithm, ('n_gen', 150), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the soltuion

# %%
soln = res.X

# For each supply point
for i in range(len(amount_supply)):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*4, (i+1)*4)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*4:(i+1)*4]))} <= {amount_supply[i]} or {sum(soln[i*4:(i+1)*4])} <= {amount_supply[i]}")

# For each demand point
for j in range(len(amount_demand)):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*4+j)+']' for i in range(len(amount_demand))])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(len(amount_demand))]))} >= {sum(soln[i*4+j] for i in range(len(amount_demand)))} or {sum(soln[i*4+j] for i in range(len(amount_demand)))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 1 + 0 + 14 + 5 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 30 + 0 + 0 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 15 + 0 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 4 + 0 + 0 + 35 <= 35 or 39 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 1 + 0 + 0 + 4 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 0 + 30 + 15 + 0 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 14 + 0 + 0 + 0 >= 14 or 14 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 5 + 0 + 0 + 35 >= 40 or 40 >= 40
# Shipping cost =  3053.94 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6249a28df9fa73c3fc0b589cdcc9f8d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6249a28df9fa73c3fc0b589cdcc9f8d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6249a28df9fa73c3fc0b589cdcc9f8d3 = L.map(
#                 &quot;map_6249a28df9fa73c3fc0b589cdcc9f8d3&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d1eec779d796f3647752ad68adc7da0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6249a28df9fa73c3fc0b589cdcc9f8d3);
#
#
#             var marker_213223660cda8e9f9966599701587437 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_6249a28df9fa73c3fc0b589cdcc9f8d3);
#
#
#             var icon_259629cbdec10e0cab1fece8a5be9e60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_213223660cda8e9f9966599701587437.setIcon(icon_259629cbdec10e0cab1fece8a5be9e60);
#
#
#         var popup_5c56ea24a0ae7cb4d1ddb3f436d74d1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d89f8f2f421ca06010913e5d0b69525 = $(`&lt;div id=&quot;html_6d89f8f2f421ca06010913e5d0b69525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_5c56ea24a0ae7cb4d1ddb3f436d74d1e.setContent(html_6d89f8f2f421ca06010913e5d0b69525);
#
#
#
#         marker_213223660cda8e9f9966599701587437.bindPopup(popup_5c56ea24a0ae7cb4d1ddb3f436d74d1e)
#         ;
#
#
#
#
#             var marker_13a0779152e604b4b0f3cd13e74a3652 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_6249a28df9fa73c3fc0b589cdcc9f8d3);
#
#
#             var icon_c028a712bffdb49502cdcaffbbb20f0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13a0779152e604b4b0f3cd13e74a3652.setIcon(icon_c028a712bffdb49502cdcaffbbb20f0b);
#
#
#         var popup_2bfbb268348a1980d5d4eae9f617e3e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_066ed39892dd5415232fdcd07aca9e29 = $(`&lt;div id=&quot;html_066ed39892dd5415232fdcd07aca9e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_2bfbb268348a1980d5d4eae9f617e3e5.setContent(html_066ed39892dd5415232fdcd07aca9e29);
#
#
#
#         marker_13a0779152e604b4b0f3cd13e74a3652.bindPopup(popup_2bfbb268348a1980d5d4eae9f617e3e5)
#         ;
#
#
#
#
#             var marker_b32f2a3b404b3adf0bbeccbd6329167f = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_6249a28df9fa73c3fc0b589cdcc9f8d3);
#
#
#             var icon_f1dc644bc2da70bf3cdaad07ddd19347 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b32f2a3b404b3adf0bbeccbd6329167f.setIcon(icon_f1dc644bc2da70bf3cdaad07ddd19347);
#
#
#         var popup_d65707199884d477d28caad1fa950d19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f49ac938b211b780ac76b33d376c4a86 = $(`&lt;div id=&quot;html_f49ac938b211b780ac76b33d376c4a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_d65707199884d477d28caad1fa950d19.setContent(html_f49ac938b211b780ac76b33d376c4a86);
#
#
#
#         marker_b32f2a3b404b3adf0bbeccbd6329167f.bindPopup(popup_d65707199884d477d28caad1fa950d19)
#         ;
#
#
#
#
#             var marker_5cd6d9b4074cf9d6412d3313de22a62b = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_6249a28df9fa73c3fc0b589cdcc9f8d3);
#
#
#             var icon_0c4d95fff79788fb3382085ac8c3ba23 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Define GA solver to solve the problem

# %%
algorithm = GA(
    pop_size=50,
    sampling=FloatRandomSampling(),
    crossover=PointCrossover(prob=0.8, n_points=2),
    mutation = PolynomialMutation(prob=0.3, repair=RoundingRepair()),
    eliminate_duplicates=False
) # create the algorithm object

res = minimize(problem, algorithm, ('n_gen', 600), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the solution

# %%
soln = res.X # get the best solution

supply_num=len(amount_supply) # Number of supply points
demand_num=len(amount_demand) # Number of demand points

# For each supply point
for i in range(supply_num):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*supply_num, (i+1)*supply_num)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*supply_num:(i+1)*supply_num]))} <= {amount_supply[i]} or {sum(soln[i*supply_num:(i+1)*supply_num])} <= {amount_supply[i]}")

# For each demand point
for j in range(demand_num):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*demand_num+j)+']' for i in range(demand_num)])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(demand_num)]))} >= {sum(soln[i*demand_num+j] for i in range(demand_num))} or {sum(soln[i*demand_num+j] for i in range(demand_num))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 3 + 3 + 2 + 12 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 5 + 6 + 19 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 14 + 1 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 2 + 23 + 1 + 9 <= 35 or 35 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 3 + 0 + 0 + 2 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 3 + 5 + 14 + 23 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 2 + 6 + 1 + 1 >= 10 or 10 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 12 + 19 + 0 + 9 >= 40 or 40 >= 40
# Shipping cost =  4392.97 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a99a2a8b4b9703e88d7845ee395a381a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a99a2a8b4b9703e88d7845ee395a381a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a99a2a8b4b9703e88d7845ee395a381a = L.map(
#                 &quot;map_a99a2a8b4b9703e88d7845ee395a381a&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21de36b9974dc0b894e009bba9535915 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a99a2a8b4b9703e88d7845ee395a381a);
#
#
#             var marker_a73e7e715dbf677dc7ab246910db3da2 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_a99a2a8b4b9703e88d7845ee395a381a);
#
#
#             var icon_d7f7f7d8b7f19aba6fcdcd9ee9d61cbd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a73e7e715dbf677dc7ab246910db3da2.setIcon(icon_d7f7f7d8b7f19aba6fcdcd9ee9d61cbd);
#
#
#         var popup_a66ea11c123b8a58d2ac1128ac9de5db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c459a420a8bf7afd9b86cab81d5ba51 = $(`&lt;div id=&quot;html_5c459a420a8bf7afd9b86cab81d5ba51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_a66ea11c123b8a58d2ac1128ac9de5db.setContent(html_5c459a420a8bf7afd9b86cab81d5ba51);
#
#
#
#         marker_a73e7e715dbf677dc7ab246910db3da2.bindPopup(popup_a66ea11c123b8a58d2ac1128ac9de5db)
#         ;
#
#
#
#
#             var marker_9ed00daa0f9c7a63a8bb56ad9bbb8d86 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_a99a2a8b4b9703e88d7845ee395a381a);
#
#
#             var icon_ab3bdc95697d8131cb9162668fec2806 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ed00daa0f9c7a63a8bb56ad9bbb8d86.setIcon(icon_ab3bdc95697d8131cb9162668fec2806);
#
#
#         var popup_ef5e3f97da09e503dfeb879941572591 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e49a419f498bf225b485328c05fd7c04 = $(`&lt;div id=&quot;html_e49a419f498bf225b485328c05fd7c04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_ef5e3f97da09e503dfeb879941572591.setContent(html_e49a419f498bf225b485328c05fd7c04);
#
#
#
#         marker_9ed00daa0f9c7a63a8bb56ad9bbb8d86.bindPopup(popup_ef5e3f97da09e503dfeb879941572591)
#         ;
#
#
#
#
#             var marker_c19d1592cdd81d302cd094451057507d = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_a99a2a8b4b9703e88d7845ee395a381a);
#
#
#             var icon_fab31f1011a7501ae1ccfc91d6ad2023 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c19d1592cdd81d302cd094451057507d.setIcon(icon_fab31f1011a7501ae1ccfc91d6ad2023);
#
#
#         var popup_7e05dda406b22daad22f9e297a1dc2fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d28e2483bc075c145bb9ad240cf5c71e = $(`&lt;div id=&quot;html_d28e2483bc075c145bb9ad240cf5c71e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_7e05dda406b22daad22f9e297a1dc2fe.setContent(html_d28e2483bc075c145bb9ad240cf5c71e);
#
#
#
#         marker_c19d1592cdd81d302cd094451057507d.bindPopup(popup_7e05dda406b22daad22f9e297a1dc2fe)
#         ;
#
#
#
#
#             var marker_7dab6d5890f92511d92ac9704d9e2525 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_a99a2a8b4b9703e88d7845ee395a381a);
#
#
#             var icon_c65d4b9cccfad7ea2d63b6ae6b8b666b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;
