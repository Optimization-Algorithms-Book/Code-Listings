# %% [markdown]
# ## Solving supply-demand problem using bio-inspired algorithms

# %% [markdown]
# In neighborhood $Y$ of city $X$, there are 8 schools that collectively possess 100 microscopes for use in biology classes. These resources, however, are not uniformly distributed amongst the schools. With recent changes in student enrollment, 4 schools have more microscopes than needed while the other 4 schools are in need of additional ones. To address this issue, Dr. Rachel Carson, who is in charge of the biology department at City $X$'s School Board, decides to use a mathematical model. She chooses to use the Transportation Problem model, a strategy aimed at efficiently allocating resources while minimizing transportation costs [1]. The model represents supply $n$ and demand $m$ as unit weights of decision variables at various points in a network, with the cost of transporting a unit from a supply point to a demand point equivalent to the time or distance between nodes. This data is captured in an $n \times m$ cost matrix.
#
# The formal statement of this integer linear programming problem is as follows [2]:
#
# Minimize $\sum_{i \in I}\sum_{j \in J} c_{ij}x_{ij}$
#
# Subject to the following constraints:
#
# $\sum_{j \in J} x_{ij}\leq S_i  \quad \quad \forall i \in I$
#
# $\sum_{i \in I} x_{ij}\geq D_j  \quad \quad \forall j \in J$
#
# $x_{ij}\geq 0 \quad \quad \forall i \in I \quad \quad \forall j \in J$
#
# where
# * $i$ is each potential origin node
# * $I$ is the complete set of potential origin nodes
# * $j$ is each potential destination node
# * $J$ is the complete set of potential nodes
# * $x_{ij}$ is the amount to be shipped from $i \in I$ to $j \in J$
# * $c_{ij}$ is per unit shipping costs between all $i, j$ pairs. Assume that this cost is 50*distance between between $i$ and $j$.
# * $S_i$ is node i supply for $i \in I$
# * $D_j$ is node i demand for $j \in J$
#
# <b> References</b>
#
# [1] Lovelace, R. Open source tools for geographic analysis in transport planning. Journal of Geographical Systems (2021).
#
# [2] Daskin, M. (2013) Network and Discrete Location: Models, Algorithms, and Applications. New York: John Wiley & Sons, Inc.

# %% [markdown]
# ### Import used libraries

# %%
import numpy as np
import random
from pymoo.algorithms.soo.nonconvex.pso import PSO
from pymoo.optimize import minimize
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.operators.crossover.pntx import PointCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.core.problem import Problem
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import folium

# %% [markdown]
# ### Set the supply-demand problem data

# %%
supply_schools = [1, 6, 7, 8] # schools with microscopes available
demand_schools = [2, 3, 4, 5] # schools with microscopes requested
amount_supply = [20, 30, 15, 35] # number of microscopes available at each school
amount_demand = [5, 45, 10, 40] # number of microscopes requested at each school
n_var=len(supply_schools)*len(demand_schools) # number of variables

# %% [markdown]
# ### Visualize the problem data

# %%
geolocator = Nominatim(user_agent="SupplyDemand") # create geolocator object
location = geolocator.geocode("Toronto, Ontario") # get coordinates of Toronto

# %%
# Function to generate random locations around a center point
def generate_random(number, center_point):
    lat, lon = center_point
    coords = [(random.uniform(lat - 0.01, lat + 0.01), random.uniform(lon - 0.01, lon + 0.01)) for _ in range(number)]
    return coords

np.random.seed(0)  # for reproducibility
supply_coords = generate_random(len(supply_schools), [location.latitude, location.longitude])
demand_coords = generate_random(len(demand_schools), [location.latitude, location.longitude])

# %%
# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cef737e3a5670924246adbc6104d67e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cef737e3a5670924246adbc6104d67e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cef737e3a5670924246adbc6104d67e0 = L.map(
#                 &quot;map_cef737e3a5670924246adbc6104d67e0&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a2d66c840dfa6e0ac81d4000e40fc29 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cef737e3a5670924246adbc6104d67e0);
#
#
#             var marker_cdf74c35f83a2d58288b3b675a0b84ac = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_cef737e3a5670924246adbc6104d67e0);
#
#
#             var icon_65830e6b27f1fc74c69cc8efc3a557a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cdf74c35f83a2d58288b3b675a0b84ac.setIcon(icon_65830e6b27f1fc74c69cc8efc3a557a7);
#
#
#         var popup_b40d3cf8ca438e02327084b06de0b17a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11674295ef27ec0c68b50209c9739204 = $(`&lt;div id=&quot;html_11674295ef27ec0c68b50209c9739204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_b40d3cf8ca438e02327084b06de0b17a.setContent(html_11674295ef27ec0c68b50209c9739204);
#
#
#
#         marker_cdf74c35f83a2d58288b3b675a0b84ac.bindPopup(popup_b40d3cf8ca438e02327084b06de0b17a)
#         ;
#
#
#
#
#             var marker_dbf04aa38fd3937788646fd4f3318aaf = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_cef737e3a5670924246adbc6104d67e0);
#
#
#             var icon_ea876de7913c07fd9f6914ea980b98ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dbf04aa38fd3937788646fd4f3318aaf.setIcon(icon_ea876de7913c07fd9f6914ea980b98ec);
#
#
#         var popup_6ebcf86bb295bbb7eec05158432b2936 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6a6efca99109e6d3e0411e0ecc1f2ea = $(`&lt;div id=&quot;html_f6a6efca99109e6d3e0411e0ecc1f2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_6ebcf86bb295bbb7eec05158432b2936.setContent(html_f6a6efca99109e6d3e0411e0ecc1f2ea);
#
#
#
#         marker_dbf04aa38fd3937788646fd4f3318aaf.bindPopup(popup_6ebcf86bb295bbb7eec05158432b2936)
#         ;
#
#
#
#
#             var marker_25831c4b79a624fe5bc03ea59e2f0419 = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_cef737e3a5670924246adbc6104d67e0);
#
#
#             var icon_36c1314f8dca33cddffb1b77a8e238d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25831c4b79a624fe5bc03ea59e2f0419.setIcon(icon_36c1314f8dca33cddffb1b77a8e238d8);
#
#
#         var popup_b64ecabab1c03c8d3b1d486dc155be4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50dcd8b29e571c8e8c8c715a66bca60d = $(`&lt;div id=&quot;html_50dcd8b29e571c8e8c8c715a66bca60d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_b64ecabab1c03c8d3b1d486dc155be4b.setContent(html_50dcd8b29e571c8e8c8c715a66bca60d);
#
#
#
#         marker_25831c4b79a624fe5bc03ea59e2f0419.bindPopup(popup_b64ecabab1c03c8d3b1d486dc155be4b)
#         ;
#
#
#
#
#             var marker_3e7d32b7990015329061ff3447fa1601 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_cef737e3a5670924246adbc6104d67e0);
#
#
#             var icon_268613873bcece11c0eb909f9c7a46fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ### Define Cost matrix

# %%
distances = []
for supply in supply_coords:
    row = []
    for demand in demand_coords:
        row.append(geodesic(supply, demand).kilometers)
    distances.append(row)

distances = np.array(distances)

cost_matrix=50*distances

# %% [markdown]
# ### Define the transportation problem

# %%
class Transportation_problem(Problem):
    def __init__(self,
                 cost_matrix, 
                 amount_supply,
                 amount_demand
                 ):
        super().__init__(n_var=n_var,n_constr=1, vtype=int)
        self.cost_matrix = cost_matrix
        self.amount_supply = amount_supply
        self.amount_demand = amount_demand
        self.xl = np.array(np.zeros(n_var))
        self.xu = np.repeat(amount_supply, len(amount_demand))

    def _evaluate(self, X, out, *args, **kwargs):
        loss = np.zeros((X.shape[0], 1))
        g = np.zeros((X.shape[0], 1))
        for i in range(len(X)):
            soln = X[i].reshape(self.cost_matrix.shape)
            cost_x = X[i].reshape(self.cost_matrix.shape)
            cost = cost_x * cost_matrix.T
            cost = cost.sum()
            loss[i] = cost         
            total_supply = soln.sum(axis=1)
            total_demand = soln.sum(axis=0)  
            g[i] =  np.any(total_supply<self.amount_supply) or np.any(total_demand<self.amount_demand)
        out["F"] = loss
        out["G"] = g

# %%
problem = Transportation_problem(cost_matrix,amount_supply,amount_demand) # create problem object

# %% [markdown]
# ## Define PSO solver to solve the problem

# %%
algorithm = PSO(pop_size=100,repair=RoundingRepair()) # create the algorithm object
res = minimize(problem, algorithm, ('n_gen', 150), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the soltuion

# %%
soln = res.X

# For each supply point
for i in range(len(amount_supply)):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*4, (i+1)*4)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*4:(i+1)*4]))} <= {amount_supply[i]} or {sum(soln[i*4:(i+1)*4])} <= {amount_supply[i]}")

# For each demand point
for j in range(len(amount_demand)):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*4+j)+']' for i in range(len(amount_demand))])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(len(amount_demand))]))} >= {sum(soln[i*4+j] for i in range(len(amount_demand)))} or {sum(soln[i*4+j] for i in range(len(amount_demand)))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 1 + 0 + 14 + 5 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 30 + 0 + 0 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 15 + 0 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 4 + 0 + 0 + 35 <= 35 or 39 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 1 + 0 + 0 + 4 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 0 + 30 + 15 + 0 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 14 + 0 + 0 + 0 >= 14 or 14 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 5 + 0 + 0 + 35 >= 40 or 40 >= 40
# Shipping cost =  3053.94 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47da455fc338a56b2ae5423c0920b243 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47da455fc338a56b2ae5423c0920b243&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_47da455fc338a56b2ae5423c0920b243 = L.map(
#                 &quot;map_47da455fc338a56b2ae5423c0920b243&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da47e76e5a1d4c99ee8e4b13e27b6572 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47da455fc338a56b2ae5423c0920b243);
#
#
#             var marker_a4804208146e6a03ac3acc91c3e39051 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_47da455fc338a56b2ae5423c0920b243);
#
#
#             var icon_f02af05602340bbf13788c30fc2fe0f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a4804208146e6a03ac3acc91c3e39051.setIcon(icon_f02af05602340bbf13788c30fc2fe0f2);
#
#
#         var popup_96af7b0c1c0a3fe7c312094f89ff91af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47a252e42900dddb33e00ae837aae165 = $(`&lt;div id=&quot;html_47a252e42900dddb33e00ae837aae165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_96af7b0c1c0a3fe7c312094f89ff91af.setContent(html_47a252e42900dddb33e00ae837aae165);
#
#
#
#         marker_a4804208146e6a03ac3acc91c3e39051.bindPopup(popup_96af7b0c1c0a3fe7c312094f89ff91af)
#         ;
#
#
#
#
#             var marker_9826735991d59f65e2b70d0f4a21cdb7 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_47da455fc338a56b2ae5423c0920b243);
#
#
#             var icon_cf14f662bc6b8926717df57ad4b5cefb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9826735991d59f65e2b70d0f4a21cdb7.setIcon(icon_cf14f662bc6b8926717df57ad4b5cefb);
#
#
#         var popup_3fc4db897518856d76a57374d5842e70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5e1f5ecfe265734cbf20b0094b7b98a = $(`&lt;div id=&quot;html_d5e1f5ecfe265734cbf20b0094b7b98a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_3fc4db897518856d76a57374d5842e70.setContent(html_d5e1f5ecfe265734cbf20b0094b7b98a);
#
#
#
#         marker_9826735991d59f65e2b70d0f4a21cdb7.bindPopup(popup_3fc4db897518856d76a57374d5842e70)
#         ;
#
#
#
#
#             var marker_1c721442a124f9d36e9baba540968adb = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_47da455fc338a56b2ae5423c0920b243);
#
#
#             var icon_e58898289a2d91c74ba2acd1b4aabc24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c721442a124f9d36e9baba540968adb.setIcon(icon_e58898289a2d91c74ba2acd1b4aabc24);
#
#
#         var popup_b534f2c8064363840a50bb4eaaced541 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9da657b7a32187f2e264d0bbbe44d1e7 = $(`&lt;div id=&quot;html_9da657b7a32187f2e264d0bbbe44d1e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_b534f2c8064363840a50bb4eaaced541.setContent(html_9da657b7a32187f2e264d0bbbe44d1e7);
#
#
#
#         marker_1c721442a124f9d36e9baba540968adb.bindPopup(popup_b534f2c8064363840a50bb4eaaced541)
#         ;
#
#
#
#
#             var marker_e6c3aa8ce89931bf94414a6969c9ef00 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_47da455fc338a56b2ae5423c0920b243);
#
#
#             var icon_15b46122832beaa93f14cbb7db6bf3c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Define GA solver to solve the problem

# %%
algorithm = GA(
    pop_size=50,
    sampling=FloatRandomSampling(),
    crossover=PointCrossover(prob=0.8, n_points=2),
    mutation = PolynomialMutation(prob=0.3, repair=RoundingRepair()),
    eliminate_duplicates=False
) # create the algorithm object

res = minimize(problem, algorithm, ('n_gen', 600), seed=1, verbose=False) # run the algorithm

# %% [markdown]
# ### Print the solution

# %%
soln = res.X

# For each supply point
for i in range(len(amount_supply)):
    print(f"Supply School({supply_schools[i]}): {' + '.join(['soln['+str(j)+']' for j in range(i*4, (i+1)*4)])} <= {amount_supply[i]} or {' + '.join(map(str, soln[i*4:(i+1)*4]))} <= {amount_supply[i]} or {sum(soln[i*4:(i+1)*4])} <= {amount_supply[i]}")

# For each demand point
for j in range(len(amount_demand)):
    print(f"Demand School({demand_schools[j]}): {' + '.join(['soln['+str(i*4+j)+']' for i in range(len(amount_demand))])} >= {amount_demand[j]} or {' + '.join(map(str, [soln[i*4+j] for i in range(len(amount_demand))]))} >= {sum(soln[i*4+j] for i in range(len(amount_demand)))} or {sum(soln[i*4+j] for i in range(len(amount_demand)))} >= {amount_demand[j]}") 

# Print shipping cost
print(f"Shipping cost =  {round(res.F[0], 2)} $")
# Out:
# Supply School(1): soln[0] + soln[1] + soln[2] + soln[3] <= 20 or 3 + 3 + 2 + 12 <= 20 or 20 <= 20
# Supply School(6): soln[4] + soln[5] + soln[6] + soln[7] <= 30 or 0 + 5 + 6 + 19 <= 30 or 30 <= 30
# Supply School(7): soln[8] + soln[9] + soln[10] + soln[11] <= 15 or 0 + 14 + 1 + 0 <= 15 or 15 <= 15
# Supply School(8): soln[12] + soln[13] + soln[14] + soln[15] <= 35 or 2 + 23 + 1 + 9 <= 35 or 35 <= 35
# Demand School(2): soln[0] + soln[4] + soln[8] + soln[12] >= 5 or 3 + 0 + 0 + 2 >= 5 or 5 >= 5
# Demand School(3): soln[1] + soln[5] + soln[9] + soln[13] >= 45 or 3 + 5 + 14 + 23 >= 45 or 45 >= 45
# Demand School(4): soln[2] + soln[6] + soln[10] + soln[14] >= 10 or 2 + 6 + 1 + 1 >= 10 or 10 >= 10
# Demand School(5): soln[3] + soln[7] + soln[11] + soln[15] >= 40 or 12 + 19 + 0 + 9 >= 40 or 40 >= 40
# Shipping cost =  4392.97 $

# %% [markdown]
# ### Visualize the solution

# %%
# Normalize function
def normalize(lst):
    s = sum(lst)
    return list(map(lambda x: (x/s)*10, lst))

# Normalize soln array
soln_normalized = normalize(soln)

# Define a color list
colors = ['cyan', 'brown', 'orange', 'purple']

# Create a map centered at Downtown Toronto
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=15, scrollWheelZoom=False, dragging=False)

# Add markers for supply schools
for i, coord in zip(supply_schools, supply_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="home", color='red'), popup=f'Supply School {i+1}').add_to(m)

# Add markers for demand schools
for i, coord in zip(demand_schools, demand_coords):
    folium.Marker(location=coord, icon=folium.Icon(icon="flag", color='blue'), popup=f'Demand School {i+1}').add_to(m)

# Add lines (edges) between supply and demand schools
for i in range(len(supply_schools)):
    for j in range(len(demand_schools)):
        soln_value = soln[i*len(demand_schools) + j]
        folium.PolyLine(locations=[supply_coords[i], demand_coords[j]], color=colors[i % len(colors)],  weight=5*soln_normalized[i*len(demand_schools) + j], popup=folium.Popup(f'# of microscopes: {soln_value}')).add_to(m)
             
# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1245f4020b69f4b4f226c17ca005944 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1245f4020b69f4b4f226c17ca005944&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c1245f4020b69f4b4f226c17ca005944 = L.map(
#                 &quot;map_c1245f4020b69f4b4f226c17ca005944&quot;,
#                 {
#                     center: [43.6534817, -79.3839347],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1873060480932c6ea5c08857a7f20719 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1245f4020b69f4b4f226c17ca005944);
#
#
#             var marker_4a744fea2cf53440bb4cb7d032337ab8 = L.marker(
#                 [43.64616898488225, -79.37698602526125],
#                 {}
#             ).addTo(map_c1245f4020b69f4b4f226c17ca005944);
#
#
#             var icon_fae840ea432afb9d6c286586e3fcca35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a744fea2cf53440bb4cb7d032337ab8.setIcon(icon_fae840ea432afb9d6c286586e3fcca35);
#
#
#         var popup_6b6d523464f7b5feef643771de5525b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aff0828a85569a90737005caf0a6803f = $(`&lt;div id=&quot;html_aff0828a85569a90737005caf0a6803f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 2&lt;/div&gt;`)[0];
#                 popup_6b6d523464f7b5feef643771de5525b7.setContent(html_aff0828a85569a90737005caf0a6803f);
#
#
#
#         marker_4a744fea2cf53440bb4cb7d032337ab8.bindPopup(popup_6b6d523464f7b5feef643771de5525b7)
#         ;
#
#
#
#
#             var marker_41a26575e840a09fa90a227166c662e4 = L.marker(
#                 [43.65875719237953, -79.38883331948522],
#                 {}
#             ).addTo(map_c1245f4020b69f4b4f226c17ca005944);
#
#
#             var icon_dbfce17e74b7db7157959a3265b05ddc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_41a26575e840a09fa90a227166c662e4.setIcon(icon_dbfce17e74b7db7157959a3265b05ddc);
#
#
#         var popup_7c967b14caaea8dd1f81633324c669df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9293c132c6d75c0b341d0c4c718d6551 = $(`&lt;div id=&quot;html_9293c132c6d75c0b341d0c4c718d6551&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 7&lt;/div&gt;`)[0];
#                 popup_7c967b14caaea8dd1f81633324c669df.setContent(html_9293c132c6d75c0b341d0c4c718d6551);
#
#
#
#         marker_41a26575e840a09fa90a227166c662e4.bindPopup(popup_7c967b14caaea8dd1f81633324c669df)
#         ;
#
#
#
#
#             var marker_978cf648faf1b9ca768f88f843c79542 = L.marker(
#                 [43.65339040174184, -79.38494487870422],
#                 {}
#             ).addTo(map_c1245f4020b69f4b4f226c17ca005944);
#
#
#             var icon_0ca58f76405b5db1a8b007ea3b5b41b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_978cf648faf1b9ca768f88f843c79542.setIcon(icon_0ca58f76405b5db1a8b007ea3b5b41b5);
#
#
#         var popup_57a704db70545ceb2b591bca6f393ad6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd72d60c1586ef7b645a1d6d16af4260 = $(`&lt;div id=&quot;html_fd72d60c1586ef7b645a1d6d16af4260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supply School 8&lt;/div&gt;`)[0];
#                 popup_57a704db70545ceb2b591bca6f393ad6.setContent(html_fd72d60c1586ef7b645a1d6d16af4260);
#
#
#
#         marker_978cf648faf1b9ca768f88f843c79542.bindPopup(popup_57a704db70545ceb2b591bca6f393ad6)
#         ;
#
#
#
#
#             var marker_747db671cefe06f0f33aed1a43196d42 = L.marker(
#                 [43.65651355945445, -79.37816023297728],
#                 {}
#             ).addTo(map_c1245f4020b69f4b4f226c17ca005944);
#
#
#             var icon_17af952098dd9c0cac1cec8d75e4f556 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;
