# %% [markdown]
# # Emergency Dispatch and Routing
#
# **Citation:** Aswin Raj Giri, Tianjian Chen, Vishnu Priya Rajendran and Alaa Khamis, "A Metaheuristic Approach to Emergency Vehicle Dispatch and Routing," IEEE International Conference on Smart Mobility, 2022.
#
# **Abstract:** Accidents and emergency situations have been on a constant rise, especially during the COVID-19 pandemic. Typically, the emergency vehicle dispatch and routing problems involve various dynamic factors which make them very different from conventional vehicle routing problems. This paper presents a metaheuristic approach to emergency vehicle dispatch and routing. Dispatching aims at allotting and sending the nearby available vehicle to the location of emergency and routing deals with selecting the ideal route to reach the destination. The objective is to minimize incident response time and the total time travel for the vehicle from the dispatch point to the destination. This usually depends on the emergency service vehicle availability and other dynamic factors such as traffic, number of turns in the route, etc. Three different bio-inspired algorithms, namely, ant colony optimization, adaptive ACO and firefly algorithm are investigated. Performance evaluation shows that firefly algorithm outperforms the other algorithms in terms of cost, number of turns, and run time for the given data set. However, in case of larger datasets and multiple variables if involved, adaptive ACO gives better results but takes longer time.

# %%
import osmnx
from optalgotools.structures import Node
from optalgotools.routing import randomized_search
# from optalgotools.routing import draw_route
import math
import random
from tqdm.notebook import tqdm
import osmnx as ox
from numpy.random import choice as weighted_choice
import pandas as pd
import itertools
from copy import copy, deepcopy
import folium

# %%
def cost(G, route):
    weight = 0
    for u, v in zip(route, route[1:]):
        weight += G[u][v][0]['length']   
    return round(weight,4)

# %%
"""
Return true with probability p.
"""
def probability(p):
    return p > random.uniform(0.0, 1.0)

# %%
def cross_over(route_1, route_2):
    origin = route_1[0]
    destination = route_1[len(route_1) - 1]

    intersection = [*itertools.filterfalse(\
                    lambda element : element in [origin, destination] ,\
                    list(set(route_1) & set(route_2)))]
    
    if len(intersection) == 0: return route_1 # if there is not common node, just return the first route

    cross_over_point = random.choice(intersection)
    first_point = route_1.index(cross_over_point)
    second_point = route_2.index(cross_over_point)

    if probability(0.5):
        return route_1[:first_point] + route_2[second_point:]
    else:
        return route_2[:second_point] + route_1[first_point:]

# %%
def haversine_distance(lon1, lat1, lon2, lat2):
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 

    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %% [markdown]
# ### Datasets
# 1. 50 buildings in the area surrouding the University of Toronto were selected as destinations, or "points of emergency".
# 2. The real locations of **8** fire stations, **5** police stations, and **10** hospitals in that area were selected as vehicle depots for various types of emergency vehicles (fire trucks, police cars, ambulances).
#
# ### Constraints
# 1. Only one request at a time.
# 2. Emergency sites have an associated "emergency level" and emergency vehicles have a "capacity" to satisfy those levels. Emergency sites can only be satisfied by a vehicle of an equal or higher capacity, or by multiple vehicles whose sum meets or exceeds the emergency site's emergency level.
# 3. The three emergency levels are **high**, **medium**, and **low**.
# 4. All emergency vehicles are initialized at their starting depot.

# %% [markdown]
# ## Functions and Classes

# %% [markdown]
# ### Cost Function

# %% [markdown]
# ### Turns in Route
#
# This function calculates the number of turns in a route between two nodes as the number of unique street ids - 1.

# %%
# Determines the number of turns in a route between two locations

def turns(G,route):
    roads = []
    for i in range(0,len(route)-1):
        way =G[route[i]][route[i+1]]
        roads.append(str(way[0]['osmid']))
    roads = len(set(roads))
    turn = roads -1
    return turn

# %% [markdown]
# ### Closest Node
#
# This function looks for the OSMID of the closest node in an OSMNX graph for a given geocode.

# %%
def closest_node_osmid(G, lat, lng):
    id = ox.distance.nearest_nodes(G,lng,lat)
    return Node(G,id)

# %% [markdown]
# ### Emergency Class

# %%
class Emergency:
    def __init__(self, building, level, type):
        self.level = level
        self.type = type
        self.building = building
    
    def __repr__(self):
        return f"[Level:{self.level}, Type:{self.type}, Building: {self.building.name}]"

# %% [markdown]
# ### Vehicle Class

# %%
class Vehicle:
    def __init__(self, name, capacity, vehicle_type, location):
        self.name = name
        self.capacity = capacity
        self.vehicle_type = vehicle_type
        self.location = location

    def __repr__(self):
        return f"[Name:{self.name}, Type:{self.vehicle_type}, Capacity: {self.capacity}, Location: {self.location}]"

# %% [markdown]
# ### Building Class

# %%
class Building:
    def __init__(self, name, lat, lng, level):
        self.name = name
        self.location = (lat, lng)
        self.level = level

# %% [markdown]
# ## Problem Class

# %%
class EmergencyRouting:
    vehicles = []
    locations = []
    emergencies = []
    results = []

    def __init__(self):
        self.load_vehicles()
        self.load_buildings()

    def load_vehicles(self, filename="emergency_vehicle_location.csv"):
        df = pd.read_csv(filename)
        for index, row in df.iterrows():
            self.vehicles.append(
                Vehicle(
                    row.name,
                    row.casualities_expected_to_treat,
                    row.vehicle_type,
                    (row.vehicle_lat, row.vehicle_lng),
                )
            )

    def load_buildings(self, filename="building_location.csv"):
        df = pd.read_csv(filename)
        for index, row in df.iterrows():
            self.locations.append(
                Building(
                    row.building_name,
                    row.building_lat,
                    row.building_lng,
                    row.casualities_expected,
                )
            )

    def generate_emergencies(self, num_emergencies, allow_repeat_building=False):
        results = []
        buildings = copy(self.locations)
        for i in range(num_emergencies):
            # Select a random emergency level, weighted towards less severe ones
            e_level = weighted_choice([1, 2, 3], 1, [0.5, 0.3, 0.2])[0]
            # Select a random emergency type
            e_type = random.choice([1, 2, 3])
            # Select a random building
            if allow_repeat_building:
                e_building = random.choice(buildings)
            else:
                e_building = buildings.pop(random.randrange(len(buildings)))
            results.append(Emergency(e_building, e_level, e_type))
        self.emergencies = results

    def route(self, G, vehicles, destination, algorithm):
        routes = []
        destination_node = closest_node_osmid(G, destination[0], destination[1])
        for v in vehicles:
            origin_node = closest_node_osmid(G, v.location[0], v.location[1])
            route = algorithm.run(G, origin_node, destination_node)
            routes.append(route)

            # Update vehicle location
            v.location = (destination[0], destination[1])
            self.vehicles[self.vehicles.index(v)] = v

        return routes

    # Takes the next emergency and assigns vehicles to be dispatched
    def dispatch(self):
        dispatched = []
        emergency = self.emergencies.pop(0)
        level = emergency.level

        # Filter to only keep relevant vehicles
        available_vehicles = [
            v for v in self.vehicles if v.vehicle_type == emergency.type
        ]
        available_vehicles = sorted(
            available_vehicles,
            key=lambda x: haversine_distance(
                emergency.building.location[1],
                emergency.building.location[0],
                x.location[1],
                x.location[0],
            ),
        )
        while level > 0:
            current = available_vehicles.pop(0)
            dispatched.append(current)
            level -= current.capacity

        results = copy(dispatched)
        dispatched.reverse()
        if level < 0:
            # Try to remove some vehicles
            for v in dispatched:
                if level + v.capacity <= 0:
                    results.pop(results.index(v))
                    level += v.capacity
                if level == 0:
                    break

        return emergency, results

    def visualize(self, G, result):

        print(result["emergency"])
        print(f"Number of Vehicles:{len(result['active_vehicles'])}")
        print(f"Total Distance: {sum([cost(G,r) for r in result['routes']])}")
        print(f"Total Turns: {sum([turns(G,r) for r in result['routes']])}")
        icons = ["fire-extinguisher", "gavel", "ambulance"]
        v_colors = ["red", "blue", "green"]
        m = folium.Map((43.654589, -79.389229), zoom_start=10)
        # Vehicle Markers
        for v in result["vehicle"]:
            color = (
                v_colors[v.vehicle_type - 1]
                if v.name in result["active_vehicles"]
                else "gray"
            )
            folium.Marker(
                location=v.location,
                icon=folium.Icon(
                    color=color, 
                    icon=icons[v.vehicle_type - 1], 
                    prefix="fa"
                ),
                popup=f"Capacity: {v.capacity}"
            ).add_to(m)


        # Destination Marker
        folium.Marker(
            location=result["emergency"].building.location,
            icon=folium.Icon(color="orange", icon="exclamation", prefix="fa"),
            popup=f"Level: {result['emergency'].level}"
        ).add_to(m)
        
        # Routes
        for r in result['routes']:
            ox.plot_route_folium(G,r,m)
        return m

    def run(self, G, num_emergencies, allow_repeat_locations):

        # Generate emergencies
        self.generate_emergencies(num_emergencies, allow_repeat_locations)
        

    def next(self, algorithm):
        if len(self.emergencies) == 0:
            return "No more emergencies to respond to."
        # Dispatch
        emergency, vehicles = self.dispatch()
        result_obj = {
            "emergency": emergency,
            "vehicle": deepcopy(self.vehicles),
            "active_vehicles": [x.name for x in vehicles]
        }

        # Route
        routes = self.route(G, vehicles, emergency.building.location, algorithm)
        result_obj["routes"] = routes
        return self.visualize(G, result_obj)

# %% [markdown]
# ### Dispatching
#
# Vehicles are dispatched as follows:
# 1. The list of all vehicles is filtered to remove any vehicles that do not match the emergency type. For example, ambulances will not be considered when responding to a fire call.
# 2. The Haversine distance between the remaining vehicles and the emergency location is determined, and the list is sorted in ascending order.
# 3. Vehicles are added to the dispatch list until the severity level of the emergency is satisfied. If the final level of the dispatched fleet is greater than what is required, we will try to remove low level vehicles to match the emergency level perfectly.
#
#     For example:<br>
#         If there is an emergency of level 3, and the closest vehicles are:<br>
#         &nbsp;&nbsp;**A (level 1):** 2 km away<br>
#         &nbsp;&nbsp;**B (level 1):** 4 km away<br>
#         &nbsp;&nbsp;**C (level 3):** 6 km away<br>
#         The dispatching algorithm will select all 3 vehicles (A, B, C), but then remove both A and B as they are not required to respond to the emergency.

# %% [markdown]
# ## Solutions

# %%
# Initialize problem
problem = EmergencyRouting()
G = osmnx.graph_from_address("University Of Toronto", dist=3000, network_type="drive_service")

# Initialize some parameters
num_emergencies = 9
allow_repeat_locations = False

problem.run(G, num_emergencies, allow_repeat_locations)

# %% [markdown]
# ### Example 1: Dispatching + Routing Emergencies using ACO

# %% [markdown]
# #### Ant Colony Optimization

# %%
class ACO:
    def __init__(self, alpha=2, beta=2, n=500, Q=1):
        self.alpha = alpha
        self.beta = beta
        self.n = n
        self.Q = Q

    def pheremone(self, level, distance):
        return level ** self.alpha * ((1/distance)) ** self.beta

    def run(self, G, origin, destination):
        # randomize the pheromones
        pheremone_concentrations = {(u,v):random.uniform(0,0.5) for [u,v] in G.edges()}
        known_routes = dict()

        for ant in tqdm(range(self.n)):
            # Place the ant at the colony
            frontier = [origin]
            explored = set()
            route = []
            found = False

            while frontier and not found:
                parent = frontier.pop(0)
                explored.add(parent)

                children = []
                children_pheremones = []
                for child in parent.expand():
                    # If we see the destination, ignore all pheremones
                    if child == destination:
                        found = True
                        route = child.path()
                        continue
                    if child not in explored:
                        children.append(child)
                        children_pheremones.append(
                            self.pheremone(
                                pheremone_concentrations[(parent.osmid, child.osmid)],
                                child.distance
                            )
                        )

                if len(children) == 0:
                    continue  # The ant is stuck, go back.

                transition_probability = [
                    children_pheremones[i] / sum(children_pheremones)
                    for i in range(len(children_pheremones))
                ]

                # Probabilistically choose a child to explore based weighted by transition probability
                chosen = random.choices(children, weights=transition_probability, k=1)[0]

                # Add all the non-explored children in case we need to explore them later
                children.pop(children.index(chosen))
                frontier.extend(children)

                # Set the chosen child to be the next node to explore
                frontier.insert(0, chosen)
            
            # We now have a completed route, we can increase pheremone levels 
            # on that route for the next ant to detect.

            for u, v in zip(route[:-1], route[1:]):
                length_of_edge = G[u][v][0]['length']
                pheremone_concentrations[(u,v)] += self.Q/length_of_edge
            
            # If the route is newly discovered, add it to the list
            route = tuple(route)
            if route in known_routes:
                known_routes[route] += 1
            else:
                known_routes[route] = 1
        return list(max(known_routes, key=known_routes.get))

# %% [markdown]
# #### Results and Visualization

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:2, Type:1, Building: building_24]
# Number of Vehicles:1
# Total Distance: 1365.701
# Total Turns: 14
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7aed13854e17419e644500ea9623eeb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7aed13854e17419e644500ea9623eeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b7aed13854e17419e644500ea9623eeb = L.map(
#                 &quot;map_b7aed13854e17419e644500ea9623eeb&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff8e59b6d8775eadeb221855631749dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7aed13854e17419e644500ea9623eeb);
#
#
#             var marker_5b6cfc889bb7235e441b11c47702636e = L.marker(
#                 [43.64866834, -79.38967358],
#                 {}
#             ).addTo(map_b7aed13854e17419e644500ea9623eeb);
#
#
#             var icon_fa15edd871140264b1e4bb268192b973 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5b6cfc889bb7235e441b11c47702636e.setIcon(icon_fa15edd871140264b1e4bb268192b973);
#
#
#         var popup_044db2efb6bcf521e32c0ffea5a2f7c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65fb276be5ebabfd232446c3ac940dc8 = $(`&lt;div id=&quot;html_65fb276be5ebabfd232446c3ac940dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_044db2efb6bcf521e32c0ffea5a2f7c7.setContent(html_65fb276be5ebabfd232446c3ac940dc8);
#
#
#
#         marker_5b6cfc889bb7235e441b11c47702636e.bindPopup(popup_044db2efb6bcf521e32c0ffea5a2f7c7)
#         ;
#
#
#
#
#             var marker_ed05b683baeaa9ba7f305b755504a14a = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_b7aed13854e17419e644500ea9623eeb);
#
#
#             var icon_214f15b538622e1cbb3012fe77154331 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed05b683baeaa9ba7f305b755504a14a.setIcon(icon_214f15b538622e1cbb3012fe77154331);
#
#
#         var popup_8a12847ffdf628976f1beada562d22c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f2e1aee3eeb8e26758e24c00b2b11a5 = $(`&lt;div id=&quot;html_2f2e1aee3eeb8e26758e24c00b2b11a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_8a12847ffdf628976f1beada562d22c0.setContent(html_2f2e1aee3eeb8e26758e24c00b2b11a5);
#
#
#
#         marker_ed05b683baeaa9ba7f305b755504a14a.bindPopup(popup_8a12847ffdf628976f1beada562d22c0)
#         ;
#
#
#
#
#             var marker_a833a6f6477d899e8ccdb1069c301c65 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_b7aed13854e17419e644500ea9623eeb);
#
#
#             var icon_92ac19fcd9ae814033cbcf3eb47dc178 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a833a6f6477d899e8ccdb1069c301c65.setIcon(icon_92ac19fcd9ae814033cbcf3eb47dc178);
#
#
#         var popup_b77f2a7848d81580f1dee3d1df58e058 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffefd7199888a7391c8884c43da6a1bd = $(`&lt;div id=&quot;html_ffefd7199888a7391c8884c43da6a1bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_b77f2a7848d81580f1dee3d1df58e058.setContent(html_ffefd7199888a7391c8884c43da6a1bd);
#
#
#
#         marker_a833a6f6477d899e8ccdb1069c301c65.bindPopup(popup_b77f2a7848d81580f1dee3d1df58e058)
#         ;
#
#
#
#
#             var marker_1702ad4def6114fdaee0b9f7aa778af8 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_b7aed13854e17419e644500ea9623eeb);
#
#
#             var icon_af8652bb92a359fa954cbc1f7bece9c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:1, Type:3, Building: building_42]
# Number of Vehicles:1
# Total Distance: 1880.942
# Total Turns: 17
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8409353532f982eddf3f468fe300201f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8409353532f982eddf3f468fe300201f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8409353532f982eddf3f468fe300201f = L.map(
#                 &quot;map_8409353532f982eddf3f468fe300201f&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5faf16e35e6966433d0c96cbd4ad1ac0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8409353532f982eddf3f468fe300201f);
#
#
#             var marker_c5d24ef0e0453bed292bf383734796bc = L.marker(
#                 [43.649738, -79.39119],
#                 {}
#             ).addTo(map_8409353532f982eddf3f468fe300201f);
#
#
#             var icon_7e0ac77140db077eea22296a880ebdad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c5d24ef0e0453bed292bf383734796bc.setIcon(icon_7e0ac77140db077eea22296a880ebdad);
#
#
#         var popup_b31a767550f41b8421d386af59cd53a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66cc2001f6ffde09fe2d5383ad28e5af = $(`&lt;div id=&quot;html_66cc2001f6ffde09fe2d5383ad28e5af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_b31a767550f41b8421d386af59cd53a7.setContent(html_66cc2001f6ffde09fe2d5383ad28e5af);
#
#
#
#         marker_c5d24ef0e0453bed292bf383734796bc.bindPopup(popup_b31a767550f41b8421d386af59cd53a7)
#         ;
#
#
#
#
#             var marker_3b35909be53f39d71c4622010610a581 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_8409353532f982eddf3f468fe300201f);
#
#
#             var icon_58407f62c6c012c63e1f4297eab08b19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3b35909be53f39d71c4622010610a581.setIcon(icon_58407f62c6c012c63e1f4297eab08b19);
#
#
#         var popup_82d1f86c755ecf80cac0b0f4bc944d26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_038bf3fdaddd07feee392ed130df7cdf = $(`&lt;div id=&quot;html_038bf3fdaddd07feee392ed130df7cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_82d1f86c755ecf80cac0b0f4bc944d26.setContent(html_038bf3fdaddd07feee392ed130df7cdf);
#
#
#
#         marker_3b35909be53f39d71c4622010610a581.bindPopup(popup_82d1f86c755ecf80cac0b0f4bc944d26)
#         ;
#
#
#
#
#             var marker_57ce81e80a2841fe908478b1ac2a3b8e = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_8409353532f982eddf3f468fe300201f);
#
#
#             var icon_98fb19c56f3649723a878b097f5923c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_57ce81e80a2841fe908478b1ac2a3b8e.setIcon(icon_98fb19c56f3649723a878b097f5923c4);
#
#
#         var popup_0fd89fde6e2f26bcc2415de01fa4cb6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7642a21080677450f277d322e6eb4290 = $(`&lt;div id=&quot;html_7642a21080677450f277d322e6eb4290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_0fd89fde6e2f26bcc2415de01fa4cb6d.setContent(html_7642a21080677450f277d322e6eb4290);
#
#
#
#         marker_57ce81e80a2841fe908478b1ac2a3b8e.bindPopup(popup_0fd89fde6e2f26bcc2415de01fa4cb6d)
#         ;
#
#
#
#
#             var marker_a82e55ce095b0b98b1feb880417e97c9 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_8409353532f982eddf3f468fe300201f);
#
#
#             var icon_8a8d34c99627e955a98c3bd675b5ab60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:1, Type:2, Building: building_28]
# Number of Vehicles:1
# Total Distance: 843.94
# Total Turns: 8
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6789d878fbdf61cf8ca9b7733ef107d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6789d878fbdf61cf8ca9b7733ef107d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6789d878fbdf61cf8ca9b7733ef107d6 = L.map(
#                 &quot;map_6789d878fbdf61cf8ca9b7733ef107d6&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_426d0a63ada1f68166187de16de9ee10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6789d878fbdf61cf8ca9b7733ef107d6);
#
#
#             var marker_522f971537bb4e49dc828ab14877d3c9 = L.marker(
#                 [43.649738, -79.39119],
#                 {}
#             ).addTo(map_6789d878fbdf61cf8ca9b7733ef107d6);
#
#
#             var icon_95d530bf6cc069334f8b28e72bbe943a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_522f971537bb4e49dc828ab14877d3c9.setIcon(icon_95d530bf6cc069334f8b28e72bbe943a);
#
#
#         var popup_e4dd4740e9a11c55c3d7a32a4c2652e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92e2d11197fa54841ef85c6ffeb83fab = $(`&lt;div id=&quot;html_92e2d11197fa54841ef85c6ffeb83fab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_e4dd4740e9a11c55c3d7a32a4c2652e0.setContent(html_92e2d11197fa54841ef85c6ffeb83fab);
#
#
#
#         marker_522f971537bb4e49dc828ab14877d3c9.bindPopup(popup_e4dd4740e9a11c55c3d7a32a4c2652e0)
#         ;
#
#
#
#
#             var marker_fe45cf9b8c76f31668679bea4d3a73ad = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_6789d878fbdf61cf8ca9b7733ef107d6);
#
#
#             var icon_7c213ccbf150c7fa546fbe4228be9e56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fe45cf9b8c76f31668679bea4d3a73ad.setIcon(icon_7c213ccbf150c7fa546fbe4228be9e56);
#
#
#         var popup_f772ba2363a241cd71a2391f0df1b319 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1db71df3e3fe5905a1e2cae57e4a0c57 = $(`&lt;div id=&quot;html_1db71df3e3fe5905a1e2cae57e4a0c57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_f772ba2363a241cd71a2391f0df1b319.setContent(html_1db71df3e3fe5905a1e2cae57e4a0c57);
#
#
#
#         marker_fe45cf9b8c76f31668679bea4d3a73ad.bindPopup(popup_f772ba2363a241cd71a2391f0df1b319)
#         ;
#
#
#
#
#             var marker_7bb2b61bbf853605d142bb8f868067b9 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_6789d878fbdf61cf8ca9b7733ef107d6);
#
#
#             var icon_e36708fa0747df4dfad325421936ae93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7bb2b61bbf853605d142bb8f868067b9.setIcon(icon_e36708fa0747df4dfad325421936ae93);
#
#
#         var popup_3909b2ef33ffa127dd88b1f26090829f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e800f0c0bd918248d1ca1bc9658d63c = $(`&lt;div id=&quot;html_3e800f0c0bd918248d1ca1bc9658d63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_3909b2ef33ffa127dd88b1f26090829f.setContent(html_3e800f0c0bd918248d1ca1bc9658d63c);
#
#
#
#         marker_7bb2b61bbf853605d142bb8f868067b9.bindPopup(popup_3909b2ef33ffa127dd88b1f26090829f)
#         ;
#
#
#
#
#             var marker_b4b0cd2bc55240ef18b92f9ad6ec3b55 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_6789d878fbdf61cf8ca9b7733ef107d6);
#
#
#             var icon_1e97a4bb521a4657893674aa073da68d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %% [markdown]
# As you can see from the above three examples, the ACO solver does not take into account the number of turns in a route, as pheremones are deposited on node-to-node edges. Since the scoring of routes in ACO is the sum of individual scores, we cannot penalize excess turns.

# %% [markdown]
# ### Example 2: Dispatching + Routing Emergencies using Firefly Algorithm

# %% [markdown]
# #### Firefly Algorithm Class

# %%
class Firefly:
    def __init__(self, num_iterations=15, pop_size=100, gamma=2, k=100):
        self.num_iterations = num_iterations
        self.pop_size = pop_size
        self.gamma = gamma 
        self.k = k

    # Cost as length + complexity of route
    def turns(G,route):
        roads = []
        for i in range(0,len(route)-1):
            way =G[route[i]][route[i+1]]
            roads.append(str(way[0]['osmid']))
        roads = len(set(roads))
        turn = roads -1
        return turn

    def luminosity(self, G, route):
        
        return cost(G,route) + self.k*turns(G,route)

    # Define the distance between two routes as the number of common nodes they possess
    def distance(self, route1,route2):
        return len(set(route1) & set(route2))
    
    def run(self, G, origin, destination):
        # Initialize population
        flies = [randomized_search(G,origin.osmid, destination.osmid) for _ in range(self.pop_size)]

        for _ in tqdm(range(self.num_iterations)):
            for i in range(self.pop_size):
                flies_luminosity = list()  # for all flies except i
                for j in range(self.pop_size):
                    if i == j:
                        continue
                    flies_luminosity.append((j, self.luminosity(G, flies[j])))
                moving_fly = flies[i]
                # Using min here as the "most" luminous is the one with lowest cost + complexity
                target_fly = min(
                    flies_luminosity,
                    key=lambda fly: fly[1]
                    * math.exp(-1 * self.gamma * self.distance(moving_fly, flies[fly[0]]))
                )
                target_fly = flies[target_fly[0]]
                # update the position, moving is just a crossover
                flies[i] = cross_over(target_fly,moving_fly)

        return min(flies, key=lambda fly: self.luminosity(G,fly))

# %% [markdown]
# #### Results and Visualization

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:1, Type:3, Building: building_25]
# Number of Vehicles:1
# Total Distance: 915.863
# Total Turns: 9
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2897fb18269c7af0f242ed599b8244c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2897fb18269c7af0f242ed599b8244c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2897fb18269c7af0f242ed599b8244c1 = L.map(
#                 &quot;map_2897fb18269c7af0f242ed599b8244c1&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e752391fea38d418e49e7e145d8301f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2897fb18269c7af0f242ed599b8244c1);
#
#
#             var marker_479585ba4faf07a8561821d4a039eb36 = L.marker(
#                 [43.649738, -79.39119],
#                 {}
#             ).addTo(map_2897fb18269c7af0f242ed599b8244c1);
#
#
#             var icon_4401aaf39dfa8b42422232762033864b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_479585ba4faf07a8561821d4a039eb36.setIcon(icon_4401aaf39dfa8b42422232762033864b);
#
#
#         var popup_34881d1180068d4666c5222979cac604 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_676ffcc1bb3c5d478713b60f3d1f9358 = $(`&lt;div id=&quot;html_676ffcc1bb3c5d478713b60f3d1f9358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_34881d1180068d4666c5222979cac604.setContent(html_676ffcc1bb3c5d478713b60f3d1f9358);
#
#
#
#         marker_479585ba4faf07a8561821d4a039eb36.bindPopup(popup_34881d1180068d4666c5222979cac604)
#         ;
#
#
#
#
#             var marker_6fccf00e26b96dcb3970ac19bb055018 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_2897fb18269c7af0f242ed599b8244c1);
#
#
#             var icon_55ca2bda8d7f781f27c6581f2205d59a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6fccf00e26b96dcb3970ac19bb055018.setIcon(icon_55ca2bda8d7f781f27c6581f2205d59a);
#
#
#         var popup_61e88398fd49af07365a78458820ce9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07f61bf85beadd5b0023b3057e0e01e0 = $(`&lt;div id=&quot;html_07f61bf85beadd5b0023b3057e0e01e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_61e88398fd49af07365a78458820ce9e.setContent(html_07f61bf85beadd5b0023b3057e0e01e0);
#
#
#
#         marker_6fccf00e26b96dcb3970ac19bb055018.bindPopup(popup_61e88398fd49af07365a78458820ce9e)
#         ;
#
#
#
#
#             var marker_f72ef43ff216ce7d092e0d75a9383d75 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_2897fb18269c7af0f242ed599b8244c1);
#
#
#             var icon_783ae6df9573826e2a66fbcda406edc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f72ef43ff216ce7d092e0d75a9383d75.setIcon(icon_783ae6df9573826e2a66fbcda406edc1);
#
#
#         var popup_13fce007a030c7d1da81575416434bbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_faf44d171c38e7e2d2c4192716a7b406 = $(`&lt;div id=&quot;html_faf44d171c38e7e2d2c4192716a7b406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_13fce007a030c7d1da81575416434bbc.setContent(html_faf44d171c38e7e2d2c4192716a7b406);
#
#
#
#         marker_f72ef43ff216ce7d092e0d75a9383d75.bindPopup(popup_13fce007a030c7d1da81575416434bbc)
#         ;
#
#
#
#
#             var marker_7877eea84b004e2011c033f2d5f22fb5 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_2897fb18269c7af0f242ed599b8244c1);
#
#
#             var icon_1a19d203f2e8a0de9d8fc4204849f352 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:3, Type:2, Building: building_22]
# Number of Vehicles:2
# Total Distance: 1276.537
# Total Turns: 8
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b17d1579b98e8374135c0c25961c135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b17d1579b98e8374135c0c25961c135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8b17d1579b98e8374135c0c25961c135 = L.map(
#                 &quot;map_8b17d1579b98e8374135c0c25961c135&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fc407a11ea93fc6992f17c97f1b5acc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b17d1579b98e8374135c0c25961c135);
#
#
#             var marker_068e90c2b50e7c46ddb8bcfbacc53fb7 = L.marker(
#                 [43.649738, -79.39119],
#                 {}
#             ).addTo(map_8b17d1579b98e8374135c0c25961c135);
#
#
#             var icon_10d24acab3dd7bda93bb08750c61b6b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_068e90c2b50e7c46ddb8bcfbacc53fb7.setIcon(icon_10d24acab3dd7bda93bb08750c61b6b5);
#
#
#         var popup_5adcb6cd5b14c3b18e5458031591ea17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_405d0095b8c6d3ac61269219ed791b9e = $(`&lt;div id=&quot;html_405d0095b8c6d3ac61269219ed791b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_5adcb6cd5b14c3b18e5458031591ea17.setContent(html_405d0095b8c6d3ac61269219ed791b9e);
#
#
#
#         marker_068e90c2b50e7c46ddb8bcfbacc53fb7.bindPopup(popup_5adcb6cd5b14c3b18e5458031591ea17)
#         ;
#
#
#
#
#             var marker_9cafc4e58cba9073e3e6da9db26ba887 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_8b17d1579b98e8374135c0c25961c135);
#
#
#             var icon_44ffc6ab16fa8d9af030a0df6fd21dd9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9cafc4e58cba9073e3e6da9db26ba887.setIcon(icon_44ffc6ab16fa8d9af030a0df6fd21dd9);
#
#
#         var popup_9a47ef63b9fd5d270fffb236dbd980e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a76d79cf9e764cf8eda219d4a4385b18 = $(`&lt;div id=&quot;html_a76d79cf9e764cf8eda219d4a4385b18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_9a47ef63b9fd5d270fffb236dbd980e4.setContent(html_a76d79cf9e764cf8eda219d4a4385b18);
#
#
#
#         marker_9cafc4e58cba9073e3e6da9db26ba887.bindPopup(popup_9a47ef63b9fd5d270fffb236dbd980e4)
#         ;
#
#
#
#
#             var marker_928b7590572a8044cfd1cadaeb5c8af8 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_8b17d1579b98e8374135c0c25961c135);
#
#
#             var icon_e1f5259d5028ae5cfd0f9014f6b6a6b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_928b7590572a8044cfd1cadaeb5c8af8.setIcon(icon_e1f5259d5028ae5cfd0f9014f6b6a6b6);
#
#
#         var popup_d0a3e4c698e2ddb5d09b68b7b0e845c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a4f2c9cf78fe0b7528e83a61a679a19 = $(`&lt;div id=&quot;html_8a4f2c9cf78fe0b7528e83a61a679a19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_d0a3e4c698e2ddb5d09b68b7b0e845c3.setContent(html_8a4f2c9cf78fe0b7528e83a61a679a19);
#
#
#
#         marker_928b7590572a8044cfd1cadaeb5c8af8.bindPopup(popup_d0a3e4c698e2ddb5d09b68b7b0e845c3)
#         ;
#
#
#
#
#             var marker_4f22b28b8486190b85716e20a3531e32 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_8b17d1579b98e8374135c0c25961c135);
#
#
#             var icon_f16e874c366e01b89e8d3ee8515c95e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:2, Type:2, Building: building_11]
# Number of Vehicles:1
# Total Distance: 779.506
# Total Turns: 3
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_459cc347aa58174245cf8695b0d03a1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_459cc347aa58174245cf8695b0d03a1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_459cc347aa58174245cf8695b0d03a1e = L.map(
#                 &quot;map_459cc347aa58174245cf8695b0d03a1e&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7606fc53c37a5cbdfbb2e7719e849131 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_459cc347aa58174245cf8695b0d03a1e);
#
#
#             var marker_5d20c56920ef37e8667c982815c8d0b0 = L.marker(
#                 [43.649738, -79.39119],
#                 {}
#             ).addTo(map_459cc347aa58174245cf8695b0d03a1e);
#
#
#             var icon_e1edef8f8d1906f08da87f23e9fb8cf9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5d20c56920ef37e8667c982815c8d0b0.setIcon(icon_e1edef8f8d1906f08da87f23e9fb8cf9);
#
#
#         var popup_27c48f25dbbdcb3531f8b97c6b0f108a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af61ca380eb3e66fa40b800c9c55b8fc = $(`&lt;div id=&quot;html_af61ca380eb3e66fa40b800c9c55b8fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_27c48f25dbbdcb3531f8b97c6b0f108a.setContent(html_af61ca380eb3e66fa40b800c9c55b8fc);
#
#
#
#         marker_5d20c56920ef37e8667c982815c8d0b0.bindPopup(popup_27c48f25dbbdcb3531f8b97c6b0f108a)
#         ;
#
#
#
#
#             var marker_49bd9bb33467f21a13b5d4d86a73ed41 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_459cc347aa58174245cf8695b0d03a1e);
#
#
#             var icon_e7f52a9331e6966ccec67c0551f68def = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_49bd9bb33467f21a13b5d4d86a73ed41.setIcon(icon_e7f52a9331e6966ccec67c0551f68def);
#
#
#         var popup_c6fed09f513d9874ce0104eee7154f80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93b52104119b62d775c9ed5021806e03 = $(`&lt;div id=&quot;html_93b52104119b62d775c9ed5021806e03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_c6fed09f513d9874ce0104eee7154f80.setContent(html_93b52104119b62d775c9ed5021806e03);
#
#
#
#         marker_49bd9bb33467f21a13b5d4d86a73ed41.bindPopup(popup_c6fed09f513d9874ce0104eee7154f80)
#         ;
#
#
#
#
#             var marker_3a2d01ae8382d79f19d8d74945ee1385 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_459cc347aa58174245cf8695b0d03a1e);
#
#
#             var icon_bc5ab9fbe421cff8c32bd3ae1e00b92e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a2d01ae8382d79f19d8d74945ee1385.setIcon(icon_bc5ab9fbe421cff8c32bd3ae1e00b92e);
#
#
#         var popup_afc9e8348798e4f0ddb75982521a6e88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6cda536709128fa17c509dc434d6b25 = $(`&lt;div id=&quot;html_a6cda536709128fa17c509dc434d6b25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_afc9e8348798e4f0ddb75982521a6e88.setContent(html_a6cda536709128fa17c509dc434d6b25);
#
#
#
#         marker_3a2d01ae8382d79f19d8d74945ee1385.bindPopup(popup_afc9e8348798e4f0ddb75982521a6e88)
#         ;
#
#
#
#
#             var marker_c70fb1abca16a914ea390e9b8bff8c52 = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_459cc347aa58174245cf8695b0d03a1e);
#
#
#             var icon_cbb024cc49446f2470efda3eae70335a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %% [markdown]
# As you can see, the results generated by the Firefly algorithm produce routes with fewer turns, as a penalty was applied to the cost function based on the number of turns in a route.
