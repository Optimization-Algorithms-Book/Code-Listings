# %% [markdown]
# # Emergency Vehicle Dispatch and Routing
#
# **Citation:** Aswin Raj Giri, Tianjian Chen, Vishnu Priya Rajendran and Alaa Khamis, "A Metaheuristic Approach to Emergency Vehicle Dispatch and Routing," IEEE International Conference on Smart Mobility, 2022.
#
# **Abstract:** Accidents and emergency situations have been on a constant rise, especially during the COVID-19 pandemic. Typically, the emergency vehicle dispatch and routing problems involve various dynamic factors which make them very different from conventional vehicle routing problems. This paper presents a metaheuristic approach to emergency vehicle dispatch and routing. Dispatching aims at allotting and sending the nearby available vehicle to the location of emergency and routing deals with selecting the ideal route to reach the destination. The objective is to minimize incident response time and the total time travel for the vehicle from the dispatch point to the destination. This usually depends on the emergency service vehicle availability and other dynamic factors such as traffic, number of turns in the route, etc. Three different bio-inspired algorithms, namely, ant colony optimization, adaptive ACO and firefly algorithm are investigated. Performance evaluation shows that firefly algorithm outperforms the other algorithms in terms of cost, number of turns, and run time for the given data set. However, in case of larger datasets and multiple variables if involved, adaptive ACO gives better results but takes longer time.

# %% [markdown]
# ### Problem definition
#
# Minimize: $\sum_{l=1}^{3}a_l\sum_{i=1}^{N}\sum_{j=W^i}^{}x_{ij}t_{ij}(t)$
#
# Subject to:
#
# All emergency vehicles are available at their location
#
# $\sum P(availability Of Emergency Vehicle) =1$ :
#
# The final severity of the vehicle that is dispatched will be equal to the required severity. For example, if the destination needs a vehicle of high severity, then we can send either 2 medium severity vehicles or one medium and 2 low severity vehicles.
#
# $ \sum_{1}^{}Severity(final Vehicle To Be Dispatched)= \sum_{1}^{N}Severity Of Each Vehicle$
#
# Where
#
# $N$ = total number of vehicles dispatched
#
# $a_l$ is weight of each emergency level
#
# $N$ is the number of emergency vehicle needed
#
# $W^i$ is incidents in location $W$ waiting for assistance with level i
#
# $x_{ij}$ is 1 if a vehicle $i$ is dispatched to an incident and 0 otherwise
#
# $t_{ij}$ is time cost for vehicle $i$ to arrive at incident $j$
#
# $\sum_{i=1}^{N}x_{ij}=1 \;  \forall j\in W^0, W^1, W^2$

# %% [markdown]
# ### Datasets
# 1. 50 buildings in the area surrouding the University of Toronto were selected as destinations, or "points of emergency".
# 2. The real locations of **8** fire stations, **5** police stations, and **10** hospitals in that area were selected as vehicle depots for various types of emergency vehicles (fire trucks, police cars, ambulances).
#
# ### Constraints
# 1. Only one request at a time.
# 2. Emergency sites have an associated "emergency level" and emergency vehicles have a "capacity" to satisfy those levels. Emergency sites can only be satisfied by a vehicle of an equal or higher capacity, or by multiple vehicles whose sum meets or exceeds the emergency site's emergency level.
# 3. The three emergency levels are **high**, **medium**, and **low**.
# 4. All emergency vehicles are initialized at their starting depot.

# %% [markdown]
# ### Common Functions and Classes

# %%
import osmnx
from optalgotools.structures import Node
from optalgotools.routing import randomized_search
import math
import random
from tqdm.notebook import tqdm
import osmnx as ox
from numpy.random import choice as weighted_choice
import pandas as pd
import itertools
from copy import copy, deepcopy
import folium

# %% [markdown]
# ### Route length
#
# This function calculaute the route length

# %%
def cost(G, route):
    weight = 0
    for u, v in zip(route, route[1:]):
        weight += G[u][v][0]['length']   
    return round(weight,4)

# %% [markdown]
# ### Probability
#
# This function returns true with probability p.

# %%
def probability(p):
    return p > random.uniform(0.0, 1.0)

# %% [markdown]
# ### Generate solutions by corssover

# %%
def cross_over(route_1, route_2):
    origin = route_1[0]
    destination = route_1[len(route_1) - 1]

    intersection = [*itertools.filterfalse(\
                    lambda element : element in [origin, destination] ,\
                    list(set(route_1) & set(route_2)))]
    
    if len(intersection) == 0: return route_1 # if there is not common node, just return the first route

    cross_over_point = random.choice(intersection)
    first_point = route_1.index(cross_over_point)
    second_point = route_2.index(cross_over_point)

    if probability(0.5):
        return route_1[:first_point] + route_2[second_point:]
    else:
        return route_2[:second_point] + route_1[first_point:]

# %% [markdown]
# ### Haversine distance
#
# This function Haversine distance between two points of interest given their GPS coordiante (lat and long)

# %%
def haversine_distance(lon1, lat1, lon2, lat2):
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 

    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %% [markdown]
# ### Turns in a route
#
# This function calculates the number of turns in a route between two nodes as the number of unique street ids - 1.

# %%
# Determines the number of turns in a route between two locations

def turns(G,route):
    roads = []
    for i in range(0,len(route)-1):
        way =G[route[i]][route[i+1]]
        roads.append(str(way[0]['osmid']))
    roads = len(set(roads))
    turn = roads -1
    return turn

# %% [markdown]
# ### Closest node
#
# This function looks for the OSMID of the closest node in an OSMNX graph for a given geocode.

# %%
def closest_node_osmid(G, lat, lng):
    id = ox.distance.nearest_nodes(G,lng,lat)
    return Node(G,id)

# %% [markdown]
# ### Emergency class

# %%
class Emergency:
    def __init__(self, building, level, type):
        self.level = level
        self.type = type
        self.building = building
    
    def __repr__(self):
        return f"[Level:{self.level}, Type:{self.type}, Building: {self.building.name}]"

# %% [markdown]
# ### Vehicle class

# %%
class Vehicle:
    def __init__(self, name, capacity, vehicle_type, location):
        self.name = name
        self.capacity = capacity
        self.vehicle_type = vehicle_type
        self.location = location

    def __repr__(self):
        return f"[Name:{self.name}, Type:{self.vehicle_type}, Capacity: {self.capacity}, Location: {self.location}]"

# %% [markdown]
# ### Building class

# %%
class Building:
    def __init__(self, name, lat, lng, level):
        self.name = name
        self.location = (lat, lng)
        self.level = level

# %% [markdown]
# ### Problem class

# %%
class EmergencyRouting:
    vehicles = []
    locations = []
    emergencies = []
    results = []

    def __init__(self):
        self.load_vehicles()
        self.load_buildings()

    def load_vehicles(self, filename="emergency_vehicle_location.csv"):
        df = pd.read_csv(filename)
        for index, row in df.iterrows():
            self.vehicles.append(
                Vehicle(
                    row.name,
                    row.casualities_expected_to_treat,
                    row.vehicle_type,
                    (row.vehicle_lat, row.vehicle_lng),
                )
            )

    def load_buildings(self, filename="building_location.csv"):
        df = pd.read_csv(filename)
        for index, row in df.iterrows():
            self.locations.append(
                Building(
                    row.building_name,
                    row.building_lat,
                    row.building_lng,
                    row.casualities_expected,
                )
            )

    def generate_emergencies(self, num_emergencies, allow_repeat_building=False):
        results = []
        buildings = copy(self.locations)
        for i in range(num_emergencies):
            # Select a random emergency level, weighted towards less severe ones
            e_level = weighted_choice([1, 2, 3], 1, [0.5, 0.3, 0.2])[0]
            # Select a random emergency type
            e_type = random.choice([1, 2, 3])
            # Select a random building
            if allow_repeat_building:
                e_building = random.choice(buildings)
            else:
                e_building = buildings.pop(random.randrange(len(buildings)))
            results.append(Emergency(e_building, e_level, e_type))
        self.emergencies = results

    def route(self, G, vehicles, destination, algorithm):
        routes = []
        destination_node = closest_node_osmid(G, destination[0], destination[1])
        for v in vehicles:
            origin_node = closest_node_osmid(G, v.location[0], v.location[1])
            route = algorithm.run(G, origin_node, destination_node)
            routes.append(route)

            # Update vehicle location
            v.location = (destination[0], destination[1])
            self.vehicles[self.vehicles.index(v)] = v

        return routes

    # Takes the next emergency and assigns vehicles to be dispatched
    def dispatch(self):
        dispatched = []
        emergency = self.emergencies.pop(0)
        level = emergency.level

        # Filter to only keep relevant vehicles
        available_vehicles = [
            v for v in self.vehicles if v.vehicle_type == emergency.type
        ]
        available_vehicles = sorted(
            available_vehicles,
            key=lambda x: haversine_distance(
                emergency.building.location[1],
                emergency.building.location[0],
                x.location[1],
                x.location[0],
            ),
        )
        while level > 0:
            current = available_vehicles.pop(0)
            dispatched.append(current)
            level -= current.capacity

        results = copy(dispatched)
        dispatched.reverse()
        if level < 0:
            # Try to remove some vehicles
            for v in dispatched:
                if level + v.capacity <= 0:
                    results.pop(results.index(v))
                    level += v.capacity
                if level == 0:
                    break

        return emergency, results

    def visualize(self, G, result):

        print(result["emergency"])
        print(f"Number of Vehicles:{len(result['active_vehicles'])}")
        print(f"Total Distance: {sum([cost(G,r) for r in result['routes']])}")
        print(f"Total Turns: {sum([turns(G,r) for r in result['routes']])}")
        icons = ["fire-extinguisher", "gavel", "ambulance"]
        v_colors = ["red", "blue", "green"]
        m = folium.Map((43.654589, -79.389229), zoom_start=10)
        # Vehicle Markers
        for v in result["vehicle"]:
            color = (
                v_colors[v.vehicle_type - 1]
                if v.name in result["active_vehicles"]
                else "gray"
            )
            folium.Marker(
                location=v.location,
                icon=folium.Icon(
                    color=color, 
                    icon=icons[v.vehicle_type - 1], 
                    prefix="fa"
                ),
                popup=f"Capacity: {v.capacity}"
            ).add_to(m)


        # Destination Marker
        folium.Marker(
            location=result["emergency"].building.location,
            icon=folium.Icon(color="orange", icon="exclamation", prefix="fa"),
            popup=f"Level: {result['emergency'].level}"
        ).add_to(m)
        
        # Routes
        for r in result['routes']:
            ox.plot_route_folium(G,r,m)
        return m

    def run(self, G, num_emergencies, allow_repeat_locations):

        # Generate emergencies
        self.generate_emergencies(num_emergencies, allow_repeat_locations)
        

    def next(self, algorithm):
        if len(self.emergencies) == 0:
            return "No more emergencies to respond to."
        # Dispatch
        emergency, vehicles = self.dispatch()
        result_obj = {
            "emergency": emergency,
            "vehicle": deepcopy(self.vehicles),
            "active_vehicles": [x.name for x in vehicles]
        }

        # Route
        routes = self.route(G, vehicles, emergency.building.location, algorithm)
        result_obj["routes"] = routes
        return self.visualize(G, result_obj)

# %% [markdown]
# ### Dispatching
#
# Vehicles are dispatched as follows:
# 1. The list of all vehicles is filtered to remove any vehicles that do not match the emergency type. For example, ambulances will not be considered when responding to a fire call.
# 2. The Haversine distance between the remaining vehicles and the emergency location is determined, and the list is sorted in ascending order.
# 3. Vehicles are added to the dispatch list until the severity level of the emergency is satisfied. If the final level of the dispatched fleet is greater than what is required, we will try to remove low level vehicles to match the emergency level perfectly.
#
#     For example:<br>
#         If there is an emergency of level 3, and the closest vehicles are:<br>
#         &nbsp;&nbsp;**A (level 1):** 2 km away<br>
#         &nbsp;&nbsp;**B (level 1):** 4 km away<br>
#         &nbsp;&nbsp;**C (level 3):** 6 km away<br>
#         The dispatching algorithm will select all 3 vehicles (A, B, C), but then remove both A and B as they are not required to respond to the emergency.

# %% [markdown]
# ## Initailization

# %%
# Initialize problem
problem = EmergencyRouting()
G = osmnx.graph_from_address("University Of Toronto", dist=3000, network_type="drive_service")

# Initialize some parameters
num_emergencies = 9
allow_repeat_locations = False

problem.run(G, num_emergencies, allow_repeat_locations)

# %% [markdown]
# ## Emergency vehicle dispatching and routing using ACO

# %% [markdown]
# #### ACO class

# %%
class ACO:
    def __init__(self, alpha=2, beta=2, n=500, Q=1):
        self.alpha = alpha
        self.beta = beta
        self.n = n
        self.Q = Q

    def pheremone(self, level, distance):
        return level ** self.alpha * ((1/distance)) ** self.beta

    def run(self, G, origin, destination):
        # randomize the pheromones
        pheremone_concentrations = {(u,v):random.uniform(0,0.5) for [u,v] in G.edges()}
        known_routes = dict()

        for ant in tqdm(range(self.n)):
            # Place the ant at the colony
            frontier = [origin]
            explored = set()
            route = []
            found = False

            while frontier and not found:
                parent = frontier.pop(0)
                explored.add(parent)

                children = []
                children_pheremones = []
                for child in parent.expand():
                    # If we see the destination, ignore all pheremones
                    if child == destination:
                        found = True
                        route = child.path()
                        continue
                    if child not in explored:
                        children.append(child)
                        children_pheremones.append(
                            self.pheremone(
                                pheremone_concentrations[(parent.osmid, child.osmid)],
                                child.distance
                            )
                        )

                if len(children) == 0:
                    continue  # The ant is stuck, go back.

                transition_probability = [
                    children_pheremones[i] / sum(children_pheremones)
                    for i in range(len(children_pheremones))
                ]

                # Probabilistically choose a child to explore based weighted by transition probability
                chosen = random.choices(children, weights=transition_probability, k=1)[0]

                # Add all the non-explored children in case we need to explore them later
                children.pop(children.index(chosen))
                frontier.extend(children)

                # Set the chosen child to be the next node to explore
                frontier.insert(0, chosen)
            
            # We now have a completed route, we can increase pheremone levels 
            # on that route for the next ant to detect.

            for u, v in zip(route[:-1], route[1:]):
                length_of_edge = G[u][v][0]['length']
                pheremone_concentrations[(u,v)] += self.Q/length_of_edge
            
            # If the route is newly discovered, add it to the list
            route = tuple(route)
            if route in known_routes:
                known_routes[route] += 1
            else:
                known_routes[route] = 1
        return list(max(known_routes, key=known_routes.get))

# %% [markdown]
# #### Results and Visualization

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:3, Type:1, Building: building_23]
# Number of Vehicles:2
# Total Distance: 3220.246
# Total Turns: 35
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f320849868f29f516e5dc507dc1cdbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f320849868f29f516e5dc507dc1cdbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9f320849868f29f516e5dc507dc1cdbb = L.map(
#                 &quot;map_9f320849868f29f516e5dc507dc1cdbb&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db779836199467f6efbb7c096ca880c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f320849868f29f516e5dc507dc1cdbb);
#
#
#             var marker_c1934fee8fe5c241bf87e3e317384d48 = L.marker(
#                 [43.64866834, -79.38967358],
#                 {}
#             ).addTo(map_9f320849868f29f516e5dc507dc1cdbb);
#
#
#             var icon_22767b247974691bf7056da2c9b99108 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c1934fee8fe5c241bf87e3e317384d48.setIcon(icon_22767b247974691bf7056da2c9b99108);
#
#
#         var popup_e902e00768e3554b350f29ec1614eca5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42471332683a5860c946c6e2146152f5 = $(`&lt;div id=&quot;html_42471332683a5860c946c6e2146152f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_e902e00768e3554b350f29ec1614eca5.setContent(html_42471332683a5860c946c6e2146152f5);
#
#
#
#         marker_c1934fee8fe5c241bf87e3e317384d48.bindPopup(popup_e902e00768e3554b350f29ec1614eca5)
#         ;
#
#
#
#
#             var marker_6d520ac32242dd26dafb612df15ecb4d = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_9f320849868f29f516e5dc507dc1cdbb);
#
#
#             var icon_c9ee3b9608d9ae6a2f8f75ebea029d30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6d520ac32242dd26dafb612df15ecb4d.setIcon(icon_c9ee3b9608d9ae6a2f8f75ebea029d30);
#
#
#         var popup_862235cfe2b4e6a0d6b5fe37ac6c4f3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8d650d00337af455e32175578aa0464 = $(`&lt;div id=&quot;html_d8d650d00337af455e32175578aa0464&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_862235cfe2b4e6a0d6b5fe37ac6c4f3f.setContent(html_d8d650d00337af455e32175578aa0464);
#
#
#
#         marker_6d520ac32242dd26dafb612df15ecb4d.bindPopup(popup_862235cfe2b4e6a0d6b5fe37ac6c4f3f)
#         ;
#
#
#
#
#             var marker_014717a653bd09cf359dd58974da6b84 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_9f320849868f29f516e5dc507dc1cdbb);
#
#
#             var icon_9b6ebbb4f56530f5678a27123ebc82af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_014717a653bd09cf359dd58974da6b84.setIcon(icon_9b6ebbb4f56530f5678a27123ebc82af);
#
#
#         var popup_2191efbf167b6aa5f01b9c6efa080dfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a4252da37c4e9b3ba2ffb1dae682f98 = $(`&lt;div id=&quot;html_0a4252da37c4e9b3ba2ffb1dae682f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_2191efbf167b6aa5f01b9c6efa080dfa.setContent(html_0a4252da37c4e9b3ba2ffb1dae682f98);
#
#
#
#         marker_014717a653bd09cf359dd58974da6b84.bindPopup(popup_2191efbf167b6aa5f01b9c6efa080dfa)
#         ;
#
#
#
#
#             var marker_e34f6794a477a5ca322ab1f3f09d9aff = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_9f320849868f29f516e5dc507dc1cdbb);
#
#
#             var icon_9db24b95200bbe9ca58355fc1f45d5fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:3, Type:1, Building: building_45]
# Number of Vehicles:3
# Total Distance: 7213.963
# Total Turns: 70
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_114e9f3732c5fa8fcca97dc3b2596ac7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_114e9f3732c5fa8fcca97dc3b2596ac7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_114e9f3732c5fa8fcca97dc3b2596ac7 = L.map(
#                 &quot;map_114e9f3732c5fa8fcca97dc3b2596ac7&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43ed70fdb3049f12c0cde8151405b631 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_114e9f3732c5fa8fcca97dc3b2596ac7);
#
#
#             var marker_d340e6c60e89bd08ec0720c4f54771c8 = L.marker(
#                 [43.656724, -79.375452],
#                 {}
#             ).addTo(map_114e9f3732c5fa8fcca97dc3b2596ac7);
#
#
#             var icon_cae538c4b27da312cc4670118f23dde8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d340e6c60e89bd08ec0720c4f54771c8.setIcon(icon_cae538c4b27da312cc4670118f23dde8);
#
#
#         var popup_64f9823d0a644730ad1ad1536794e804 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23957b7017891789b7b5c80c0ca9bcda = $(`&lt;div id=&quot;html_23957b7017891789b7b5c80c0ca9bcda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_64f9823d0a644730ad1ad1536794e804.setContent(html_23957b7017891789b7b5c80c0ca9bcda);
#
#
#
#         marker_d340e6c60e89bd08ec0720c4f54771c8.bindPopup(popup_64f9823d0a644730ad1ad1536794e804)
#         ;
#
#
#
#
#             var marker_951c01a6489210a79ef442b8c1689a25 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_114e9f3732c5fa8fcca97dc3b2596ac7);
#
#
#             var icon_2d53cf54f6cc83a4cbda6a8e0db1928c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_951c01a6489210a79ef442b8c1689a25.setIcon(icon_2d53cf54f6cc83a4cbda6a8e0db1928c);
#
#
#         var popup_8d5889993c952e30e6782db029c6aced = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5c9312f9deb665766bcd84fa5647ba7 = $(`&lt;div id=&quot;html_e5c9312f9deb665766bcd84fa5647ba7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_8d5889993c952e30e6782db029c6aced.setContent(html_e5c9312f9deb665766bcd84fa5647ba7);
#
#
#
#         marker_951c01a6489210a79ef442b8c1689a25.bindPopup(popup_8d5889993c952e30e6782db029c6aced)
#         ;
#
#
#
#
#             var marker_40ccd1085791539ebdb005cc54bdeeb7 = L.marker(
#                 [43.65691835, -79.40467807],
#                 {}
#             ).addTo(map_114e9f3732c5fa8fcca97dc3b2596ac7);
#
#
#             var icon_87c3ed0772b577eca291ecf247869fd9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_40ccd1085791539ebdb005cc54bdeeb7.setIcon(icon_87c3ed0772b577eca291ecf247869fd9);
#
#
#         var popup_85bd459e3db5d1b19b86ab36de2642d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19841ec21bd2fd3d4e3fa98c605f2568 = $(`&lt;div id=&quot;html_19841ec21bd2fd3d4e3fa98c605f2568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_85bd459e3db5d1b19b86ab36de2642d4.setContent(html_19841ec21bd2fd3d4e3fa98c605f2568);
#
#
#
#         marker_40ccd1085791539ebdb005cc54bdeeb7.bindPopup(popup_85bd459e3db5d1b19b86ab36de2642d4)
#         ;
#
#
#
#
#             var marker_a674bf99e20a4c35f417e7c7e97414dc = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_114e9f3732c5fa8fcca97dc3b2596ac7);
#
#
#             var icon_9d3a295745355c729e01f0351b13b01a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot

# %%
problem.next(ACO())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [Level:2, Type:1, Building: building_50]
# Number of Vehicles:1
# Total Distance: 1205.834
# Total Turns: 11
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba4250de1e26794c3d496d8a6a6b3b66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba4250de1e26794c3d496d8a6a6b3b66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba4250de1e26794c3d496d8a6a6b3b66 = L.map(
#                 &quot;map_ba4250de1e26794c3d496d8a6a6b3b66&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_626fb18ef776733eeabeeba387e2bc6f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba4250de1e26794c3d496d8a6a6b3b66);
#
#
#             var marker_57705bf30800fd72ed99a2a56302a485 = L.marker(
#                 [43.656724, -79.375452],
#                 {}
#             ).addTo(map_ba4250de1e26794c3d496d8a6a6b3b66);
#
#
#             var icon_eb788444117bb83edf20923f668bb6dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_57705bf30800fd72ed99a2a56302a485.setIcon(icon_eb788444117bb83edf20923f668bb6dc);
#
#
#         var popup_5fd3d71346e6b1f7eaca40fcd817cef8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6be2d75cede2b9fe60aada472f630eab = $(`&lt;div id=&quot;html_6be2d75cede2b9fe60aada472f630eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_5fd3d71346e6b1f7eaca40fcd817cef8.setContent(html_6be2d75cede2b9fe60aada472f630eab);
#
#
#
#         marker_57705bf30800fd72ed99a2a56302a485.bindPopup(popup_5fd3d71346e6b1f7eaca40fcd817cef8)
#         ;
#
#
#
#
#             var marker_798f80434596923112b4008af173bc47 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_ba4250de1e26794c3d496d8a6a6b3b66);
#
#
#             var icon_785fa55802b57759eb6230cc291f1fa8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_798f80434596923112b4008af173bc47.setIcon(icon_785fa55802b57759eb6230cc291f1fa8);
#
#
#         var popup_b8580d01083cd9dc2074c93bcc7c62a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd554a926b57b8c9fb2d4d801eae868d = $(`&lt;div id=&quot;html_bd554a926b57b8c9fb2d4d801eae868d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_b8580d01083cd9dc2074c93bcc7c62a8.setContent(html_bd554a926b57b8c9fb2d4d801eae868d);
#
#
#
#         marker_798f80434596923112b4008af173bc47.bindPopup(popup_b8580d01083cd9dc2074c93bcc7c62a8)
#         ;
#
#
#
#
#             var marker_1977175c621465cf0a88718858c22779 = L.marker(
#                 [43.652578, -79.398673],
#                 {}
#             ).addTo(map_ba4250de1e26794c3d496d8a6a6b3b66);
#
#
#             var icon_99f832d5bb3fd2a54d263250c282ad83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1977175c621465cf0a88718858c22779.setIcon(icon_99f832d5bb3fd2a54d263250c282ad83);
#
#
#         var popup_329b6690d59a0b66061f87e7f3f57355 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8171f42542836b12341c2798781faf8 = $(`&lt;div id=&quot;html_f8171f42542836b12341c2798781faf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_329b6690d59a0b66061f87e7f3f57355.setContent(html_f8171f42542836b12341c2798781faf8);
#
#
#
#         marker_1977175c621465cf0a88718858c22779.bindPopup(popup_329b6690d59a0b66061f87e7f3f57355)
#         ;
#
#
#
#
#             var marker_946baae81c110f745d5d2279b50ef26a = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_ba4250de1e26794c3d496d8a6a6b3b66);
#
#
#             var icon_ea2ebe327d6ae79fb8169b1afd3b7fe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &

# %% [markdown]
# As you can see from the above three examples, the ACO solver does not take into account the number of turns in a route, as pheremones are deposited on node-to-node edges. Since the scoring of routes in ACO is the sum of individual scores, we cannot penalize excess turns.

# %% [markdown]
# ## Emergency vehicle dispatching and routing using Firefly Algorithm

# %% [markdown]
# #### Firefly Algorithm Class

# %%
class Firefly:
    def __init__(self, num_iterations=15, pop_size=100, gamma=2, k=100):
        self.num_iterations = num_iterations
        self.pop_size = pop_size
        self.gamma = gamma 
        self.k = k

    # Cost as length + complexity of route
    def turns(G,route):
        roads = []
        for i in range(0,len(route)-1):
            way =G[route[i]][route[i+1]]
            roads.append(str(way[0]['osmid']))
        roads = len(set(roads))
        turn = roads -1
        return turn

    def luminosity(self, G, route):
        
        return cost(G,route) + self.k*turns(G,route)

    # Define the distance between two routes as the number of common nodes they possess
    def distance(self, route1,route2):
        return len(set(route1) & set(route2))
    
    def run(self, G, origin, destination):
        # Initialize population
        flies = [randomized_search(G,origin.osmid, destination.osmid) for _ in range(self.pop_size)]

        for _ in tqdm(range(self.num_iterations)):
            for i in range(self.pop_size):
                flies_luminosity = list()  # for all flies except i
                for j in range(self.pop_size):
                    if i == j:
                        continue
                    flies_luminosity.append((j, self.luminosity(G, flies[j])))
                moving_fly = flies[i]
                # Using min here as the "most" luminous is the one with lowest cost + complexity
                target_fly = min(
                    flies_luminosity,
                    key=lambda fly: fly[1]
                    * math.exp(-1 * self.gamma * self.distance(moving_fly, flies[fly[0]]))
                )
                target_fly = flies[target_fly[0]]
                # update the position, moving is just a crossover
                flies[i] = cross_over(target_fly,moving_fly)

        return min(flies, key=lambda fly: self.luminosity(G,fly))

# %% [markdown]
# #### Results and Visualization

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:1, Type:1, Building: building_38]
# Number of Vehicles:1
# Total Distance: 608.209
# Total Turns: 8
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed1bc7854c4c6376f049a1135bfd85c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed1bc7854c4c6376f049a1135bfd85c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ed1bc7854c4c6376f049a1135bfd85c4 = L.map(
#                 &quot;map_ed1bc7854c4c6376f049a1135bfd85c4&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ada2773a503d30eaf526cdc0eba87cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed1bc7854c4c6376f049a1135bfd85c4);
#
#
#             var marker_9634221b86d09a1d0576ea4cb4aae84b = L.marker(
#                 [43.65318, -79.368843],
#                 {}
#             ).addTo(map_ed1bc7854c4c6376f049a1135bfd85c4);
#
#
#             var icon_2e8552fe378154aab0e9e3e75ca5bbde = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9634221b86d09a1d0576ea4cb4aae84b.setIcon(icon_2e8552fe378154aab0e9e3e75ca5bbde);
#
#
#         var popup_bdd05c66b9d0c19c396a0549eeeca8d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b8da64c0988ec9833b40fedecf33273 = $(`&lt;div id=&quot;html_3b8da64c0988ec9833b40fedecf33273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_bdd05c66b9d0c19c396a0549eeeca8d1.setContent(html_3b8da64c0988ec9833b40fedecf33273);
#
#
#
#         marker_9634221b86d09a1d0576ea4cb4aae84b.bindPopup(popup_bdd05c66b9d0c19c396a0549eeeca8d1)
#         ;
#
#
#
#
#             var marker_687b07a78192017202a199af44f69b04 = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_ed1bc7854c4c6376f049a1135bfd85c4);
#
#
#             var icon_4ce32fd197b04e183002556b4b9c8c7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_687b07a78192017202a199af44f69b04.setIcon(icon_4ce32fd197b04e183002556b4b9c8c7a);
#
#
#         var popup_71a6d7c6ebef2df92d75f67886f5d082 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bcc4e5d92794166d5f362cef6d12ed6 = $(`&lt;div id=&quot;html_1bcc4e5d92794166d5f362cef6d12ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_71a6d7c6ebef2df92d75f67886f5d082.setContent(html_1bcc4e5d92794166d5f362cef6d12ed6);
#
#
#
#         marker_687b07a78192017202a199af44f69b04.bindPopup(popup_71a6d7c6ebef2df92d75f67886f5d082)
#         ;
#
#
#
#
#             var marker_c8eaa079ce80e913b632866ca878f15d = L.marker(
#                 [43.652578, -79.398673],
#                 {}
#             ).addTo(map_ed1bc7854c4c6376f049a1135bfd85c4);
#
#
#             var icon_c65401b172ea0148e9da42b32cb09c96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c8eaa079ce80e913b632866ca878f15d.setIcon(icon_c65401b172ea0148e9da42b32cb09c96);
#
#
#         var popup_93f717f5bab8f4244235d9acf114680c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc4a2c79ec6c63d6bb42342244c7bf17 = $(`&lt;div id=&quot;html_fc4a2c79ec6c63d6bb42342244c7bf17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_93f717f5bab8f4244235d9acf114680c.setContent(html_fc4a2c79ec6c63d6bb42342244c7bf17);
#
#
#
#         marker_c8eaa079ce80e913b632866ca878f15d.bindPopup(popup_93f717f5bab8f4244235d9acf114680c)
#         ;
#
#
#
#
#             var marker_34c45bf2983edcbaa75057300f45a98b = L.marker(
#                 [43.67193998, -79.38897056],
#                 {}
#             ).addTo(map_ed1bc7854c4c6376f049a1135bfd85c4);
#
#
#             var icon_3e683f14d7d60be06dcc6c0cbeb79244 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &q

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:1, Type:2, Building: building_28]
# Number of Vehicles:1
# Total Distance: 841.971
# Total Turns: 7
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98524a4a478a09ffa15b5b59263443a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98524a4a478a09ffa15b5b59263443a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_98524a4a478a09ffa15b5b59263443a4 = L.map(
#                 &quot;map_98524a4a478a09ffa15b5b59263443a4&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9cc9ddf6095c80d389323505ea62c13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98524a4a478a09ffa15b5b59263443a4);
#
#
#             var marker_707e23d18051a2429e8637f64c901484 = L.marker(
#                 [43.65318, -79.368843],
#                 {}
#             ).addTo(map_98524a4a478a09ffa15b5b59263443a4);
#
#
#             var icon_72a6df53fd928bca3261d1f7ef4bd5cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_707e23d18051a2429e8637f64c901484.setIcon(icon_72a6df53fd928bca3261d1f7ef4bd5cc);
#
#
#         var popup_6b0789c075a4a6d549fbdb5239288622 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8342ba03bb4fe0c8a3b0919240ac2d1b = $(`&lt;div id=&quot;html_8342ba03bb4fe0c8a3b0919240ac2d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_6b0789c075a4a6d549fbdb5239288622.setContent(html_8342ba03bb4fe0c8a3b0919240ac2d1b);
#
#
#
#         marker_707e23d18051a2429e8637f64c901484.bindPopup(popup_6b0789c075a4a6d549fbdb5239288622)
#         ;
#
#
#
#
#             var marker_f29dd61920893682cbc076dda9a8e8fb = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_98524a4a478a09ffa15b5b59263443a4);
#
#
#             var icon_c359da6d42aa827982a969adedcd2962 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f29dd61920893682cbc076dda9a8e8fb.setIcon(icon_c359da6d42aa827982a969adedcd2962);
#
#
#         var popup_87847f3f72d811e23775372a743601e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c70e5760a969787fbad15f398cdd537 = $(`&lt;div id=&quot;html_1c70e5760a969787fbad15f398cdd537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_87847f3f72d811e23775372a743601e5.setContent(html_1c70e5760a969787fbad15f398cdd537);
#
#
#
#         marker_f29dd61920893682cbc076dda9a8e8fb.bindPopup(popup_87847f3f72d811e23775372a743601e5)
#         ;
#
#
#
#
#             var marker_64209ac9a4c420c07dee662373bd40b8 = L.marker(
#                 [43.652578, -79.398673],
#                 {}
#             ).addTo(map_98524a4a478a09ffa15b5b59263443a4);
#
#
#             var icon_7189998a9c14b6fae19e5c96c285f876 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_64209ac9a4c420c07dee662373bd40b8.setIcon(icon_7189998a9c14b6fae19e5c96c285f876);
#
#
#         var popup_75f49b16e10a80c694fc1b4eee23bab8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7850b433f55fc21ec3db9a1f5368f9ad = $(`&lt;div id=&quot;html_7850b433f55fc21ec3db9a1f5368f9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_75f49b16e10a80c694fc1b4eee23bab8.setContent(html_7850b433f55fc21ec3db9a1f5368f9ad);
#
#
#
#         marker_64209ac9a4c420c07dee662373bd40b8.bindPopup(popup_75f49b16e10a80c694fc1b4eee23bab8)
#         ;
#
#
#
#
#             var marker_83937a5f8d5bf044ad5b52b6314a0fe6 = L.marker(
#                 [43.669014, -79.389389],
#                 {}
#             ).addTo(map_98524a4a478a09ffa15b5b59263443a4);
#
#
#             var icon_05b6436cb11308d0e2505274a0e999ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot

# %%
problem.next(Firefly())
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [Level:1, Type:2, Building: building_7]
# Number of Vehicles:1
# Total Distance: 1102.963
# Total Turns: 13
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85dd461e074a305bf61a7630328ab035 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85dd461e074a305bf61a7630328ab035&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_85dd461e074a305bf61a7630328ab035 = L.map(
#                 &quot;map_85dd461e074a305bf61a7630328ab035&quot;,
#                 {
#                     center: [43.654589, -79.389229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3aece7f9e3e82ebeac1378294e3655d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_85dd461e074a305bf61a7630328ab035);
#
#
#             var marker_6f8ff5a4608e57b7d42ccea992a3e0c2 = L.marker(
#                 [43.65318, -79.368843],
#                 {}
#             ).addTo(map_85dd461e074a305bf61a7630328ab035);
#
#
#             var icon_d261fe43616f319042081dd54732413f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6f8ff5a4608e57b7d42ccea992a3e0c2.setIcon(icon_d261fe43616f319042081dd54732413f);
#
#
#         var popup_4de769f5b913ccb0fa1269124aaf07e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2b6b6f0ebaedef3b46b6d2a0d482d2a = $(`&lt;div id=&quot;html_f2b6b6f0ebaedef3b46b6d2a0d482d2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_4de769f5b913ccb0fa1269124aaf07e6.setContent(html_f2b6b6f0ebaedef3b46b6d2a0d482d2a);
#
#
#
#         marker_6f8ff5a4608e57b7d42ccea992a3e0c2.bindPopup(popup_4de769f5b913ccb0fa1269124aaf07e6)
#         ;
#
#
#
#
#             var marker_212b1464acd9247cb4904266cfd9e65c = L.marker(
#                 [43.67231832, -79.37552335],
#                 {}
#             ).addTo(map_85dd461e074a305bf61a7630328ab035);
#
#
#             var icon_b6f1aed0498409eabe1b6e13321b78e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_212b1464acd9247cb4904266cfd9e65c.setIcon(icon_b6f1aed0498409eabe1b6e13321b78e4);
#
#
#         var popup_2304120f7aef1ae108688346bcb09c17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e35d5e984dc5a76156b9bd7b81c44ad5 = $(`&lt;div id=&quot;html_e35d5e984dc5a76156b9bd7b81c44ad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 2&lt;/div&gt;`)[0];
#                 popup_2304120f7aef1ae108688346bcb09c17.setContent(html_e35d5e984dc5a76156b9bd7b81c44ad5);
#
#
#
#         marker_212b1464acd9247cb4904266cfd9e65c.bindPopup(popup_2304120f7aef1ae108688346bcb09c17)
#         ;
#
#
#
#
#             var marker_bd3bcfee3b00d170467f7ee58f5e6d34 = L.marker(
#                 [43.652578, -79.398673],
#                 {}
#             ).addTo(map_85dd461e074a305bf61a7630328ab035);
#
#
#             var icon_2f795af2fe00f1a4ecfa4a599c78bd9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bd3bcfee3b00d170467f7ee58f5e6d34.setIcon(icon_2f795af2fe00f1a4ecfa4a599c78bd9f);
#
#
#         var popup_1ac45dccaf6c783b3df769d9a74dd1ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4330ffc698d9aac5e78bf9e3597ba553 = $(`&lt;div id=&quot;html_4330ffc698d9aac5e78bf9e3597ba553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: 1&lt;/div&gt;`)[0];
#                 popup_1ac45dccaf6c783b3df769d9a74dd1ef.setContent(html_4330ffc698d9aac5e78bf9e3597ba553);
#
#
#
#         marker_bd3bcfee3b00d170467f7ee58f5e6d34.bindPopup(popup_1ac45dccaf6c783b3df769d9a74dd1ef)
#         ;
#
#
#
#
#             var marker_1ec421ff2004b476265e65b64cbbbfb5 = L.marker(
#                 [43.669014, -79.389389],
#                 {}
#             ).addTo(map_85dd461e074a305bf61a7630328ab035);
#
#
#             var icon_d1809f6d135b9e3fe240207c6bcd72ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot

# %% [markdown]
# As you can see, the results generated by the Firefly algorithm produce routes with fewer turns, as a penalty was applied to the cost function based on the number of turns in a route.

# %% [markdown]
# ## Emergency vehicle dispatching and routing using Artificial Bee Colony (ABC) Algorithm

# %% [markdown]
# ### ABC class

# %% [markdown]
# ## Comaprison
