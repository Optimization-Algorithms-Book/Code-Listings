# %% [markdown]
# # Solving Delivery Semi-Truck Routing Problem

# %%
from optalgotools.algorithms import SimulatedAnnealing
from optalgotools.problems import TSP
import numpy as np
import pandas as pd
import osmnx as ox
import networkx as nx
import folium
import folium.plugins

# %% [markdown]
# ## Data Preperation

# %%
# Load list of all walmart locations on Ontario
# Data is available in Appendix B of the book's GitHub repo and can be read directly using URL begins with raw.
wal_df = pd.read_csv("https://raw.githubusercontent.com/Optimization-Algorithms-Book/Code-Listings/main/Appendix%20B/data/TSP/Walmart_ON.csv")

# %%
wal_df.tail(5)
# Out:
#       latitude  longitude                store_number           phone  \
# 148  43.917370 -78.959730  Walmart Supercentre; #3113  (905) 655-0206
# 149  42.270682 -83.010996  Walmart Supercentre; #3114  (519) 969-8121
# 150  42.314048 -82.942432  Walmart Supercentre; #3115  (519) 945-3065
# 151  43.786103 -79.628413  Walmart Supercentre; #1081  (905) 851-4648
# 152  43.115150 -80.734587  Walmart Supercentre; #3120  (519) 539-5120
#
#                 address        city Province postal_code
# 148   4100 Baldwin St S      Whitby       ON     L1R 3H8
# 149    3120 Dougall Ave     Windsor       ON     N9E 1S7
# 150  7100 Tecumseh Rd E     Windsor       ON     N8T 1E6
# 151         8300 Hwy 27  Woodbridge       ON     L4H 0R9
# 152     499 Norwich Ave   Woodstock       ON     N4S 9A2

# %%
# City to region mapping from wikipedia
cityToRegion = {
    'Toronto': 'Toronto',
    'Ajax': 'Durham Region',
    'Clarington': 'Durham Region',
    'Brock': 'Durham Region',
    'Oshawa': 'Durham Region',
    'Pickering': 'Durham Region',
    'Scugog': 'Durham Region',
    'Uxbridge': 'Durham Region',
    'Whitby': 'Durham Region',
    'Burlington': 'Halton Region',
    'Halton Hills': 'Halton Region',
    'Milton': 'Halton Region',
    'Oakville': 'Halton Region',
    'Brampton': 'Peel Region',
    'Caledon': 'Peel Region',
    'Mississauga': 'Peel Region',
    'Aurora': 'York Region',
    'East Gwillimbury': 'York Region',
    'Georgina': 'York Region',
    'King': 'York Region',
    'Markham': 'York Region',
    'Newmarket': 'York Region',
    'Richmond Hill': 'York Region',
    'Vaughan': 'York Region',
    'Whitchurch-Stouffville': 'York Region',
    'Mono': 'Dufferin County',
    'Orangeville': 'Dufferin County',
    'Bradford West Gwillimbury': 'Simcoe County',
    'New Tecumseth': 'Simcoe County'
}

# %%
# Selecting cities that are in Durham Region, York Region, or Toronto
cities_list = [city for city, region in cityToRegion.items() if city in wal_df.city.unique() and region in ['Durham Region', 'York Region', 'Toronto']]
print(cities_list)
# Out:
# ['Toronto', 'Ajax', 'Oshawa', 'Pickering', 'Uxbridge', 'Whitby', 'Aurora', 'Markham', 'Newmarket', 'Richmond Hill', 'Vaughan']

# %%
# Select Walmart stores that are in the above list and are Supercentres
gta_part = wal_df[wal_df.store_number.str.startswith('Walmart Supercentre') & wal_df.city.isin(cities_list)].reset_index(drop=True)
wal_gta_count = gta_part.shape[0]
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8

# %%
# Get the lat and long coordinates of the above set of Walmart's and 
# create the graph of roads that connects them that is within 42KM  
gta_part_loc = gta_part[['latitude', 'longitude']]

G = ox.graph_from_point(tuple(gta_part_loc.mean().to_list()), dist=42000, dist_type='network',
                        network_type='drive', clean_periphery=True, simplify=True, retain_all=True, truncate_by_edge=True)

# %%
# Map each walmart to the nearst road on the map and make sure that the distances (in meter) is small (e.g. less than 300m) 
# or otherwise re-evaluate the graph above with a bigger dist
gta_part['osmid'], gta_part['osmid_dist_m'] = zip(*gta_part.apply(lambda row: ox.nearest_nodes(G, row.longitude, row.latitude, return_dist=True), axis = 1))
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code  \
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8
#
#           osmid  osmid_dist_m
# 0     674536269    277.963737
# 1     701911552    246.673809
# 2   10291311614     98.517541
# 3     437952581    189.265679
# 4     699255429     95.426436
# 5    1543685682    119.115062
# 6    1768769491    243.984412
# 7    1360818945    155.728635
# 8     414466395     83.206854
# 9     414461288    133.692850
# 10    428087600    165.561053
# 11     35992100    111.385944
# 12    420576809     88.513525
# 13    253013816     44.449970
# 14     23828442    103.976358
# 15    391917373    155.188839
# 16    391909065     82.203538
# 17   4597575290    135.341559

# %%
# Visualize the Walmart superstores locations on the map
m = folium.Map(location=gta_part_loc.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=False)
for store_ind in range(wal_gta_count):
    folium.Marker(gta_part_loc.values.tolist()[store_ind],  popup=gta_part['store_number'][store_ind], icon=folium.Icon(color='blue', icon="fa-shopping-cart", prefix='fa'),).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee87132ad783453579e155d27bb7d43c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee87132ad783453579e155d27bb7d43c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ee87132ad783453579e155d27bb7d43c = L.map(
#                 &quot;map_ee87132ad783453579e155d27bb7d43c&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70b27f7272adefa59389b4f325dc1579 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ee87132ad783453579e155d27bb7d43c);
#
#
#             var marker_ade99e2dbe5969740657c5df66b6c166 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_ee87132ad783453579e155d27bb7d43c);
#
#
#             var icon_6e09a6c895bd0b3296e12d6f110a1164 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ade99e2dbe5969740657c5df66b6c166.setIcon(icon_6e09a6c895bd0b3296e12d6f110a1164);
#
#
#         var popup_a73959ad2f318d9c74155f46bcc00f7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4b51b57303024de7952d0a80f8ecdc4 = $(`&lt;div id=&quot;html_b4b51b57303024de7952d0a80f8ecdc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #3001&lt;/div&gt;`)[0];
#                 popup_a73959ad2f318d9c74155f46bcc00f7b.setContent(html_b4b51b57303024de7952d0a80f8ecdc4);
#
#
#
#         marker_ade99e2dbe5969740657c5df66b6c166.bindPopup(popup_a73959ad2f318d9c74155f46bcc00f7b)
#         ;
#
#
#
#
#             var marker_deef111748893ff2b92f4d59d0375051 = L.marker(
#                 [44.01501, -79.411176],
#                 {}
#             ).addTo(map_ee87132ad783453579e155d27bb7d43c);
#
#
#             var icon_d32647c6d91e966b9018d860b6ba7e5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_deef111748893ff2b92f4d59d0375051.setIcon(icon_d32647c6d91e966b9018d860b6ba7e5e);
#
#
#         var popup_f617019e1dda98f8f2f285fd1cf98934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc9eaa23f4f3f762b4978592faa9cf23 = $(`&lt;div id=&quot;html_bc9eaa23f4f3f762b4978592faa9cf23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #5778&lt;/div&gt;`)[0];
#                 popup_f617019e1dda98f8f2f285fd1cf98934.setContent(html_bc9eaa23f4f3f762b4978592faa9cf23);
#
#
#
#         marker_deef111748893ff2b92f4d59d0375051.bindPopup(popup_f617019e1dda98f8f2f285fd1cf98934)
#         ;
#
#
#
#
#             var marker_190e777543ed05cf294089ec76ddcfdd = L.marker(
#                 [43.871301, -79.215267],
#                 {}
#             ).addTo(map_ee87132ad783453579e155d27bb7d43c);
#
#
#             var icon_abe626a4aa7cb8cf72582b1318d3c5d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_190e777543ed05cf294089ec76ddcfdd.setIcon(icon_abe626a4aa7cb8cf72582b1318d3c5d5);
#
#
#         var popup_b9c73d380b0d687f4c096d7782b33c6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66c60f5f3373eaaa7e35c8a6af1ef636 = $(`&lt;div id=&quot;html_66c60f5f3373eaaa7e35c8a6af1ef636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #1109&lt;/div&gt;`)[0];
#                 popup_b9c73d380b0d687f4c096d7782b33c6e.setContent(html_66c60f5f3373eaaa7e35c8a6af1ef636);
#
#
#
#         marker_190e777543ed05cf294089ec76ddcfdd.bindPopup(popup_b9c73d380b0d687f4c096d7782b33c6e)
#         ;
#
#
#
#
#             var marker_41d77bee612fffa1837b03790deeee36 = L.marker(
#                 [43.867108, -79.290345],
#                 {}
#             ).addTo(map_ee87132ad783453579e155d27bb7d43c);
#
#
#             var icon_db309be7a29e3dece93dee993def13dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %% [markdown]
# ## Finding the optimal route using SimulatedAnnealing

# %%
# helper function that takes a folium map and plot an antpath based on the route of the osmids 
def draw_route(G, route, m):
    ways_frame = ox.graph_to_gdfs(G)[1]    
    path = []
    for u, v in zip(route[0:], route[1:]):
        try:
            geo = (ways_frame.query(f'u == {u} and v == {v}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        except:
            geo = (ways_frame.query(f'u == {v} and v == {u}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        x, y = m_geo.coords.xy
        points = map(list, [*zip([*y],[*x])])
        path.extend([*points][:-1])

    folium.plugins.AntPath(
        locations = path,
        dash_array=[1, 10],
        delay=1000,
        color='red',
        pulse_color='black'
    ).add_to(m)

    return m

# %%
# A helper function that takes the graph and it creates a map and draw a path between all locations in it 
def draw_map_path(G, path, locations, routes):
    m = folium.Map(location=locations.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=True)

    route = []

    locationlist = locations.values.tolist()
    num_loc = len(locationlist)
    for i in range(num_loc):
        store_id = path[i]

        folium.Marker(location=locationlist[store_id], icon=folium.Icon(color='white', icon_color='white')).add_to(m)
        icon = folium.DivIcon(
            icon_size=(150,36),
            icon_anchor=(12,40),
            html="""<span class="fa-stack " style="font-size: 12pt" >
                    <span class="fa fa-circle-o fa-stack-2x" style="color : blue"></span>
                    <strong class="fa-stack-1x">
                         {:d}
                    </strong>
                </span>""".format(i)
        )
        folium.Marker(location=locationlist[store_id], icon=icon).add_to(m)
        
        if i == 0:
            store_id_1 = path[num_loc-1]
        else:
            store_id_1 = path[i-1]

        shortest_route = routes[store_id_1][store_id]
        
        if i == num_loc-1:
            route.extend(shortest_route)
        else:
            route.extend(shortest_route[:-1])

    draw_route(G, route, m=m)
        
    return m

# %%
# eval the distances between the Walmart locations using the graph
# this code is compatible with networkx 2.6
# # pip install networkx==2.6
gta_part_dists = np.zeros([wal_gta_count, wal_gta_count])
gta_part_pathes = [[[] for i in range(wal_gta_count)] for j in range(wal_gta_count)]
for i in range(wal_gta_count):
    for j in range(wal_gta_count):
        if i==j:
            continue
        gta_part_pathes[i][j] = nx.shortest_path(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length', method='dijkstra')
        gta_part_dists[i][j] = nx.shortest_path_length(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length', method='dijkstra')/1000

# %%
# Create a TSP object for the problem
gta_part_tsp = TSP(dists=gta_part_dists, gen_method='mutate')

# %%
# Create an SA object to help solving the tsp problem
sa = SimulatedAnnealing(max_iter=1000, max_iter_per_temp=100, initial_temp=85, final_temp=0.0001, cooling_schedule='linear', cooling_alpha=0.9)

# %%
# Get an initial random solution and check its length 
sa.init_annealing(gta_part_tsp)
print(sa.s_cur)
print(sa.val_cur)

# assuming store with index #0 has a warehouse and the tour will start and end with it.
ind = sa.s_cur.index(0)
# Out:
# [0, 9, 15, 3, 17, 5, 1, 13, 16, 11, 12, 14, 8, 6, 4, 2, 7, 10, 0]
# 593.8894710000001

# %%
# Draw the path of the random initial solution
# print(len(sa.s_cur[ind:] + sa.s_cur[:ind]))
draw_map_path(G, sa.s_cur[ind:] + sa.s_cur[:ind], gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c77bcfa6305de604e08d8024ea71fc7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c77bcfa6305de604e08d8024ea71fc7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c77bcfa6305de604e08d8024ea71fc7e = L.map(
#                 &quot;map_c77bcfa6305de604e08d8024ea71fc7e&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e34db9284a81ed27e98c885874f0bb4c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var marker_84c4d47e748aa1ac856e09357e28b3d6 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var icon_949692e80f9a66fd04c04e2c9c783d37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_84c4d47e748aa1ac856e09357e28b3d6.setIcon(icon_949692e80f9a66fd04c04e2c9c783d37);
#
#
#             var marker_206a789d5ff52988b9c4851af12e8e55 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var div_icon_caffc70f1ee5e7ae1bd2cbe6ee4e1e6e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_206a789d5ff52988b9c4851af12e8e55.setIcon(div_icon_caffc70f1ee5e7ae1bd2cbe6ee4e1e6e);
#
#
#             var marker_b66ca314c9f374a13d7224253391e779 = L.marker(
#                 [43.877256, -79.409737],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var icon_e7cbeb5c49e86ff0e4baf2e812e948ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b66ca314c9f374a13d7224253391e779.setIcon(icon_e7cbeb5c49e86ff0e4baf2e812e948ad);
#
#
#             var marker_69e80989b5fe8802f17d596db370bb41 = L.marker(
#                 [43.877256, -79.409737],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var div_icon_5d25049e635c3befd0bb1fd4ec199cd8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_69e80989b5fe8802f17d596db370bb41.setIcon(div_icon_5d25049e635c3befd0bb1fd4ec199cd8);
#
#
#             var marker_09fcf5baadd1a69e092282665707035d = L.marker(
#                 [43.795658, -79.530293],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);
#
#
#             var icon_3cf9b15658bdba605f1d1c8e2ea232e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09fcf5baadd1a69e092282665707035d.setIcon(icon_3cf9b15658bdba605f1d1c8e2ea232e4);
#
#
#             var marker_39041c43bc4a0d08e444795dc1a3b208 = L.marker(
#                 [43.795658, -79.530293],
#                 {}
#             ).addTo(map_c77bcfa6305de604e08d8024ea71fc7e);

# %%
# Run SA and eval the best solution distance
sa.run(gta_part_tsp, repetition=10)
print(sa.val_allbest)
print(gta_part_tsp.eval_solution(sa.s_allbest[ind:] + sa.s_allbest[:ind]))
# Out:
# 227.1716330000001
# 227.1716330000001

# %%
# Draw the path
draw_map_path(G, sa.s_allbest[ind:] + sa.s_allbest[:ind], gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b31ebeaf666223c529e1b21ecc36ead3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b31ebeaf666223c529e1b21ecc36ead3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b31ebeaf666223c529e1b21ecc36ead3 = L.map(
#                 &quot;map_b31ebeaf666223c529e1b21ecc36ead3&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e26ba1ee3cae962f67f00fef0b817de = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var marker_87db4eb5a2c45c1c8cd935feb3998fe3 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var icon_c8c9533a1cd5d8aed8f551a8d7554f5d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_87db4eb5a2c45c1c8cd935feb3998fe3.setIcon(icon_c8c9533a1cd5d8aed8f551a8d7554f5d);
#
#
#             var marker_b458fe0a4ffc90e1eb6ef46c8f07390c = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var div_icon_d17b8cc0d4923ad5b6c8928c7092beef = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_b458fe0a4ffc90e1eb6ef46c8f07390c.setIcon(div_icon_d17b8cc0d4923ad5b6c8928c7092beef);
#
#
#             var marker_62b696aa8aae8a8dd41efa22d21fb950 = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var icon_0d608a20b5c3ffadf1cd68243964f500 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62b696aa8aae8a8dd41efa22d21fb950.setIcon(icon_0d608a20b5c3ffadf1cd68243964f500);
#
#
#             var marker_300e20fecb36ebe7811255a6467c8fc8 = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var div_icon_97be4aae34564ec9503bcfdd62597b64 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_300e20fecb36ebe7811255a6467c8fc8.setIcon(div_icon_97be4aae34564ec9503bcfdd62597b64);
#
#
#             var marker_46b4dabfa4215343f4e529f51fb61fae = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
#
#
#             var icon_36b53a91ea8ecca4a8c86e81f96c992d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_46b4dabfa4215343f4e529f51fb61fae.setIcon(icon_36b53a91ea8ecca4a8c86e81f96c992d);
#
#
#             var marker_d2300e78decc446d5597dc189a0a0d51 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_b31ebeaf666223c529e1b21ecc36ead3);
