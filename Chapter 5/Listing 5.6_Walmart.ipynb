# %%
import sys
# adding search_optimization_tools to the system path
sys.path.insert(0, '../')

# %%
from search_optimization_tools.algorithms import SimulatedAnnealing
from search_optimization_tools.problems import TSP
import pandas as pd
import numpy as np
import osmnx as ox
import networkx as nx
import folium
import folium.plugins

# %%
# load list of all walmart locations on Ontario
wal_df = pd.read_csv("../search_optimization_tools/problems/samples/TSP/Walmart_ON.csv")

# %%
# city to region mapping from wikipedia
cityToRegion = {
    'Toronto': 'Toronto',
    'Ajax': 'Durham Region',
    'Clarington': 'Durham Region',
    'Brock': 'Durham Region',
    'Oshawa': 'Durham Region',
    'Pickering': 'Durham Region',
    'Scugog': 'Durham Region',
    'Uxbridge': 'Durham Region',
    'Whitby': 'Durham Region',
    'Burlington': 'Halton Region',
    'Halton Hills': 'Halton Region',
    'Milton': 'Halton Region',
    'Oakville': 'Halton Region',
    'Brampton': 'Peel Region',
    'Caledon': 'Peel Region',
    'Mississauga': 'Peel Region',
    'Aurora': 'York Region',
    'East Gwillimbury': 'York Region',
    'Georgina': 'York Region',
    'King': 'York Region',
    'Markham': 'York Region',
    'Newmarket': 'York Region',
    'Richmond Hill': 'York Region',
    'Vaughan': 'York Region',
    'Whitchurch-Stouffville': 'York Region',
    'Mono': 'Dufferin County',
    'Orangeville': 'Dufferin County',
    'Bradford West Gwillimbury': 'Simcoe County',
    'New Tecumseth': 'Simcoe County'
}

# %%
# selecting cities that are in Durham Region, York Region, or Toronto
cities_list = [city for city, region in cityToRegion.items() if city in wal_df.city.unique() and region in ['Durham Region', 'York Region', 'Toronto']]
print(cities_list)
# Out:
# ['Toronto', 'Ajax', 'Oshawa', 'Pickering', 'Uxbridge', 'Whitby', 'Aurora', 'Markham', 'Newmarket', 'Richmond Hill', 'Vaughan']

# %%
# select walmarts thar are in the above list and is Supercentre
gta_part = wal_df[wal_df.store_number.str.startswith('Walmart Supercentre') & wal_df.city.isin(cities_list)].reset_index(drop=True)
wal_gta_count = gta_part.shape[0]
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8

# %%
# get the lat and long locations of the above set of Walmart's and create the graph of roads that connects them
# that is within 42KM  
gta_part_loc = gta_part[['latitude', 'longitude']]

G = ox.graph_from_point(tuple(gta_part_loc.mean().to_list()), dist=42000, dist_type='network',
                        network_type='drive', clean_periphery=True, simplify=True, retain_all=True, truncate_by_edge=True)

# %%
# map each walmart to the nearst road on the map and make sure that the distances (in meter) is small (e.g. less than 300m) 
# or otherwise re-evaluate the graph above with a bigger dist
gta_part['osmid'], gta_part['osmid_dist_m'] = zip(*gta_part.apply(lambda row: ox.nearest_nodes(G, row.longitude, row.latitude, return_dist=True), axis = 1))
gta_part
# Out:
#      latitude  longitude                       store_number           phone  \
# 0   43.866158 -79.013226         Walmart Supercentre; #3001  (905) 426-6160
# 1   44.015010 -79.411176         Walmart Supercentre; #5778  (905) 841-0300
# 2   43.871301 -79.215267         Walmart Supercentre; #1109  (905) 472-9582
# 3   43.867108 -79.290345         Walmart Supercentre; #3053  (905) 477-6060
# 4   44.066859 -79.484682         Walmart Supercentre; #3062  (905) 853-8811
# 5   43.907599 -78.814547         Walmart Supercentre; #1153  (905) 579-3325
# 6   43.942780 -78.847706         Walmart Supercentre; #3161  (905) 404-6581
# 7   43.880690 -78.881540         Walmart Supercentre; #1056  (905) 438-1400
# 8   43.843959 -79.068945         Walmart Supercentre; #3186  (905) 619-9588
# 9   43.877256 -79.409737         Walmart Supercentre; #3195  (905) 737-3457
# 10  43.841221 -79.415830         Walmart Supercentre; #1116  (905) 747-0628
# 11  43.669418 -79.339249         Walmart Supercentre; #1150  (416) 461-8778
# 12  43.667720 -79.485890         Walmart Supercentre; #1004  (416) 763-7325
# 13  43.757604 -79.488971         Walmart Supercentre; #1139  (416) 633-0854
# 14  43.656318 -79.434930  Walmart Supercentre; #3106; (NOP)  (416) 537-2561
# 15  43.795658 -79.530293  Walmart Supercentre; #3145; (NOP)  (905) 761-7945
# 16  43.845490 -79.555122         Walmart Supercentre; #1095  (905) 832-4060
# 17  43.917370 -78.959730         Walmart Supercentre; #3113  (905) 655-0206
#
#                       address           city Province postal_code  \
# 0     270 Kingston Rd E RR #1           Ajax       ON     L1S 4S7
# 1       135 First Commerce Dr         Aurora       ON     L4G 0G2
# 2         500 Copper Creek Dr        Markham       ON     L6B 0S1
# 3       5000 Hwy-7 Unit Y006A        Markham       ON     L3R 4M9
# 4               17940 Yonge S      Newmarket       ON     L3Y 8S4
# 5              1300 King St E         Oshawa       ON     L1H 8J4
# 6             1471 Harmony Rd         Oshawa       ON     L1H 7K5
# 7                680 Laval Dr         Oshawa       ON     L1J 0B5
# 8       1899 Brock Rd Unit #1      Pickering       ON     L1V 4H7
# 9   1070 Major Mackenzie Dr E  Richmond Hill       ON     L4S 1P3
# 10       255 Silver Linden Dr  Richmond Hill       ON     L4B 4V5
# 11          1000 Gerrard St E        Toronto       ON     M4M 3G6
# 12        2525 St Clair Ave W        Toronto       ON     M6N 4Z5
# 13              3757 Keele St        Toronto       ON     M3J 1N4
# 14            900 Dufferin St        Toronto       ON     M6H 4A9
# 15           101 Edgeley Blvd        Vaughan       ON     L4K 4Z4
# 16    3600 Major Mackenzie Dr        Vaughan       ON     L6A 1S1
# 17          4100 Baldwin St S         Whitby       ON     L1R 3H8
#
#           osmid  osmid_dist_m
# 0     674536269    277.963737
# 1     701911552    246.673809
# 2   10291311614     98.517541
# 3     437952581    189.265679
# 4     699255429     95.426436
# 5    1543685682    119.115062
# 6    1768769491    243.984412
# 7    1360818945    155.728635
# 8     414466395     83.206854
# 9     414461288    133.692850
# 10    428087600    165.561053
# 11     35992100    111.385944
# 12    420576809     88.513525
# 13    253013816     44.449970
# 14     23828442    103.976358
# 15    391917373    155.188839
# 16    391909065     82.203538
# 17   4597575290    135.341559

# %%
# visualize the walmart locations on the map
m = folium.Map(location=gta_part_loc.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=False)
for store_ind in range(wal_gta_count):
    folium.Marker(gta_part_loc.values.tolist()[store_ind],  popup=gta_part['store_number'][store_ind], icon=folium.Icon(color='blue', icon="fa-shopping-cart", prefix='fa'),).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_118de149bfc67b2cbd3504b56333f8ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_118de149bfc67b2cbd3504b56333f8ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_118de149bfc67b2cbd3504b56333f8ee = L.map(
#                 &quot;map_118de149bfc67b2cbd3504b56333f8ee&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f200049fffbf1881a00e66fb9eb86f96 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_118de149bfc67b2cbd3504b56333f8ee);
#
#
#             var marker_6be8a6e351769302a7d19425966aa260 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_118de149bfc67b2cbd3504b56333f8ee);
#
#
#             var icon_bdf74d81be0f7fb3dfd7ff905ef4ddae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6be8a6e351769302a7d19425966aa260.setIcon(icon_bdf74d81be0f7fb3dfd7ff905ef4ddae);
#
#
#         var popup_31729e56b25748724131e4a8e5dae128 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b099525603d64be9970e55e3090bd34 = $(`&lt;div id=&quot;html_8b099525603d64be9970e55e3090bd34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #3001&lt;/div&gt;`)[0];
#                 popup_31729e56b25748724131e4a8e5dae128.setContent(html_8b099525603d64be9970e55e3090bd34);
#
#
#
#         marker_6be8a6e351769302a7d19425966aa260.bindPopup(popup_31729e56b25748724131e4a8e5dae128)
#         ;
#
#
#
#
#             var marker_d5c5428aae2ad757d071370f763deee3 = L.marker(
#                 [44.01501, -79.411176],
#                 {}
#             ).addTo(map_118de149bfc67b2cbd3504b56333f8ee);
#
#
#             var icon_28ee390531f3ff496baedb2be050e56c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d5c5428aae2ad757d071370f763deee3.setIcon(icon_28ee390531f3ff496baedb2be050e56c);
#
#
#         var popup_ad6a2d88ef68efa3b6f3cc8ab566eb2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a2707a473e7ad967ed84a20d82f90a2 = $(`&lt;div id=&quot;html_1a2707a473e7ad967ed84a20d82f90a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #5778&lt;/div&gt;`)[0];
#                 popup_ad6a2d88ef68efa3b6f3cc8ab566eb2f.setContent(html_1a2707a473e7ad967ed84a20d82f90a2);
#
#
#
#         marker_d5c5428aae2ad757d071370f763deee3.bindPopup(popup_ad6a2d88ef68efa3b6f3cc8ab566eb2f)
#         ;
#
#
#
#
#             var marker_fa272bae14fc2570d7738106789193d9 = L.marker(
#                 [43.871301, -79.215267],
#                 {}
#             ).addTo(map_118de149bfc67b2cbd3504b56333f8ee);
#
#
#             var icon_33027d66c72751106526553497376914 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa272bae14fc2570d7738106789193d9.setIcon(icon_33027d66c72751106526553497376914);
#
#
#         var popup_14fa9c6f2da272a1bfd736921ebb4a2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9d96701e91ee791d68cb67b4b8032c5 = $(`&lt;div id=&quot;html_d9d96701e91ee791d68cb67b4b8032c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walmart Supercentre; #1109&lt;/div&gt;`)[0];
#                 popup_14fa9c6f2da272a1bfd736921ebb4a2a.setContent(html_d9d96701e91ee791d68cb67b4b8032c5);
#
#
#
#         marker_fa272bae14fc2570d7738106789193d9.bindPopup(popup_14fa9c6f2da272a1bfd736921ebb4a2a)
#         ;
#
#
#
#
#             var marker_b07e12f712e7a211e10e6e3507daaebe = L.marker(
#                 [43.867108, -79.290345],
#                 {}
#             ).addTo(map_118de149bfc67b2cbd3504b56333f8ee);
#
#
#             var icon_c7232a7d2f398be7e1f9abcf6f1ec39e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
# helper function that takes a folium map and plot an antpath based on the route of the osmids 
def draw_route(G, route, m):
    ways_frame = ox.graph_to_gdfs(G)[1]    
    path = []
    for u, v in zip(route[0:], route[1:]):
        try:
            geo = (ways_frame.query(f'u == {u} and v == {v}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        except:
            geo = (ways_frame.query(f'u == {v} and v == {u}').to_dict('list')['geometry'])
            m_geo = min(geo,key=lambda x:x.length)
        x, y = m_geo.coords.xy
        points = map(list, [*zip([*y],[*x])])
        path.extend([*points][:-1])

    folium.plugins.AntPath(
        locations = path,
        dash_array=[1, 10],
        delay=1000,
        color='red',
        pulse_color='black'
    ).add_to(m)

    return m

# %%
# A helper function that takes the graph and it creates a map and draw a path between all locations in it 
def draw_map_path(G, path, locations, routes):
    m = folium.Map(location=locations.mean().to_list(), zoom_start=10, scrollWheelZoom=False, dragging=True)

    route = []

    locationlist = locations.values.tolist()
    num_loc = len(locationlist)
    for i in range(num_loc):
        store_id = path[i]

        folium.Marker(location=locationlist[store_id], icon=folium.Icon(color='white', icon_color='white')).add_to(m)
        icon = folium.DivIcon(
            icon_size=(150,36),
            icon_anchor=(12,40),
            html="""<span class="fa-stack " style="font-size: 12pt" >
                    <span class="fa fa-circle-o fa-stack-2x" style="color : blue"></span>
                    <strong class="fa-stack-1x">
                         {:d}
                    </strong>
                </span>""".format(i)
        )
        folium.Marker(location=locationlist[store_id], icon=icon).add_to(m)
        
        if i == 0:
            store_id_1 = path[num_loc-1]
        else:
            store_id_1 = path[i-1]

        shortest_route = routes[store_id_1][store_id]
        
        if i == num_loc-1:
            route.extend(shortest_route)
        else:
            route.extend(shortest_route[:-1])

    draw_route(G, route, m=m)
        
    return m

# %%
# eval the distances between the walmart locations using the graph
gta_part_dists = np.zeros([wal_gta_count, wal_gta_count])
gta_part_pathes = [[[] for i in range(wal_gta_count)] for j in range(wal_gta_count)]
for i in range(wal_gta_count):
    for j in range(wal_gta_count):
        if i==j:
            continue
        gta_part_pathes[i][j] = nx.shortest_path(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length')
        gta_part_dists[i][j] = nx.shortest_path_length(G=G, source=gta_part.osmid[i], target=gta_part.osmid[j], weight='length')/1000

# %%
# create a TSP object for the problem
gta_part_tsp = TSP(dists=gta_part_dists, gen_method='mutate')

# %%
# create an SA object to help solving the tsp problem
sa = SimulatedAnnealing(max_iter=1000, max_iter_per_temp=100, initial_temp=85, final_temp=0.0001, cooling_schedule='linear', cooling_alpha=0.9)

# %%
# Get an initial random solution and check its length 
sa.init_annealing(gta_part_tsp)
print(sa.s_cur)
print(sa.val_cur)

# assuming store with index #0 has a warehouse and the tour will start and end with it.
ind = sa.s_cur.index(0)
# Out:
# [0, 5, 15, 10, 4, 8, 16, 7, 11, 3, 2, 12, 6, 9, 14, 1, 17, 13, 0]
# 744.3745210000001

# %%
# Draw the path of the random initial solution
# print(len(sa.s_cur[ind:] + sa.s_cur[:ind]))
draw_map_path(G, sa.s_cur[ind:] + sa.s_cur[:ind], gta_part_loc, gta_part_pathes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26184cc7641f05718a6a3635213ca97d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26184cc7641f05718a6a3635213ca97d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26184cc7641f05718a6a3635213ca97d = L.map(
#                 &quot;map_26184cc7641f05718a6a3635213ca97d&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cbe70469f7f8dfbb9263e82a38cdc45 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var marker_e2df0e460aa717bd4e9cf01ea5db970b = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var icon_96b755718b02fefca1571524179b569c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e2df0e460aa717bd4e9cf01ea5db970b.setIcon(icon_96b755718b02fefca1571524179b569c);
#
#
#             var marker_43da63fdce8b930a3789fa39058b9e18 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var div_icon_a57bb10ebcea29677af2c7860b4dfa1f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_43da63fdce8b930a3789fa39058b9e18.setIcon(div_icon_a57bb10ebcea29677af2c7860b4dfa1f);
#
#
#             var marker_3d1264144a6b1b3781e89f2bb7cc4d96 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var icon_890f1e34519c52d10a9546830fb9cdf8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d1264144a6b1b3781e89f2bb7cc4d96.setIcon(icon_890f1e34519c52d10a9546830fb9cdf8);
#
#
#             var marker_a867d9ea76ddc0320c6997e4984034f5 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var div_icon_b0ce3813ae339fa4d3da118031c5b9ae = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_a867d9ea76ddc0320c6997e4984034f5.setIcon(div_icon_b0ce3813ae339fa4d3da118031c5b9ae);
#
#
#             var marker_c8d0a77466be0150b2e34542c7695916 = L.marker(
#                 [43.795658, -79.530293],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);
#
#
#             var icon_f2787c84466d163285de09b554e7e7fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8d0a77466be0150b2e34542c7695916.setIcon(icon_f2787c84466d163285de09b554e7e7fb);
#
#
#             var marker_71138657cb110c72ea0478c700c3fb37 = L.marker(
#                 [43.795658, -79.530293],
#                 {}
#             ).addTo(map_26184cc7641f05718a6a3635213ca97d);

# %%
# Run SA and eval the best solution distance
sa.run(gta_part_tsp, repetition=10)
print(sa.val_allbest)

# print(gta_part_tsp.eval_solution(sa.s_allbest))
# draw_map_path(G, sa.s_allbest, gta_part_loc, gta_part_pathes)

# draw the sub-optimal path
print(gta_part_tsp.eval_solution(sa.s_allbest[ind:] + sa.s_allbest[:ind]))
draw_map_path(G, sa.s_allbest[ind:] + sa.s_allbest[:ind], gta_part_loc, gta_part_pathes)
# Out:
# 222.82919100000007
# 222.82919100000007
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e08cc5aef8cf07bf009d2ba0475122 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e08cc5aef8cf07bf009d2ba0475122&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39e08cc5aef8cf07bf009d2ba0475122 = L.map(
#                 &quot;map_39e08cc5aef8cf07bf009d2ba0475122&quot;,
#                 {
#                     center: [43.84941772222223, -79.25817699999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a476bf7adb1377587004aea0c61c046 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var marker_5c12007960c34ae0d14913e37b325f67 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var icon_fbfae801ee6b26d7b34883405c885187 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c12007960c34ae0d14913e37b325f67.setIcon(icon_fbfae801ee6b26d7b34883405c885187);
#
#
#             var marker_ed39e63708bd63a74d8e5f6de5d51cd2 = L.marker(
#                 [43.866158, -79.013226],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var div_icon_2b0a042770f32ff4fe784dd8fd2b17be = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         0\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_ed39e63708bd63a74d8e5f6de5d51cd2.setIcon(div_icon_2b0a042770f32ff4fe784dd8fd2b17be);
#
#
#             var marker_18721f9867ee6577d6e4b5d04fe5204b = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var icon_6a3762f8ca00487022ed527705fa9786 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18721f9867ee6577d6e4b5d04fe5204b.setIcon(icon_6a3762f8ca00487022ed527705fa9786);
#
#
#             var marker_1f53c035f6fc8eb380cfa80ca7252314 = L.marker(
#                 [43.88069, -78.88154],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var div_icon_6456b16e31ada165ce9aacc8063b0adf = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan class=\&quot;fa-stack \&quot; style=\&quot;font-size: 12pt\&quot; \u003e\n                    \u003cspan class=\&quot;fa fa-circle-o fa-stack-2x\&quot; style=\&quot;color : blue\&quot;\u003e\u003c/span\u003e\n                    \u003cstrong class=\&quot;fa-stack-1x\&quot;\u003e\n                         1\n                    \u003c/strong\u003e\n                \u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [12, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_1f53c035f6fc8eb380cfa80ca7252314.setIcon(div_icon_6456b16e31ada165ce9aacc8063b0adf);
#
#
#             var marker_eddf458085a76b14fb43d65e8cea7152 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
#
#
#             var icon_96d280b087fc44ad4825bed4f2c79a41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eddf458085a76b14fb43d65e8cea7152.setIcon(icon_96d280b087fc44ad4825bed4f2c79a41);
#
#
#             var marker_78b7440a42a68f2e3cb1d720249e1fe8 = L.marker(
#                 [43.907599, -78.814547],
#                 {}
#             ).addTo(map_39e08cc5aef8cf07bf009d2ba0475122);
