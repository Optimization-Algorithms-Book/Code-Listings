# %%
import hypernetx as hnx
import matplotlib.pyplot as plt

data = {
    0: ("A","B","G"),
    1: ("A","C","D","E","F"),
    2: ("B","F"),
    3: ("A","B","D","E","F","G")
}
H = hnx.Hypergraph(data)
hnx.draw(H)
plt.savefig('CH03_F05.png', format='png', dpi=300)
