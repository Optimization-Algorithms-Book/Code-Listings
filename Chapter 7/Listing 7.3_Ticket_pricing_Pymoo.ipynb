# %% [markdown]
# # Solving Ticket Pricing using GA in pymoo

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA
# from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.crossover.pntx import PointCrossover, SinglePointCrossover, TwoPointCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.core.problem import Problem
from pymoo.optimize import minimize

# %%
# define the problem
class TicketPrice(Problem):

    def __init__(self):
        super().__init__(n_var=1,
                         n_obj=1,
                         n_constr=0,
                         xl=75.0,
                         xu=235.0, vtype=float)

    def _evaluate(self, x, out, *args, **kwargs):
        out["F"]= 20*x*x-6200*x+350000

# %%
problem = TicketPrice()
algorithm = GA(
    pop_size=100,
    sampling=FloatRandomSampling(),
    crossover=PointCrossover(prob=0.8, n_points=2),
    mutation = PolynomialMutation(prob=0.3, repair=RoundingRepair()),
    eliminate_duplicates=True
)

res = minimize(problem, algorithm, ('n_gen', 100), seed=1, verbose=True)

# show the results
print(f"Optimal ticket price ($): {res.X}")
print(f"Profit ($): {-res.F}") # negate the objective value when printing the result
# Out:
# =================================================
# n_gen  |  n_eval  |     f_avg     |     f_min
# =================================================
#      1 |      100 | -8.602168E+04 | -1.304636E+05
#      2 |      200 | -1.211150E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      3 |      243 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      4 |      277 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      5 |      307 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      6 |      334 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      7 |      363 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      8 |      394 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      9 |      423 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     10 |      453 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     11 |      484 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     12 |      511 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     13 |      539 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     14 |      568 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     15 |      595 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     16 |      627 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     17 |      659 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     18 |      690 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     19 |      720 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     20 |      754 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     21 |      787 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     22 |      814 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     23 |      837 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     24 |      869 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     25 |      894 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     26 |      926 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     27 |      955 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     28 |      984 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     29 |     1015 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     30 |     1049 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     31 |     1076 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     32 |     1106 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     33 |     1139 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     34 |     1170 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     35 |     1199 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     36 |     1226 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     37 |     1256 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     38 |     1291 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     39 |     1318 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     40 |     1347 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     41 |     1382 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     42 |     1411 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     43 |     1443 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     44 |     1475 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     45 |     1504 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     46 |     1535 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     47 |     1566 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     48 |     1593 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     49 |     1619 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     50 |     1651 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     51 |     1679 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     52 |     1711 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     53 |     1740 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     54 |     1771 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     55 |     1798 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     56 |     1828 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     57 |     1854 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     58 |     1881 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     59 |     1909 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     60 |     1942 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     61 |     1969 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     62 |     1993 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     63 |     2023 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     64 |     2054 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     65 |     2084 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     66 |     2117 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     67 |     2149 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     68 |     2179 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     69 |     2209 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     70 |     2237 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     71 |     2267 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     72 |     2294 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     73 |     2325 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     74 |     2353 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     75 |     2385 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     76 |     2411 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     77 |     2442 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     78 |     2477 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     79 |     2509 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     80 |     2541 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     81 |     2569 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     82 |     2600 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     83 |     2630 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     84 |     2661 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     85 |     2694 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     86 |     2727 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     87 |     2757 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     88 |     2790 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     89 |     2819 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     90 |     2844 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     91 |     2871 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     92 |     2901 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     93 |     2929 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     94 |     2965 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     95 |     2995 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     96 |     3023 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     97 |     3054 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     98 |     3083 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#     99 |     3118 | -1.238438E+05 | -1.305000E+05
# WARNING: Mating could not produce the required number of (unique) offsprings!
#    100 |     3143 | -1.238438E+05 | -1.305000E+05
# Optimal ticket price ($): [155]
# Profit ($): [130500.]
